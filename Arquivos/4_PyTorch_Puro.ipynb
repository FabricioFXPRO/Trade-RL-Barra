# %%
# Bloco 1: Preparar os Dados

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time

# Carregar o dataset
data = pd.read_csv('D:\\dados\\bar_M1_data_07-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = ['Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior', 'Corpo', 'Range', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK', 'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram']
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# Bloco 2: Criar o Ambiente

import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(low=0, high=1, shape=(len(data.columns) - 3,), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        return obs.astype(np.float32)

    def step(self, action):
        self.current_step += 1

        done = self.current_step >= len(self.data) - 1
        reward = 0

        if action == 1:  # Comprar
            reward = (self.data['Valor'].iloc[self.current_step] - self.data['Valor'].iloc[self.current_step - 1]) - 0.25  # Subtrair custo de operação
        elif action == 2:  # Vender
            reward = (self.data['Valor'].iloc[self.current_step - 1] - self.data['Valor'].iloc[self.current_step]) - 0.25  # Subtrair custo de operação

        obs = self._next_observation()
        return obs, reward, done, {}

# Bloco 3: Criar o Agente usando PyTorch

import torch
import torch.nn as nn
import torch.optim as optim

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Definir a rede de política (Policy Network)
class PolicyNetwork(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(PolicyNetwork, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.model(x)

# Definir a rede de valor (Value Network)
class ValueNetwork(nn.Module):
    def __init__(self, obs_size):
        super(ValueNetwork, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return self.model(x)

# Instanciar as redes
policy_net = PolicyNetwork(obs_size, n_actions).to(device)
value_net = ValueNetwork(obs_size).to(device)

# Definir os otimizadores
policy_optimizer = optim.Adam(policy_net.parameters(), lr=1e-4)
value_optimizer = optim.Adam(value_net.parameters(), lr=1e-3)

# Bloco 4: Treinamento com Logs usando PyTorch

from torch.distributions import Categorical
import random

# Hiperparâmetros adicionais
episodes = 1000          # Número total de episódios para treinar
timestep = 0             # Contador de passos de tempo
update_timestep = 2000   # Número de passos de tempo para atualizar a política
gamma = 0.99             # Taxa de desconto para cálculo de recompensas futuras
K_epochs = 4             # Número de épocas para atualizar a política
eps_clip = 0.2           # Parâmetro de clipagem para PPO
epsilon = 0.1            # Taxa de exploração para estratégia epsilon-greedy

for episode in range(episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).to(device)
    done = False
    total_reward = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0

    # Memória para armazenar experiências
    states = []
    actions = []
    rewards = []
    dones = []
    log_probs = []

    while not done:
        timestep += 1

        # Epsilon-greedy: escolher ação aleatória com probabilidade epsilon
        if random.uniform(0, 1) < epsilon:
            action = torch.tensor(random.choice([0, 1, 2]), dtype=torch.long).to(device)
            log_prob = torch.tensor(0.0).to(device)  # Nenhuma probabilidade de log válida para ações aleatórias
        else:
            # Selecionar ação da rede de política
            logits = policy_net(obs)
            dist = Categorical(logits=logits)
            action = dist.sample()
            log_prob = dist.log_prob(action)

        obs_next, reward, done, _ = env.step(action.item())
        obs_next = torch.FloatTensor(obs_next).to(device)

        # Armazenar na memória
        states.append(obs)
        actions.append(action)
        rewards.append(torch.tensor(reward, dtype=torch.float32, device=device))
        dones.append(torch.tensor(done, dtype=torch.float32, device=device))
        log_probs.append(log_prob)

        # Atualizar contagem de ações e total de recompensas
        action_int = action.item()
        actions_count[action_int] += 1
        total_reward += reward
        if reward > 0:
            wins += 1
            win_total += reward
        elif reward < 0:
            losses += 1
            lose_total += reward

        # Imprimir logs apenas quando o gatilho for igual a 1
        gatilho = int(data['Gatilho'].iloc[env.current_step])
        if gatilho == 1:
            print(f"Episode: {episode + 1}, Step: {env.current_step}, Action: {action_int}, Reward: {reward}")

        # Atualizar o estado
        obs = obs_next

        # Atualizar a política se o timestep atingir o limite
        if timestep % update_timestep == 0 or done:
            # Converter listas em tensores
            states_tensor = torch.stack(states)
            actions_tensor = torch.stack(actions)
            rewards_tensor = torch.tensor(rewards, dtype=torch.float32, device=device)
            dones_tensor = torch.tensor(dones, dtype=torch.float32, device=device)
            log_probs_tensor = torch.stack(log_probs).detach()

            # Calcular os valores e vantagens
            returns = []
            discounted_reward = torch.tensor(0.0, device=device)
            for reward, is_done in zip(reversed(rewards_tensor), reversed(dones_tensor)):
                if is_done.item():
                    discounted_reward = torch.tensor(0.0, device=device)
                discounted_reward = reward + (gamma * discounted_reward)
                returns.insert(0, discounted_reward)
            returns = torch.stack(returns).detach()

            # Converter estados para o dispositivo
            states_tensor = states_tensor.to(device)
            actions_tensor = actions_tensor.to(device)

            # Calcular valores atuais
            values = value_net(states_tensor).squeeze()

            # Calcular vantagens
            advantages = (returns - values).detach()

            # Normalizar vantagens
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

            # Atualizar a política e a rede de valor
            policy_loss_accum = 0
            value_loss_accum = 0
            for _ in range(K_epochs):
                # Calcular perdas
                logits = policy_net(states_tensor)
                dist = Categorical(logits=logits)
                new_log_probs = dist.log_prob(actions_tensor)
                entropy = dist.entropy().mean()

                ratio = (new_log_probs - log_probs_tensor).exp()
                surr1 = ratio * advantages
                surr2 = torch.clamp(ratio, 1 - eps_clip, 1 + eps_clip) * advantages
                policy_loss = -torch.min(surr1, surr2).mean()
                policy_loss_accum += policy_loss

                value_loss = nn.MSELoss()(values, returns)
                value_loss_accum += value_loss

            # Atualizar a política
            policy_optimizer.zero_grad()
            policy_loss_accum.backward(retain_graph=True)
            policy_optimizer.step()

            # Atualizar a rede de valor
            value_optimizer.zero_grad()
            value_loss_accum.backward()
            value_optimizer.step()

            # Limpar memória
            states = []
            actions = []
            rewards = []
            dones = []
            log_probs = []
            timestep = 0

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    end_time = time.time()
    training_time = end_time - start_time
    print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Win Rate: {win_rate:.2f}, Win Total: {win_total}, Lose Total: {lose_total}, Ação 0: {actions_count[0]}, Ação 1: {actions_count[1]}, Ação 2: {actions_count[2]}, Wins: {wins}, Losses: {losses}")
    print(f"Tempo de Treinamento: {training_time:.2f} segundos")

print("Treinamento finalizado.")
# Out:
# Episode: 1, Step: 630, Action: 2, Reward: 0.5
# Episode: 1, Step: 631, Action: 2, Reward: 2.5
# Episode: 1, Step: 632, Action: 2, Reward: -1.0
# Episode: 1, Step: 633, Action: 2, Reward: -4.75
# Episode: 1, Step: 634, Action: 2, Reward: 1.0
# Episode: 1, Step: 635, Action: 2, Reward: 2.25
# Episode: 1, Step: 636, Action: 2, Reward: 0.5
# Episode: 1, Step: 637, Action: 2, Reward: 1.0
# Episode: 1, Step: 638, Action: 2, Reward: 0.0
# Episode: 1, Step: 639, Action: 2, Reward: -1.0
# Episode: 1, Step: 640, Action: 2, Reward: -1.75
# Episode: 1, Step: 641, Action: 0, Reward: 0
# Episode: 1, Step: 642, Action: 2, Reward: -3.0
# Episode: 1, Step: 643, Action: 2, Reward: -5.0
# Episode: 1, Step: 644, Action: 2, Reward: 1.5
# Episode: 1, Step: 645, Action: 2, Reward: -0.25
# Episode: 1, Step: 646, Action: 2, Reward: -0.75
# Episode: 1, Step: 647, Action: 2, Reward: -0.5
# Episode: 1, Step: 648, Action: 2, Reward: -2.75
# Episode: 1, Step: 649, Action: 2, Reward: 4.0
# Episode: 1, Step: 650, Action: 2, Reward: -2.5
# Episode: 1, Step: 651, Action: 2, Reward: -1.25
# Episode: 1, Step: 652, Action: 2, Reward: -5.0
# Episode: 1, Step: 653, Action: 2, Reward: -5.25
# Episode: 1, Step: 654, Action: 2, Reward: -1.0
# Episode: 1, Step: 655, Action: 2, Reward: -1.75
# Episode: 1, Step: 656, Action: 2, Reward: -0.5
# Episode: 1, Step: 657, Action: 2, Reward: -1.0
# Episode: 1, Step: 658, Action: 2, Reward: 3.0
# Episode: 1, Step: 659, Action: 2, Reward: -3.75
# Episode: 1, Step: 660, Action: 0, Reward: 0
# Episode: 1, Step: 1949, Action: 2, Reward: 0.5
# Episode: 1, Step: 1950, Action: 2, Reward: -0.25
# Episode: 1, Step: 1951, Action: 2, Reward: -0.25
# Episode: 1, Step: 1952, Action: 2, Reward: 1.0
# Episode: 1, Step: 1953, Action: 2, Reward: 3.25
# Episode: 1, Step: 1954, Action: 2, Reward: -2.75
# Episode: 1, Step: 1955, Action: 2, Reward: -1.75
# Episode: 1, Step: 1956, Action: 2, Reward: 1.75
# Episode: 1, Step: 1957, Action: 2, Reward: -4.25
# Episode: 1, Step: 1958, Action: 2, Reward: 1.0
# Episode: 1, Step: 1959, Action: 0, Reward: 0
# Episode: 1, Step: 1960, Action: 2, Reward: -0.75
# Episode: 1, Step: 1961, Action: 2, Reward: -4.0
# Episode: 1, Step: 1962, Action: 2, Reward: 0.25
# Episode: 1, Step: 1963, Action: 2, Reward: -2.0
# Episode: 1, Step: 1964, Action: 2, Reward: -3.0
# Episode: 1, Step: 1965, Action: 1, Reward: -0.25
# Episode: 1, Step: 1966, Action: 2, Reward: -2.0
# Episode: 1, Step: 1967, Action: 2, Reward: 3.25
# Episode: 1, Step: 1968, Action: 2, Reward: -0.5
# Episode: 1, Step: 1969, Action: 2, Reward: -0.75
# Episode: 1, Step: 1970, Action: 2, Reward: 1.25
# Episode: 1, Step: 1971, Action: 2, Reward: 1.25
# Episode: 1, Step: 1972, Action: 2, Reward: 0.75
# Episode: 1, Step: 1973, Action: 2, Reward: -0.25
# Episode: 1, Step: 1974, Action: 2, Reward: -3.25
# Episode: 1, Step: 1975, Action: 2, Reward: 0.75
# Episode: 1, Step: 1976, Action: 2, Reward: -0.25
# Episode: 1, Step: 1977, Action: 2, Reward: -2.75
# Episode: 1, Step: 1978, Action: 2, Reward: -1.5
# Episode: 1, Step: 1979, Action: 2, Reward: 0.75
# Episode: 1, Step: 3268, Action: 2, Reward: 1.25
# Episode: 1, Step: 3269, Action: 2, Reward: -2.25
# Episode: 1, Step: 3270, Action: 2, Reward: -0.25
# Episode: 1, Step: 3271, Action: 2, Reward: 1.75
# Episode: 1, Step: 3272, Action: 2, Reward: 0.25
# Episode: 1, Step: 3273, Action: 2, Reward: -1.75
# Episode: 1, Step: 3274, Action: 2, Reward: 2.25
# Episode: 1, Step: 3275, Action: 2, Reward: -1.5
# Episode: 1, Step: 3276, Action: 2, Reward: 1.5
# Episode: 1, Step: 3277, Action: 2, Reward: -1.5
# Episode: 1, Step: 3278, Action: 0, Reward: 0
# Episode: 1, Step: 3279, Action: 2, Reward: 1.5
# Episode: 1, Step: 3280, Action: 2, Reward: -3.25
# Episode: 1, Step: 3281, Action: 2, Reward: 0.25
# Episode: 1, Step: 3282, Action: 2, Reward: 0.5
# Episode: 1, Step: 3283, Action: 2, Reward: 1.75
# Episode: 1, Step: 3284, Action: 2, Reward: 3.0
# Episode: 1, Step: 3285, Action: 2, Reward: -2.75
# Episode: 1, Step: 3286, Action: 2, Reward: 0.0
# Episode: 1, Step: 3287, Action: 1, Reward: -1.25
# Episode: 1, Step: 3288, Action: 2, Reward: 0.5
# Episode: 1, Step: 3289, Action: 2, Reward: -3.0
# Episode: 1, Step: 3290, Action: 2, Reward: 2.0
# Episode: 1, Step: 3291, Action: 2, Reward: 1.75
# Episode: 1, Step: 3292, Action: 2, Reward: -2.25
# Episode: 1, Step: 3293, Action: 2, Reward: 0.5
# Episode: 1, Step: 3294, Action: 2, Reward: 0.25
# Episode: 1, Step: 3295, Action: 2, Reward: 0.75
# Episode: 1, Step: 3296, Action: 2, Reward: -2.25
# Episode: 1, Step: 3297, Action: 2, Reward: 3.75
# Episode: 1, Step: 3298, Action: 2, Reward: 1.75
# Episode: 1, Step: 4237, Action: 2, Reward: -0.75
# Episode: 1, Step: 4238, Action: 2, Reward: -0.25
# Episode: 1, Step: 4239, Action: 2, Reward: 0.25
# Episode: 1, Step: 4240, Action: 2, Reward: 0.5
# Episode: 1, Step: 4241, Action: 2, Reward: -0.25
# Episode: 1, Step: 4242, Action: 2, Reward: 0.0
# Episode: 1, Step: 4243, Action: 2, Reward: 0.0
# Episode: 1, Step: 4244, Action: 2, Reward: -1.75
# Episode: 1, Step: 4245, Action: 2, Reward: 0.25
# Episode: 1, Step: 4246, Action: 0, Reward: 0
# Episode: 1, Step: 4247, Action: 2, Reward: -0.75
# Episode: 1, Step: 4248, Action: 2, Reward: -0.75
# Episode: 1, Step: 4249, Action: 2, Reward: -1.0
# Episode: 1, Step: 4250, Action: 2, Reward: 1.25
# Episode: 1, Step: 4251, Action: 2, Reward: 1.25
# Episode: 1, Step: 4252, Action: 2, Reward: -1.0
# Episode: 1, Step: 4253, Action: 2, Reward: -1.25
# Episode: 1, Step: 4254, Action: 2, Reward: -0.5
# Episode: 1, Step: 4255, Action: 2, Reward: -1.25
# Episode: 1, Step: 4256, Action: 2, Reward: -0.25
# Episode: 1, Step: 4257, Action: 2, Reward: 0.5
# Episode: 1, Step: 4258, Action: 2, Reward: -0.75
# Episode: 1, Step: 4259, Action: 2, Reward: -2.25
# Episode: 1, Step: 4260, Action: 2, Reward: -1.0
# Episode: 1, Step: 4261, Action: 2, Reward: -1.25
# Episode: 1, Step: 4262, Action: 2, Reward: -0.25
# Episode: 1, Step: 4263, Action: 2, Reward: 1.0
# Episode: 1, Step: 4264, Action: 2, Reward: 0.25
# Episode: 1, Step: 4265, Action: 2, Reward: -0.5
# Episode: 1, Step: 4266, Action: 2, Reward: 1.25
# Episode: 1, Step: 4267, Action: 2, Reward: -0.25
# Episode: 1, Step: 5194, Action: 2, Reward: -2.0
# Episode: 1, Step: 5195, Action: 2, Reward: -0.75
# Episode: 1, Step: 5196, Action: 2, Reward: 1.0
# Episode: 1, Step: 5197, Action: 2, Reward: -1.25
# Episode: 1, Step: 5198, Action: 1, Reward: 0.75
# Episode: 1, Step: 5199, Action: 2, Reward: 0.0
# Episode: 1, Step: 5200, Action: 2, Reward: -2.0
# Episode: 1, Step: 5201, Action: 2, Reward: -2.25
# Episode: 1, Step: 5202, Action: 2, Reward: -4.0
# Episode: 1, Step: 5203, Action: 2, Reward: -3.75
# Episode: 1, Step: 5204, Action: 2, Reward: 5.25
# Episode: 1, Step: 5205, Action: 2, Reward: -0.25
# Episode: 1, Step: 5206, Action: 2, Reward: 0.25
# Episode: 1, Step: 5207, Action: 2, Reward: -1.5
# Episode: 1, Step: 5208, Action: 0, Reward: 0
# Episode: 1, Step: 5209, Action: 2, Reward: 1.25
# Episode: 1, Step: 5210, Action: 2, Reward: -0.25
# Episode: 1, Step: 5211, Action: 2, Reward: -0.5
# Episode: 1, Step: 5212, Action: 2, Reward: 2.5
# Episode: 1, Step: 5213, Action: 2, Reward: -1.5
# Episode: 1, Step: 5214, Action: 2, Reward: 1.75
# Episode: 1, Step: 5215, Action: 2, Reward: -0.75
# Episode: 1, Step: 5216, Action: 2, Reward: -2.5
# Episode: 1, Step: 5217, Action: 2, Reward: -2.25
# Episode: 1, Step: 5218, Action: 2, Reward: 0.25
# Episode: 1, Step: 5219, Action: 2, Reward: 2.5
# Episode: 1, Step: 5220, Action: 2, Reward: -1.0
# Episode: 1, Step: 5221, Action: 2, Reward: 1.0
# Episode: 1, Step: 5222, Action: 2, Reward: -2.25
# Episode: 1, Step: 5223, Action: 2, Reward: 0.5
# Episode: 1, Step: 5224, Action: 2, Reward: -0.25
# Episode: 1, Step: 6393, Action: 2, Reward: 0.75
# Episode: 1, Step: 6394, Action: 2, Reward: -0.25
# Episode: 1, Step: 6395, Action: 2, Reward: 0.5
# Episode: 1, Step: 6396, Action: 2, Reward: 1.25
# Episode: 1, Step: 6397, Action: 2, Reward: -4.25
# Episode: 1, Step: 6398, Action: 2, Reward: 0.75
# Episode: 1, Step: 6399, Action: 2, Reward: -0.75
# Episode: 1, Step: 6400, Action: 2, Reward: 0.25
# Episode: 1, Step: 6401, Action: 2, Reward: 0.5
# Episode: 1, Step: 6402, Action: 2, Reward: 0.0
# Episode: 1, Step: 6403, Action: 2, Reward: 0.0
# Episode: 1, Step: 6404, Action: 2, Reward: 0.25
# Episode: 1, Step: 6405, Action: 2, Reward: 0.25
# Episode: 1, Step: 6406, Action: 2, Reward: -1.75
# Episode: 1, Step: 6407, Action: 2, Reward: -3.25
# Episode: 1, Step: 6408, Action: 2, Reward: 1.25
# Episode: 1, Step: 6409, Action: 2, Reward: -0.5
# Episode: 1, Step: 6410, Action: 2, Reward: 0.75
# Episode: 1, Step: 6411, Action: 2, Reward: 1.5
# Episode: 1, Step: 6412, Action: 2, Reward: -0.5
# Episode: 1, Step: 6413, Action: 2, Reward: -3.75
# Episode: 1, Step: 6414, Action: 2, Reward: 0.0
# Episode: 1, Step: 6415, Action: 2, Reward: 1.75
# Episode: 1, Step: 6416, Action: 2, Reward: 0.25
# Episode: 1, Step: 6417, Action: 2, Reward: -1.25
# Episode: 1, Step: 6418, Action: 2, Reward: -1.75
# Episode: 1, Step: 6419, Action: 2, Reward: 2.75
# Episode: 1, Step: 6420, Action: 2, Reward: 2.0
# Episode: 1, Step: 6421, Action: 2, Reward: -0.5
# Episode: 1, Step: 6422, Action: 1, Reward: 1.0
# Episode: 1, Step: 6423, Action: 2, Reward: 2.25
# Episode: 1, Step: 7711, Action: 2, Reward: 0.5
# Episode: 1, Step: 7712, Action: 2, Reward: -4.5
# Episode: 1, Step: 7713, Action: 2, Reward: -1.75
# Episode: 1, Step: 7714, Action: 2, Reward: -0.25
# Episode: 1, Step: 7715, Action: 2, Reward: -0.75
# Episode: 1, Step: 7716, Action: 2, Reward: -1.5
# Episode: 1, Step: 7717, Action: 2, Reward: 1.0
# Episode: 1, Step: 7718, Action: 1, Reward: -1.25
# Episode: 1, Step: 7719, Action: 2, Reward: -1.75
# Episode: 1, Step: 7720, Action: 2, Reward: -0.25
# Episode: 1, Step: 7721, Action: 2, Reward: 1.75
# Episode: 1, Step: 7722, Action: 2, Reward: -1.0
# Episode: 1, Step: 7723, Action: 2, Reward: 0.5
# Episode: 1, Step: 7724, Action: 2, Reward: -1.0
# Episode: 1, Step: 7725, Action: 2, Reward: 0.25
# Episode: 1, Step: 7726, Action: 2, Reward: 1.5
# Episode: 1, Step: 7727, Action: 2, Reward: -0.75
# Episode: 1, Step: 7728, Action: 2, Reward: -2.5
# Episode: 1, Step: 7729, Action: 2, Reward: 2.0
# Episode: 1, Step: 7730, Action: 2, Reward: 2.5
# Episode: 1, Step: 7731, Action: 2, Reward: -1.0
# Episode: 1, Step: 7732, Action: 2, Reward: -2.25
# Episode: 1, Step: 7733, Action: 2, Reward: -2.0
# Episode: 1, Step: 7734, Action: 2, Reward: 0.25
# Episode: 1, Step: 7735, Action: 2, Reward: 1.5
# Episode: 1, Step: 7736, Action: 2, Reward: -0.75
# Episode: 1, Step: 7737, Action: 2, Reward: 0.0
# Episode: 1, Step: 7738, Action: 2, Reward: 1.25
# Episode: 1, Step: 7739, Action: 2, Reward: -1.75
# Episode: 1, Step: 7740, Action: 2, Reward: 0.75
# Episode: 1, Step: 7741, Action: 2, Reward: -1.25
# Episode: 1, Step: 9030, Action: 2, Reward: 0.0
# Episode: 1, Step: 9031, Action: 2, Reward: -2.0
# Episode: 1, Step: 9032, Action: 2, Reward: 0.5
# Episode: 1, Step: 9033, Action: 2, Reward: 1.25
# Episode: 1, Step: 9034, Action: 1, Reward: -0.75
# Episode: 1, Step: 9035, Action: 2, Reward: 0.5
# Episode: 1, Step: 9036, Action: 2, Reward: 0.75
# Episode: 1, Step: 9037, Action: 2, Reward: -0.5
# Episode: 1, Step: 9038, Action: 2, Reward: -2.25
# Episode: 1, Step: 9039, Action: 2, Reward: -0.75
# Episode: 1, Step: 9040, Action: 2, Reward: -1.25
# Episode: 1, Step: 9041, Action: 2, Reward: 0.25
# Episode: 1, Step: 9042, Action: 2, Reward: 0.25
# Episode: 1, Step: 9043, Action: 2, Reward: -0.5
# Episode: 1, Step: 9044, Action: 2, Reward: 1.5
# Episode: 1, Step: 9045, Action: 0, Reward: 0
# Episode: 1, Step: 9046, Action: 2, Reward: 0.25
# Episode: 1, Step: 9047, Action: 2, Reward: -1.0
# Episode: 1, Step: 9048, Action: 2, Reward: -1.75
# Episode: 1, Step: 9049, Action: 2, Reward: 3.25
# Episode: 1, Step: 9050, Action: 2, Reward: -1.25
# Episode: 1, Step: 9051, Action: 2, Reward: 0.0
# Episode: 1, Step: 9052, Action: 2, Reward: 1.25
# Episode: 1, Step: 9053, Action: 2, Reward: -1.0
# Episode: 1, Step: 9054, Action: 2, Reward: 0.25
# Episode: 1, Step: 9055, Action: 2, Reward: -0.75
# Episode: 1, Step: 9056, Action: 2, Reward: 0.0
# Episode: 1, Step: 9057, Action: 2, Reward: -1.25
# Episode: 1, Step: 9058, Action: 2, Reward: -0.5
# Episode: 1, Step: 9059, Action: 2, Reward: 0.75
# Episode: 1, Step: 9060, Action: 2, Reward: 0.0
# Episode: 1, Step: 10348, Action: 2, Reward: 0.75
# Episode: 1, Step: 10349, Action: 2, Reward: -1.75
# Episode: 1, Step: 10350, Action: 2, Reward: -1.0
# Episode: 1, Step: 10351, Action: 2, Reward: -0.25
# Episode: 1, Step: 10352, Action: 2, Reward: 1.5
# Episode: 1, Step: 10353, Action: 2, Reward: -0.25
# Episode: 1, Step: 10354, Action: 2, Reward: 1.75
# Episode: 1, Step: 10355, Action: 2, Reward: -1.75
# Episode: 1, Step: 10356, Action: 2, Reward: 1.25
# Episode: 1, Step: 10357, Action: 2, Reward: -0.25
# Episode: 1, Step: 10358, Action: 2, Reward: -1.5
# Episode: 1, Step: 10359, Action: 2, Reward: -1.5
# Episode: 1, Step: 10360, Action: 2, Reward: 1.0
# Episode: 1, Step: 10361, Action: 2, Reward: -0.25
# Episode: 1, Step: 10362, Action: 2, Reward: 0.5
# Episode: 1, Step: 10363, Action: 2, Reward: -0.75
# Episode: 1, Step: 10364, Action: 2, Reward: 0.75
# Episode: 1, Step: 10365, Action: 2, Reward: 0.5
# Episode: 1, Step: 10366, Action: 2, Reward: -1.0
# Episode: 1, Step: 10367, Action: 2, Reward: 1.25
# Episode: 1, Step: 10368, Action: 2, Reward: -2.5
# Episode: 1, Step: 10369, Action: 2, Reward: 1.0
# Episode: 1, Step: 10370, Action: 2, Reward: -0.25
# Episode: 1, Step: 10371, Action: 2, Reward: 1.0
# Episode: 1, Step: 10372, Action: 2, Reward: -1.25
# Episode: 1, Step: 10373, Action: 1, Reward: 1.0
# Episode: 1, Step: 10374, Action: 2, Reward: 1.25
# Episode: 1, Step: 10375, Action: 2, Reward: -1.75
# Episode: 1, Step: 10376, Action: 2, Reward: -0.5
# Episode: 1, Step: 10377, Action: 2, Reward: -1.5
# Episode: 1, Step: 10378, Action: 2, Reward: -0.5
# Episode: 1, Step: 11667, Action: 2, Reward: -3.5
# Episode: 1, Step: 11668, Action: 2, Reward: 2.75
# Episode: 1, Step: 11669, Action: 2, Reward: -0.25
# Episode: 1, Step: 11670, Action: 2, Reward: -3.5
# Episode: 1, Step: 11671, Action: 2, Reward: 0.25
# Episode: 1, Step: 11672, Action: 2, Reward: -1.0
# Episode: 1, Step: 11673, Action: 2, Reward: -2.75
# Episode: 1, Step: 11674, Action: 2, Reward: -1.25
# Episode: 1, Step: 11675, Action: 2, Reward: 2.5
# Episode: 1, Step: 11676, Action: 2, Reward: 0.25
# Episode: 1, Step: 11677, Action: 2, Reward: 0.75
# Episode: 1, Step: 11678, Action: 2, Reward: 1.25
# Episode: 1, Step: 11679, Action: 2, Reward: 2.25
# Episode: 1, Step: 11680, Action: 2, Reward: 0.25
# Episode: 1, Step: 11681, Action: 2, Reward: -1.25
# Episode: 1, Step: 11682, Action: 2, Reward: -2.5
# Episode: 1, Step: 11683, Action: 2, Reward: 2.75
# Episode: 1, Step: 11684, Action: 2, Reward: 2.0
# Episode: 1, Step: 11685, Action: 2, Reward: 0.75
# Episode: 1, Step: 11686, Action: 2, Reward: 5.0
# Episode: 1, Step: 11687, Action: 2, Reward: 3.75
# Episode: 1, Step: 11688, Action: 2, Reward: -9.0
# Episode: 1, Step: 11689, Action: 2, Reward: 1.0
# Episode: 1, Step: 11690, Action: 2, Reward: -3.75
# Episode: 1, Step: 11691, Action: 2, Reward: -4.5
# Episode: 1, Step: 11692, Action: 2, Reward: -1.25
# Episode: 1, Step: 11693, Action: 2, Reward: 3.75
# Episode: 1, Step: 11694, Action: 2, Reward: -1.5
# Episode: 1, Step: 11695, Action: 2, Reward: -2.25
# Episode: 1, Step: 11696, Action: 2, Reward: 0.5
# Episode: 1, Step: 11697, Action: 2, Reward: 0.5
# Episode: 1, Step: 12863, Action: 2, Reward: 1.25
# Episode: 1, Step: 12864, Action: 2, Reward: 0.0
# Episode: 1, Step: 12865, Action: 1, Reward: 0.25
# Episode: 1, Step: 12866, Action: 2, Reward: 1.75
# Episode: 1, Step: 12867, Action: 2, Reward: -2.25
# Episode: 1, Step: 12868, Action: 2, Reward: 0.5
# Episode: 1, Step: 12869, Action: 2, Reward: 1.25
# Episode: 1, Step: 12870, Action: 2, Reward: -2.25
# Episode: 1, Step: 12871, Action: 0, Reward: 0
# Episode: 1, Step: 12872, Action: 2, Reward: 0.0
# Episode: 1, Step: 12873, Action: 2, Reward: -1.5
# Episode: 1, Step: 12874, Action: 2, Reward: -2.75
# Episode: 1, Step: 12875, Action: 2, Reward: 0.0
# Episode: 1, Step: 12876, Action: 1, Reward: 0.0
# Episode: 1, Step: 12877, Action: 2, Reward: -0.25
# Episode: 1, Step: 12878, Action: 2, Reward: 1.0
# Episode: 1, Step: 12879, Action: 2, Reward: 0.0
# Episode: 1, Step: 12880, Action: 2, Reward: -2.0
# Episode: 1, Step: 12881, Action: 2, Reward: 0.75
# Episode: 1, Step: 12882, Action: 2, Reward: -0.25
# Episode: 1, Step: 12883, Action: 2, Reward: -0.5
# Episode: 1, Step: 12884, Action: 2, Reward: 0.0
# Episode: 1, Step: 12885, Action: 2, Reward: -0.25
# Episode: 1, Step: 12886, Action: 2, Reward: -1.0
# Episode: 1, Step: 12887, Action: 2, Reward: -0.25
# Episode: 1, Step: 12888, Action: 2, Reward: 0.0
# Episode: 1, Step: 12889, Action: 2, Reward: 0.0
# Episode: 1, Step: 12890, Action: 2, Reward: 1.25
# Episode: 1, Step: 12891, Action: 2, Reward: 0.0
# Episode: 1, Step: 12892, Action: 2, Reward: -2.75
# Episode: 1, Step: 12893, Action: 2, Reward: -2.5
# Episode: 1, Step: 14182, Action: 2, Reward: -1.25
# Episode: 1, Step: 14183, Action: 2, Reward: 0.25
# Episode: 1, Step: 14184, Action: 2, Reward: -0.5
# Episode: 1, Step: 14185, Action: 2, Reward: -1.5
# Episode: 1, Step: 14186, Action: 2, Reward: -5.75
# Episode: 1, Step: 14187, Action: 2, Reward: 0.25
# Episode: 1, Step: 14188, Action: 2, Reward: 3.0
# Episode: 1, Step: 14189, Action: 2, Reward: 2.25
# Episode: 1, Step: 14190, Action: 2, Reward: 3.75
# Episode: 1, Step: 14191, Action: 2, Reward: 0.25
# Episode: 1, Step: 14192, Action: 2, Reward: 1.75
# Episode: 1, Step: 14193, Action: 2, Reward: -6.0
# Episode: 1, Step: 14194, Action: 2, Reward: -1.0
# Episode: 1, Step: 14195, Action: 2, Reward: 0.75
# Episode: 1, Step: 14196, Action: 2, Reward: 0.25
# Episode: 1, Step: 14197, Action: 2, Reward: 1.25
# Episode: 1, Step: 14198, Action: 2, Reward: -5.75
# Episode: 1, Step: 14199, Action: 2, Reward: 2.5
# Episode: 1, Step: 14200, Action: 2, Reward: -0.5
# Episode: 1, Step: 14201, Action: 2, Reward: 0.0
# Episode: 1, Step: 14202, Action: 2, Reward: -0.25
# Episode: 1, Step: 14203, Action: 2, Reward: 0.75
# Episode: 1, Step: 14204, Action: 2, Reward: 0.5
# Episode: 1, Step: 14205, Action: 2, Reward: 0.0
# Episode: 1, Step: 14206, Action: 2, Reward: -2.0
# Episode: 1, Step: 14207, Action: 2, Reward: 0.0
# Episode: 1, Step: 14208, Action: 2, Reward: 1.25
# Episode: 1, Step: 14209, Action: 2, Reward: 0.5
# Episode: 1, Step: 14210, Action: 2, Reward: 5.75
# Episode: 1, Step: 14211, Action: 2, Reward: 0.25
# Episode: 1, Step: 14212, Action: 2, Reward: -2.0
# Episode: 1, Step: 15502, Action: 2, Reward: 1.75
# Episode: 1, Step: 15503, Action: 2, Reward: 5.0
# Episode: 1, Step: 15504, Action: 2, Reward: 0.0
# Episode: 1, Step: 15505, Action: 2, Reward: 4.75
# Episode: 1, Step: 15506, Action: 2, Reward: -7.25
# Episode: 1, Step: 15507, Action: 2, Reward: -3.5
# Episode: 1, Step: 15508, Action: 2, Reward: 3.0
# Episode: 1, Step: 15509, Action: 2, Reward: -4.5
# Episode: 1, Step: 15510, Action: 2, Reward: 2.25
# Episode: 1, Step: 15511, Action: 2, Reward: -2.25
# Episode: 1, Step: 15512, Action: 1, Reward: 4.5
# Episode: 1, Step: 15513, Action: 1, Reward: 7.0
# Episode: 1, Step: 15514, Action: 1, Reward: -2.75
# Episode: 1, Step: 15515, Action: 2, Reward: 6.5
# Episode: 1, Step: 15516, Action: 0, Reward: 0
# Episode: 1, Step: 15517, Action: 1, Reward: -1.5
# Episode: 1, Step: 15518, Action: 1, Reward: 2.5
# Episode: 1, Step: 15519, Action: 2, Reward: -0.5
# Episode: 1, Step: 15520, Action: 0, Reward: 0
# Episode: 1, Step: 15521, Action: 1, Reward: -4.0
# Episode: 1, Step: 15522, Action: 1, Reward: -8.0
# Episode: 1, Step: 15523, Action: 0, Reward: 0
# Episode: 1, Step: 15524, Action: 1, Reward: -1.75
# Episode: 1, Step: 15525, Action: 1, Reward: -9.25
# Episode: 1, Step: 15526, Action: 1, Reward: -10.75
# Episode: 1, Step: 15527, Action: 1, Reward: 7.5
# Episode: 1, Step: 15528, Action: 1, Reward: -5.25
# Episode: 1, Step: 15529, Action: 1, Reward: -5.75
# Episode: 1, Step: 15530, Action: 1, Reward: 5.75
# Episode: 1, Step: 15531, Action: 1, Reward: 5.0
# Episode: 1, Step: 15532, Action: 1, Reward: 0.75
# Episode: 1, Step: 16822, Action: 2, Reward: 1.0
# Episode: 1, Step: 16823, Action: 2, Reward: -3.0
# Episode: 1, Step: 16824, Action: 2, Reward: -5.5
# Episode: 1, Step: 16825, Action: 2, Reward: -0.25
# Episode: 1, Step: 16826, Action: 2, Reward: -5.25
# Episode: 1, Step: 16827, Action: 2, Reward: -8.0
# Episode: 1, Step: 16828, Action: 2, Reward: 1.5
# Episode: 1, Step: 16829, Action: 2, Reward: -4.25
# Episode: 1, Step: 16830, Action: 2, Reward: -4.5
# Episode: 1, Step: 16831, Action: 2, Reward: 2.5
# Episode: 1, Step: 16832, Action: 2, Reward: -0.25
# Episode: 1, Step: 16833, Action: 2, Reward: -5.25
# Episode: 1, Step: 16834, Action: 2, Reward: 1.5
# Episode: 1, Step: 16835, Action: 2, Reward: 0.75
# Episode: 1, Step: 16836, Action: 2, Reward: -2.5
# Episode: 1, Step: 16837, Action: 2, Reward: -6.0
# Episode: 1, Step: 16838, Action: 2, Reward: 1.75
# Episode: 1, Step: 16839, Action: 2, Reward: 0.5
# Episode: 1, Step: 16840, Action: 2, Reward: 2.5
# Episode: 1, Step: 16841, Action: 2, Reward: 9.0
# Episode: 1, Step: 16842, Action: 2, Reward: -3.75
# Episode: 1, Step: 16843, Action: 2, Reward: 4.25
# Episode: 1, Step: 16844, Action: 2, Reward: -7.75
# Episode: 1, Step: 16845, Action: 2, Reward: -5.5
# Episode: 1, Step: 16846, Action: 2, Reward: -6.25
# Episode: 1, Step: 16847, Action: 2, Reward: -1.0
# Episode: 1, Step: 16848, Action: 2, Reward: 4.25
# Episode: 1, Step: 16849, Action: 1, Reward: 1.25
# Episode: 1, Step: 16850, Action: 2, Reward: -3.0
# Episode: 1, Step: 16851, Action: 2, Reward: 6.75
# Episode: 1, Step: 16852, Action: 0, Reward: 0
# Episode: 1, Step: 18140, Action: 0, Reward: 0
# Episode: 1, Step: 18141, Action: 2, Reward: 0.5
# Episode: 1, Step: 18142, Action: 2, Reward: 1.75
# Episode: 1, Step: 18143, Action: 2, Reward: 3.25
# Episode: 1, Step: 18144, Action: 1, Reward: 1.0
# Episode: 1, Step: 18145, Action: 2, Reward: 6.5
# Episode: 1, Step: 18146, Action: 2, Reward: 1.0
# Episode: 1, Step: 18147, Action: 2, Reward: -4.25
# Episode: 1, Step: 18148, Action: 2, Reward: -2.25
# Episode: 1, Step: 18149, Action: 2, Reward: 4.5
# Episode: 1, Step: 18150, Action: 2, Reward: 9.75
# Episode: 1, Step: 18151, Action: 2, Reward: -3.5
# Episode: 1, Step: 18152, Action: 2, Reward: -2.75
# Episode: 1, Step: 18153, Action: 2, Reward: -2.0
# Episode: 1, Step: 18154, Action: 0, Reward: 0
# Episode: 1, Step: 18155, Action: 2, Reward: 2.5
# Episode: 1, Step: 18156, Action: 2, Reward: 6.75
# Episode: 1, Step: 18157, Action: 2, Reward: -6.0
# Episode: 1, Step: 18158, Action: 2, Reward: -0.75
# Episode: 1, Step: 18159, Action: 2, Reward: 0.5
# Episode: 1, Step: 18160, Action: 2, Reward: 1.25
# Episode: 1, Step: 18161, Action: 2, Reward: -1.75
# Episode: 1, Step: 18162, Action: 2, Reward: -3.75
# Episode: 1, Step: 18163, Action: 2, Reward: 10.0
# Episode: 1, Step: 18164, Action: 2, Reward: -3.0
# Episode: 1, Step: 18165, Action: 2, Reward: -0.25
# Episode: 1, Step: 18166, Action: 2, Reward: -3.5
# Episode: 1, Step: 18167, Action: 2, Reward: -0.5
# Episode: 1, Step: 18168, Action: 2, Reward: 9.0
# Episode: 1, Step: 18169, Action: 2, Reward: -5.25
# Episode: 1, Step: 18170, Action: 2, Reward: 3.25
# Episode: 1, Step: 19339, Action: 2, Reward: 3.25
# Episode: 1, Step: 19340, Action: 2, Reward: 0.75
# Episode: 1, Step: 19341, Action: 2, Reward: -4.75
# Episode: 1, Step: 19342, Action: 2, Reward: 9.25
# Episode: 1, Step: 19343, Action: 2, Reward: 2.5
# Episode: 1, Step: 19344, Action: 2, Reward: -3.75
# Episode: 1, Step: 19345, Action: 2, Reward: -1.0
# Episode: 1, Step: 19346, Action: 2, Reward: -8.25
# Episode: 1, Step: 19347, Action: 2, Reward: -8.5
# Episode: 1, Step: 19348, Action: 2, Reward: -0.75
# Episode: 1, Step: 19349, Action: 2, Reward: 0.75
# Episode: 1, Step: 19350, Action: 2, Reward: -0.75
# Episode: 1, Step: 19351, Action: 2, Reward: 1.75
# Episode: 1, Step: 19352, Action: 2, Reward: -1.25
# Episode: 1, Step: 19353, Action: 2, Reward: -0.5
# Episode: 1, Step: 19354, Action: 2, Reward: -6.0
# Episode: 1, Step: 19355, Action: 2, Reward: 3.25
# Episode: 1, Step: 19356, Action: 2, Reward: -3.0
# Episode: 1, Step: 19357, Action: 2, Reward: 3.0
# Episode: 1, Step: 19358, Action: 0, Reward: 0
# Episode: 1, Step: 19359, Action: 2, Reward: -2.75
# Episode: 1, Step: 19360, Action: 2, Reward: 0.5
# Episode: 1, Step: 19361, Action: 2, Reward: 0.0
# Episode: 1, Step: 19362, Action: 2, Reward: 0.5
# Episode: 1, Step: 19363, Action: 2, Reward: 2.25
# Episode: 1, Step: 19364, Action: 2, Reward: -5.75
# Episode: 1, Step: 19365, Action: 2, Reward: 1.5
# Episode: 1, Step: 19366, Action: 2, Reward: 4.5
# Episode: 1, Step: 19367, Action: 2, Reward: -1.75
# Episode: 1, Step: 19368, Action: 2, Reward: 2.0
# Episode: 1, Step: 19369, Action: 2, Reward: -14.0
# Episode: 1, Step: 20658, Action: 2, Reward: -3.25
# Episode: 1, Step: 20659, Action: 2, Reward: -5.5
# Episode: 1, Step: 20660, Action: 2, Reward: -4.5
# Episode: 1, Step: 20661, Action: 2, Reward: 3.75
# Episode: 1, Step: 20662, Action: 2, Reward: -1.75
# Episode: 1, Step: 20663, Action: 2, Reward: -1.0
# Episode: 1, Step: 20664, Action: 2, Reward: -0.25
# Episode: 1, Step: 20665, Action: 2, Reward: 3.5
# Episode: 1, Step: 20666, Action: 2, Reward: 2.0
# Episode: 1, Step: 20667, Action: 2, Reward: -4.25
# Episode: 1, Step: 20668, Action: 2, Reward: 3.25
# Episode: 1, Step: 20669, Action: 0, Reward: 0
# Episode: 1, Step: 20670, Action: 2, Reward: 4.25
# Episode: 1, Step: 20671, Action: 2, Reward: -4.0
# Episode: 1, Step: 20672, Action: 2, Reward: 4.75
# Episode: 1, Step: 20673, Action: 2, Reward: 3.5
# Episode: 1, Step: 20674, Action: 2, Reward: 0.75
# Episode: 1, Step: 20675, Action: 0, Reward: 0
# Episode: 1, Step: 20676, Action: 2, Reward: 1.0
# Episode: 1, Step: 20677, Action: 2, Reward: 2.75
# Episode: 1, Step: 20678, Action: 2, Reward: -3.0
# Episode: 1, Step: 20679, Action: 2, Reward: -3.75
# Episode: 1, Step: 20680, Action: 2, Reward: -1.25
# Episode: 1, Step: 20681, Action: 2, Reward: -0.75
# Episode: 1, Step: 20682, Action: 2, Reward: 0.0
# Episode: 1, Step: 20683, Action: 2, Reward: -1.0
# Episode: 1, Step: 20684, Action: 2, Reward: -5.5
# Episode: 1, Step: 20685, Action: 2, Reward: -3.75
# Episode: 1, Step: 20686, Action: 2, Reward: 5.75
# Episode: 1, Step: 20687, Action: 1, Reward: -0.75
# Episode: 1, Step: 20688, Action: 2, Reward: 2.0
# Episode: 1, Step: 21977, Action: 2, Reward: 3.0
# Episode: 1, Step: 21978, Action: 2, Reward: 3.25
# Episode: 1, Step: 21979, Action: 0, Reward: 0
# Episode: 1, Step: 21980, Action: 2, Reward: 3.25
# Episode: 1, Step: 21981, Action: 2, Reward: 3.5
# Episode: 1, Step: 21982, Action: 2, Reward: -3.5
# Episode: 1, Step: 21983, Action: 2, Reward: 2.5
# Episode: 1, Step: 21984, Action: 2, Reward: 2.25
# Episode: 1, Step: 21985, Action: 2, Reward: 0.0
# Episode: 1, Step: 21986, Action: 2, Reward: -0.75
# Episode: 1, Step: 21987, Action: 2, Reward: 5.0
# Episode: 1, Step: 21988, Action: 2, Reward: -3.75
# Episode: 1, Step: 21989, Action: 2, Reward: 1.5
# Episode: 1, Step: 21990, Action: 2, Reward: 1.25
# Episode: 1, Step: 21991, Action: 2, Reward: 4.0
# Episode: 1, Step: 21992, Action: 2, Reward: 1.5
# Episode: 1, Step: 21993, Action: 2, Reward: -3.5
# Episode: 1, Step: 21994, Action: 2, Reward: 1.25
# Episode: 1, Step: 21995, Action: 2, Reward: -0.25
# Episode: 1, Step: 21996, Action: 2, Reward: 3.25
# Episode: 1, Step: 21997, Action: 2, Reward: 0.25
# Episode: 1, Step: 21998, Action: 2, Reward: 3.25
# Episode: 1, Step: 21999, Action: 2, Reward: -5.0
# Episode: 1, Step: 22000, Action: 2, Reward: -3.5
# Episode: 1, Step: 22001, Action: 2, Reward: -3.5
# Episode: 1, Step: 22002, Action: 2, Reward: 3.25
# Episode: 1, Step: 22003, Action: 2, Reward: -3.5
# Episode: 1, Step: 22004, Action: 2, Reward: 0.5
# Episode: 1, Step: 22005, Action: 2, Reward: -4.0
# Episode: 1, Step: 22006, Action: 2, Reward: -3.5
# Episode: 1, Step: 22007, Action: 2, Reward: 7.25
# Episode: 1, Step: 23295, Action: 2, Reward: 13.0
# Episode: 1, Step: 23296, Action: 2, Reward: -1.0
# Episode: 1, Step: 23297, Action: 2, Reward: -10.0
# Episode: 1, Step: 23298, Action: 2, Reward: -8.5
# Episode: 1, Step: 23299, Action: 0, Reward: 0
# Episode: 1, Step: 23300, Action: 2, Reward: 6.0
# Episode: 1, Step: 23301, Action: 2, Reward: -1.25
# Episode: 1, Step: 23302, Action: 2, Reward: 16.75
# Episode: 1, Step: 23303, Action: 2, Reward: 2.25
# Episode: 1, Step: 23304, Action: 2, Reward: 5.5
# Episode: 1, Step: 23305, Action: 2, Reward: -3.0
# Episode: 1, Step: 23306, Action: 2, Reward: -2.75
# Episode: 1, Step: 23307, Action: 1, Reward: -5.25
# Episode: 1, Step: 23308, Action: 2, Reward: -5.5
# Episode: 1, Step: 23309, Action: 2, Reward: 4.0
# Episode: 1, Step: 23310, Action: 2, Reward: 2.75
# Episode: 1, Step: 23311, Action: 2, Reward: -20.25
# Episode: 1, Step: 23312, Action: 2, Reward: -3.5
# Episode: 1, Step: 23313, Action: 2, Reward: 6.75
# Episode: 1, Step: 23314, Action: 2, Reward: 7.25
# Episode: 1, Step: 23315, Action: 2, Reward: -4.0
# Episode: 1, Step: 23316, Action: 2, Reward: -4.75
# Episode: 1, Step: 23317, Action: 2, Reward: -8.0
# Episode: 1, Step: 23318, Action: 2, Reward: -1.5
# Episode: 1, Step: 23319, Action: 2, Reward: 0.75
# Episode: 1, Step: 23320, Action: 2, Reward: -3.25
# Episode: 1, Step: 23321, Action: 2, Reward: -20.75
# Episode: 1, Step: 23322, Action: 2, Reward: -6.5
# Episode: 1, Step: 23323, Action: 2, Reward: 5.0
# Episode: 1, Step: 23324, Action: 2, Reward: 7.75
# Episode: 1, Step: 23325, Action: 0, Reward: 0
# Episode: 1, Step: 24610, Action: 2, Reward: -5.25
# Episode: 1, Step: 24611, Action: 1, Reward: 2.0
# Episode: 1, Step: 24612, Action: 2, Reward: -2.25
# Episode: 1, Step: 24613, Action: 2, Reward: -6.25
# Episode: 1, Step: 24614, Action: 2, Reward: -8.75
# Episode: 1, Step: 24615, Action: 2, Reward: 2.75
# Episode: 1, Step: 24616, Action: 2, Reward: 5.5
# Episode: 1, Step: 24617, Action: 2, Reward: 3.25
# Episode: 1, Step: 24618, Action: 2, Reward: -6.0
# Episode: 1, Step: 24619, Action: 2, Reward: 2.0
# Episode: 1, Step: 24620, Action: 2, Reward: -0.25
# Episode: 1, Step: 24621, Action: 2, Reward: -1.25
# Episode: 1, Step: 24622, Action: 2, Reward: 1.75
# Episode: 1, Step: 24623, Action: 2, Reward: 1.0
# Episode: 1, Step: 24624, Action: 2, Reward: 0.5
# Episode: 1, Step: 24625, Action: 2, Reward: 3.25
# Episode: 1, Step: 24626, Action: 2, Reward: 1.0
# Episode: 1, Step: 24627, Action: 2, Reward: -1.0
# Episode: 1, Step: 24628, Action: 2, Reward: 4.5
# Episode: 1, Step: 24629, Action: 2, Reward: 2.25
# Episode: 1, Step: 24630, Action: 2, Reward: -4.25
# Episode: 1, Step: 24631, Action: 2, Reward: -2.25
# Episode: 1, Step: 24632, Action: 2, Reward: -1.25
# Episode: 1, Step: 24633, Action: 2, Reward: 1.75
# Episode: 1, Step: 24634, Action: 2, Reward: -0.75
# Episode: 1, Step: 24635, Action: 2, Reward: 0.5
# Episode: 1, Step: 24636, Action: 2, Reward: 1.75
# Episode: 1, Step: 24637, Action: 2, Reward: -2.75
# Episode: 1, Step: 24638, Action: 2, Reward: 5.5
# Episode: 1, Step: 24639, Action: 2, Reward: 7.5
# Episode: 1, Step: 24640, Action: 2, Reward: -3.25
# Episode: 1, Step: 25809, Action: 2, Reward: 0.25
# Episode: 1, Step: 25810, Action: 2, Reward: -0.75
# Episode: 1, Step: 25811, Action: 2, Reward: -2.75
# Episode: 1, Step: 25812, Action: 2, Reward: 2.25
# Episode: 1, Step: 25813, Action: 2, Reward: -3.25
# Episode: 1, Step: 25814, Action: 2, Reward: -0.5
# Episode: 1, Step: 25815, Action: 2, Reward: 1.0
# Episode: 1, Step: 25816, Action: 2, Reward: 2.75
# Episode: 1, Step: 25817, Action: 2, Reward: -1.25
# Episode: 1, Step: 25818, Action: 2, Reward: -1.5
# Episode: 1, Step: 25819, Action: 2, Reward: 1.0
# Episode: 1, Step: 25820, Action: 2, Reward: -3.0
# Episode: 1, Step: 25821, Action: 2, Reward: 0.5
# Episode: 1, Step: 25822, Action: 2, Reward: 2.75
# Episode: 1, Step: 25823, Action: 2, Reward: -2.5
# Episode: 1, Step: 25824, Action: 2, Reward: 1.0
# Episode: 1, Step: 25825, Action: 2, Reward: -2.0
# Episode: 1, Step: 25826, Action: 2, Reward: 0.5
# Episode: 1, Step: 25827, Action: 2, Reward: 0.75
# Episode: 1, Step: 25828, Action: 2, Reward: 0.0
# Episode: 1, Step: 25829, Action: 2, Reward: 0.75
# Episode: 1, Step: 25830, Action: 2, Reward: -0.75
# Episode: 1, Step: 25831, Action: 2, Reward: -1.0
# Episode: 1, Step: 25832, Action: 2, Reward: -1.5
# Episode: 1, Step: 25833, Action: 2, Reward: 1.5
# Episode: 1, Step: 25834, Action: 2, Reward: -0.5
# Episode: 1, Step: 25835, Action: 2, Reward: -3.0
# Episode: 1, Step: 25836, Action: 2, Reward: -4.25
# Episode: 1, Step: 25837, Action: 2, Reward: 2.75
# Episode: 1, Step: 25838, Action: 2, Reward: -3.0
# Episode: 1, Step: 25839, Action: 2, Reward: 8.75
# Episode: 1, Step: 27127, Action: 2, Reward: -0.25
# Episode: 1, Step: 27128, Action: 2, Reward: -4.0
# Episode: 1, Step: 27129, Action: 2, Reward: -2.25
# Episode: 1, Step: 27130, Action: 2, Reward: 5.75
# Episode: 1, Step: 27131, Action: 2, Reward: -5.75
# Episode: 1, Step: 27132, Action: 2, Reward: 1.5
# Episode: 1, Step: 27133, Action: 2, Reward: 4.0
# Episode: 1, Step: 27134, Action: 2, Reward: -1.25
# Episode: 1, Step: 27135, Action: 2, Reward: -4.5
# Episode: 1, Step: 27136, Action: 2, Reward: -2.25
# Episode: 1, Step: 27137, Action: 2, Reward: 2.5
# Episode: 1, Step: 27138, Action: 2, Reward: -1.5
# Episode: 1, Step: 27139, Action: 2, Reward: 1.0
# Episode: 1, Step: 27140, Action: 2, Reward: -4.0
# Episode: 1, Step: 27141, Action: 2, Reward: 2.5
# Episode: 1, Step: 27142, Action: 2, Reward: -0.75
# Episode: 1, Step: 27143, Action: 2, Reward: -6.0
# Episode: 1, Step: 27144, Action: 2, Reward: 2.0
# Episode: 1, Step: 27145, Action: 0, Reward: 0
# Episode: 1, Step: 27146, Action: 2, Reward: -1.25
# Episode: 1, Step: 27147, Action: 2, Reward: 1.5
# Episode: 1, Step: 27148, Action: 2, Reward: 1.0
# Episode: 1, Step: 27149, Action: 2, Reward: -0.5
# Episode: 1, Step: 27150, Action: 2, Reward: -1.25
# Episode: 1, Step: 27151, Action: 2, Reward: -0.5
# Episode: 1, Step: 27152, Action: 2, Reward: 1.5
# Episode: 1, Step: 27153, Action: 1, Reward: 2.25
# Episode: 1, Step: 27154, Action: 2, Reward: -0.25
# Episode: 1, Step: 27155, Action: 2, Reward: 2.25
# Episode: 1, Step: 27156, Action: 1, Reward: -2.75
# Episode: 1, Step: 27157, Action: 1, Reward: 4.0
# Episode: 1, Step: 28446, Action: 2, Reward: 0.0
# Episode: 1, Step: 28447, Action: 2, Reward: -3.25
# Episode: 1, Step: 28448, Action: 2, Reward: 5.75
# Episode: 1, Step: 28449, Action: 0, Reward: 0
# Episode: 1, Step: 28450, Action: 2, Reward: -2.75
# Episode: 1, Step: 28451, Action: 0, Reward: 0
# Episode: 1, Step: 28452, Action: 2, Reward: -3.25
# Episode: 1, Step: 28453, Action: 2, Reward: -2.0
# Episode: 1, Step: 28454, Action: 0, Reward: 0
# Episode: 1, Step: 28455, Action: 2, Reward: 0.5
# Episode: 1, Step: 28456, Action: 2, Reward: 4.25
# Episode: 1, Step: 28457, Action: 2, Reward: -2.75
# Episode: 1, Step: 28458, Action: 2, Reward: -3.75
# Episode: 1, Step: 28459, Action: 2, Reward: 3.0
# Episode: 1, Step: 28460, Action: 2, Reward: 1.25
# Episode: 1, Step: 28461, Action: 2, Reward: 1.5
# Episode: 1, Step: 28462, Action: 2, Reward: 2.25
# Episode: 1, Step: 28463, Action: 2, Reward: 0.0
# Episode: 1, Step: 28464, Action: 0, Reward: 0
# Episode: 1, Step: 28465, Action: 2, Reward: -3.5
# Episode: 1, Step: 28466, Action: 2, Reward: -0.75
# Episode: 1, Step: 28467, Action: 2, Reward: 3.0
# Episode: 1, Step: 28468, Action: 2, Reward: 0.0
# Episode: 1, Step: 28469, Action: 2, Reward: -0.75
# Episode: 1, Step: 28470, Action: 2, Reward: -1.5
# Episode: 1, Step: 28471, Action: 2, Reward: -2.0
# Episode: 1, Step: 28472, Action: 2, Reward: -0.75
# Episode: 1, Step: 28473, Action: 2, Reward: -3.5
# Episode: 1, Step: 28474, Action: 2, Reward: -8.0
# Episode: 1, Step: 28475, Action: 2, Reward: -3.75
# Episode: 1, Step: 28476, Action: 2, Reward: -3.0
# Episode: 1, Step: 29762, Action: 2, Reward: 0.25
# Episode: 1, Step: 29763, Action: 2, Reward: 6.25
# Episode: 1, Step: 29764, Action: 2, Reward: 7.25
# Episode: 1, Step: 29765, Action: 2, Reward: 0.25
# Episode: 1, Step: 29766, Action: 2, Reward: 7.75
# Episode: 1, Step: 29767, Action: 2, Reward: -1.75
# Episode: 1, Step: 29768, Action: 2, Reward: 5.5
# Episode: 1, Step: 29769, Action: 2, Reward: -1.5
# Episode: 1, Step: 29770, Action: 2, Reward: 10.25
# Episode: 1, Step: 29771, Action: 2, Reward: -11.0
# Episode: 1, Step: 29772, Action: 1, Reward: -0.25
# Episode: 1, Step: 29773, Action: 2, Reward: 12.25
# Episode: 1, Step: 29774, Action: 2, Reward: -7.0
# Episode: 1, Step: 29775, Action: 2, Reward: -2.5
# Episode: 1, Step: 29776, Action: 2, Reward: -5.75
# Episode: 1, Step: 29777, Action: 0, Reward: 0
# Episode: 1, Step: 29778, Action: 1, Reward: -3.25
# Episode: 1, Step: 29779, Action: 2, Reward: -5.5
# Episode: 1, Step: 29780, Action: 2, Reward: 1.5
# Episode: 1, Step: 29781, Action: 2, Reward: -5.75
# Episode: 1, Step: 29782, Action: 2, Reward: -4.0
# Episode: 1, Step: 29783, Action: 2, Reward: -2.75
# Episode: 1, Step: 29784, Action: 2, Reward: 0.5
# Episode: 1, Step: 29785, Action: 2, Reward: 4.5
# Episode: 1, Step: 29786, Action: 2, Reward: -1.5
# Episode: 1, Step: 29787, Action: 2, Reward: 1.0
# Episode: 1, Step: 29788, Action: 2, Reward: -2.0
# Episode: 1, Step: 29789, Action: 2, Reward: 3.75
# Episode: 1, Step: 29790, Action: 1, Reward: 0.75
# Episode: 1, Step: 29791, Action: 2, Reward: 0.25
# Episode: 1, Step: 29792, Action: 2, Reward: -6.75
# Episode: 1, Step: 31081, Action: 2, Reward: 4.75
# Episode: 1, Step: 31082, Action: 2, Reward: 9.25
# Episode: 1, Step: 31083, Action: 2, Reward: -0.5
# Episode: 1, Step: 31084, Action: 2, Reward: 5.5
# Episode: 1, Step: 31085, Action: 1, Reward: -12.5
# Episode: 1, Step: 31086, Action: 2, Reward: 11.0
# Episode: 1, Step: 31087, Action: 2, Reward: -7.0
# Episode: 1, Step: 31088, Action: 2, Reward: -1.75
# Episode: 1, Step: 31089, Action: 2, Reward: -2.5
# Episode: 1, Step: 31090, Action: 2, Reward: -5.25
# Episode: 1, Step: 31091, Action: 2, Reward: -0.25
# Episode: 1, Step: 31092, Action: 2, Reward: -8.5
# Episode: 1, Step: 31093, Action: 2, Reward: -22.0
# Episode: 1, Step: 31094, Action: 2, Reward: -4.5
# Episode: 1, Step: 31095, Action: 2, Reward: 4.0
# Episode: 1, Step: 31096, Action: 2, Reward: -2.5
# Episode: 1, Step: 31097, Action: 2, Reward: 1.5
# Episode: 1, Step: 31098, Action: 2, Reward: 3.75
# Episode: 1, Step: 31099, Action: 2, Reward: 0.5
# Episode: 1, Step: 31100, Action: 2, Reward: -5.5
# Episode: 1, Step: 31101, Action: 2, Reward: 0.75
# Episode: 1, Step: 31102, Action: 2, Reward: -4.0
# Episode: 1, Step: 31103, Action: 2, Reward: 8.25
# Episode: 1, Step: 31104, Action: 2, Reward: -5.25
# Episode: 1, Step: 31105, Action: 2, Reward: -3.75
# Episode: 1, Step: 31106, Action: 2, Reward: -2.0
# Episode: 1, Step: 31107, Action: 2, Reward: -4.25
# Episode: 1, Step: 31108, Action: 2, Reward: -7.5
# Episode: 1, Step: 31109, Action: 2, Reward: 8.0
# Episode: 1, Step: 31110, Action: 2, Reward: 19.0
# Episode: 1, Step: 31111, Action: 2, Reward: -3.25
# Episode: 1, Step: 32272, Action: 2, Reward: -11.0
# Episode: 1, Step: 32273, Action: 2, Reward: -4.75
# Episode: 1, Step: 32274, Action: 2, Reward: -3.75
# Episode: 1, Step: 32275, Action: 1, Reward: 7.0
# Episode: 1, Step: 32276, Action: 2, Reward: 13.75
# Episode: 1, Step: 32277, Action: 2, Reward: 12.75
# Episode: 1, Step: 32278, Action: 2, Reward: -1.5
# Episode: 1, Step: 32279, Action: 2, Reward: 18.5
# Episode: 1, Step: 32280, Action: 2, Reward: 7.0
# Episode: 1, Step: 32281, Action: 2, Reward: 18.5
# Episode: 1, Step: 32282, Action: 2, Reward: -8.0
# Episode: 1, Step: 32283, Action: 2, Reward: 37.5
# Episode: 1, Step: 32284, Action: 2, Reward: 0.25
# Episode: 1, Step: 32285, Action: 2, Reward: -25.25
# Episode: 1, Step: 32286, Action: 1, Reward: 10.5
# Episode: 1, Step: 32287, Action: 1, Reward: 25.5
# Episode: 1, Step: 32288, Action: 1, Reward: 0.25
# Episode: 1, Step: 32289, Action: 2, Reward: 12.5
# Episode: 1, Step: 32290, Action: 2, Reward: 3.5
# Episode: 1, Step: 32291, Action: 2, Reward: -30.0
# Episode: 1, Step: 32292, Action: 2, Reward: 8.5
# Episode: 1, Step: 32293, Action: 2, Reward: -8.25
# Episode: 1, Step: 32294, Action: 2, Reward: -3.25
# Episode: 1, Step: 32295, Action: 2, Reward: 14.25
# Episode: 1, Step: 32296, Action: 2, Reward: 12.75
# Episode: 1, Step: 32297, Action: 1, Reward: 25.5
# Episode: 1, Step: 32298, Action: 1, Reward: -0.5
# Episode: 1, Step: 32299, Action: 1, Reward: 9.0
# Episode: 1, Step: 32300, Action: 1, Reward: 23.0
# Episode: 1, Step: 32301, Action: 1, Reward: 20.5
# Episode: 1, Step: 32302, Action: 1, Reward: -2.75
# Episode: 1, Step: 33590, Action: 2, Reward: -17.25
# Episode: 1, Step: 33591, Action: 2, Reward: -30.25
# Episode: 1, Step: 33592, Action: 2, Reward: 6.0
# Episode: 1, Step: 33593, Action: 2, Reward: -2.5
# Episode: 1, Step: 33594, Action: 2, Reward: 9.0
# Episode: 1, Step: 33595, Action: 2, Reward: -2.75
# Episode: 1, Step: 33596, Action: 2, Reward: -6.25
# Episode: 1, Step: 33597, Action: 2, Reward: -13.75
# Episode: 1, Step: 33598, Action: 2, Reward: 16.0
# Episode: 1, Step: 33599, Action: 2, Reward: -11.75
# Episode: 1, Step: 33600, Action: 2, Reward: 2.75
# Episode: 1, Step: 33601, Action: 2, Reward: -8.25
# Episode: 1, Step: 33602, Action: 2, Reward: -11.0
# Episode: 1, Step: 33603, Action: 2, Reward: 23.0
# Episode: 1, Step: 33604, Action: 2, Reward: 7.25
# Episode: 1, Step: 33605, Action: 2, Reward: 6.25
# Episode: 1, Step: 33606, Action: 0, Reward: 0
# Episode: 1, Step: 33607, Action: 2, Reward: 9.25
# Episode: 1, Step: 33608, Action: 2, Reward: -10.25
# Episode: 1, Step: 33609, Action: 2, Reward: -11.25
# Episode: 1, Step: 33610, Action: 2, Reward: -7.25
# Episode: 1, Step: 33611, Action: 2, Reward: -5.25
# Episode: 1, Step: 33612, Action: 2, Reward: -5.5
# Episode: 1, Step: 33613, Action: 2, Reward: 3.0
# Episode: 1, Step: 33614, Action: 2, Reward: -8.25
# Episode: 1, Step: 33615, Action: 2, Reward: 8.5
# Episode: 1, Step: 33616, Action: 2, Reward: -0.75
# Episode: 1, Step: 33617, Action: 2, Reward: 3.25
# Episode: 1, Step: 33618, Action: 2, Reward: 1.75
# Episode: 1, Step: 33619, Action: 2, Reward: 0.75
# Episode: 1, Step: 33620, Action: 2, Reward: -3.5
# Episode: 1, Step: 34909, Action: 2, Reward: 4.75
# Episode: 1, Step: 34910, Action: 2, Reward: -33.0
# Episode: 1, Step: 34911, Action: 2, Reward: -18.25
# Episode: 1, Step: 34912, Action: 1, Reward: -25.25
# Episode: 1, Step: 34913, Action: 2, Reward: 2.5
# Episode: 1, Step: 34914, Action: 2, Reward: -17.75
# Episode: 1, Step: 34915, Action: 0, Reward: 0
# Episode: 1, Step: 34916, Action: 2, Reward: 0.5
# Episode: 1, Step: 34917, Action: 2, Reward: -30.25
# Episode: 1, Step: 34918, Action: 2, Reward: 12.75
# Episode: 1, Step: 34919, Action: 2, Reward: 4.0
# Episode: 1, Step: 34920, Action: 2, Reward: 12.25
# Episode: 1, Step: 34921, Action: 2, Reward: -9.0
# Episode: 1, Step: 34922, Action: 2, Reward: 12.0
# Episode: 1, Step: 34923, Action: 2, Reward: -20.0
# Episode: 1, Step: 34924, Action: 2, Reward: -3.25
# Episode: 1, Step: 34925, Action: 2, Reward: 0.25
# Episode: 1, Step: 34926, Action: 2, Reward: 4.75
# Episode: 1, Step: 34927, Action: 2, Reward: 17.0
# Episode: 1, Step: 34928, Action: 2, Reward: -36.0
# Episode: 1, Step: 34929, Action: 2, Reward: 4.0
# Episode: 1, Step: 34930, Action: 2, Reward: -19.0
# Episode: 1, Step: 34931, Action: 2, Reward: 25.75
# Episode: 1, Step: 34932, Action: 2, Reward: -0.25
# Episode: 1, Step: 34933, Action: 2, Reward: 6.75
# Episode: 1, Step: 34934, Action: 2, Reward: 5.75
# Episode: 1, Step: 34935, Action: 2, Reward: 30.25
# Episode: 1, Step: 34936, Action: 2, Reward: -23.25
# Episode: 1, Step: 34937, Action: 2, Reward: -0.5
# Episode: 1, Step: 34938, Action: 2, Reward: 10.0
# Episode: 1, Step: 34939, Action: 2, Reward: -29.5
# Episode: 1, Step: 36287, Action: 1, Reward: -7.0
# Episode: 1, Step: 36288, Action: 2, Reward: -9.0
# Episode: 1, Step: 36289, Action: 2, Reward: 19.0
# Episode: 1, Step: 36290, Action: 2, Reward: 23.5
# Episode: 1, Step: 36291, Action: 2, Reward: -4.75
# Episode: 1, Step: 36292, Action: 2, Reward: -19.25
# Episode: 1, Step: 36293, Action: 2, Reward: 4.5
# Episode: 1, Step: 36294, Action: 2, Reward: -1.75
# Episode: 1, Step: 36295, Action: 1, Reward: -47.5
# Episode: 1, Step: 36296, Action: 2, Reward: -14.25
# Episode: 1, Step: 36297, Action: 2, Reward: 6.75
# Episode: 1, Step: 36298, Action: 2, Reward: 23.5
# Episode: 1, Step: 36299, Action: 2, Reward: -29.25
# Episode: 1, Step: 36300, Action: 2, Reward: 0.0
# Episode: 1, Step: 36301, Action: 1, Reward: -14.0
# Episode: 1, Step: 36302, Action: 2, Reward: 29.5
# Episode: 1, Step: 36303, Action: 2, Reward: -16.75
# Episode: 1, Step: 36304, Action: 2, Reward: 2.25
# Episode: 1, Step: 36305, Action: 2, Reward: 49.5
# Episode: 1, Step: 36306, Action: 2, Reward: 21.25
# Episode: 1, Step: 36307, Action: 2, Reward: -24.75
# Episode: 1, Step: 36308, Action: 2, Reward: 7.0
# Episode: 1, Step: 36309, Action: 2, Reward: -3.25
# Episode: 1, Step: 36310, Action: 2, Reward: -38.75
# Episode: 1, Step: 36311, Action: 2, Reward: -8.25
# Episode: 1, Step: 36312, Action: 2, Reward: -33.0
# Episode: 1, Step: 36313, Action: 0, Reward: 0
# Episode: 1, Step: 36314, Action: 2, Reward: 4.75
# Episode: 1, Step: 36315, Action: 2, Reward: -4.5
# Episode: 1, Step: 36316, Action: 2, Reward: 0.0
# Episode: 1, Step: 36317, Action: 2, Reward: -34.25
# Episode: 1, Step: 37666, Action: 2, Reward: -3.0
# Episode: 1, Step: 37667, Action: 2, Reward: -11.0
# Episode: 1, Step: 37668, Action: 2, Reward: -22.5
# Episode: 1, Step: 37669, Action: 2, Reward: -13.25
# Episode: 1, Step: 37670, Action: 2, Reward: 19.75
# Episode: 1, Step: 37671, Action: 2, Reward: -17.5
# Episode: 1, Step: 37672, Action: 2, Reward: 27.25
# Episode: 1, Step: 37673, Action: 2, Reward: -37.25
# Episode: 1, Step: 37674, Action: 2, Reward: 15.75
# Episode: 1, Step: 37675, Action: 2, Reward: -19.0
# Episode: 1, Step: 37676, Action: 2, Reward: -13.0
# Episode: 1, Step: 37677, Action: 2, Reward: 32.75
# Episode: 1, Step: 37678, Action: 2, Reward: 9.0
# Episode: 1, Step: 37679, Action: 2, Reward: 10.75
# Episode: 1, Step: 37680, Action: 2, Reward: -8.0
# Episode: 1, Step: 37681, Action: 2, Reward: 21.75
# Episode: 1, Step: 37682, Action: 2, Reward: -4.25
# Episode: 1, Step: 37683, Action: 2, Reward: 17.75
# Episode: 1, Step: 37684, Action: 2, Reward: -6.75
# Episode: 1, Step: 37685, Action: 0, Reward: 0
# Episode: 1, Step: 37686, Action: 2, Reward: 35.25
# Episode: 1, Step: 37687, Action: 2, Reward: -14.5
# Episode: 1, Step: 37688, Action: 2, Reward: 3.5
# Episode: 1, Step: 37689, Action: 2, Reward: -26.75
# Episode: 1, Step: 37690, Action: 2, Reward: 6.25
# Episode: 1, Step: 37691, Action: 2, Reward: -10.5
# Episode: 1, Step: 37692, Action: 2, Reward: 16.75
# Episode: 1, Step: 37693, Action: 2, Reward: 30.75
# Episode: 1, Step: 37694, Action: 2, Reward: 4.0
# Episode: 1, Step: 37695, Action: 2, Reward: -4.75
# Episode: 1, Step: 37696, Action: 2, Reward: 5.0
# Episode: 1, Step: 39045, Action: 2, Reward: -2.0
# Episode: 1, Step: 39046, Action: 2, Reward: -22.0
# Episode: 1, Step: 39047, Action: 2, Reward: 26.0
# Episode: 1, Step: 39048, Action: 2, Reward: -17.75
# Episode: 1, Step: 39049, Action: 2, Reward: 1.5
# Episode: 1, Step: 39050, Action: 2, Reward: -16.0
# Episode: 1, Step: 39051, Action: 2, Reward: 10.5
# Episode: 1, Step: 39052, Action: 2, Reward: 14.0
# Episode: 1, Step: 39053, Action: 2, Reward: -6.5
# Episode: 1, Step: 39054, Action: 2, Reward: 11.5
# Episode: 1, Step: 39055, Action: 2, Reward: 14.0
# Episode: 1, Step: 39056, Action: 2, Reward: 12.25
# Episode: 1, Step: 39057, Action: 2, Reward: 4.5
# Episode: 1, Step: 39058, Action: 2, Reward: 16.0
# Episode: 1, Step: 39059, Action: 2, Reward: 4.0
# Episode: 1, Step: 39060, Action: 2, Reward: 23.0
# Episode: 1, Step: 39061, Action: 2, Reward: -5.25
# Episode: 1, Step: 39062, Action: 2, Reward: 14.5
# Episode: 1, Step: 39063, Action: 2, Reward: -8.75
# Episode: 1, Step: 39064, Action: 2, Reward: 13.25
# Episode: 1, Step: 39065, Action: 2, Reward: -4.5
# Episode: 1, Step: 39066, Action: 2, Reward: -30.5
# Episode: 1, Step: 39067, Action: 2, Reward: 1.75
# Episode: 1, Step: 39068, Action: 2, Reward: 14.25
# Episode: 1, Step: 39069, Action: 2, Reward: -6.0
# Episode: 1, Step: 39070, Action: 2, Reward: -6.0
# Episode: 1, Step: 39071, Action: 2, Reward: 7.75
# Episode: 1, Step: 39072, Action: 2, Reward: 17.0
# Episode: 1, Step: 39073, Action: 2, Reward: 13.25
# Episode: 1, Step: 39074, Action: 2, Reward: -10.0
# Episode: 1, Step: 39075, Action: 2, Reward: 7.75
# Episode: 1, Step: 40424, Action: 2, Reward: 2.5
# Episode: 1, Step: 40425, Action: 2, Reward: -21.25
# Episode: 1, Step: 40426, Action: 2, Reward: -14.25
# Episode: 1, Step: 40427, Action: 2, Reward: 3.25
# Episode: 1, Step: 40428, Action: 2, Reward: -13.0
# Episode: 1, Step: 40429, Action: 2, Reward: 1.5
# Episode: 1, Step: 40430, Action: 2, Reward: 13.0
# Episode: 1, Step: 40431, Action: 2, Reward: -10.5
# Episode: 1, Step: 40432, Action: 2, Reward: -1.0
# Episode: 1, Step: 40433, Action: 2, Reward: 4.0
# Episode: 1, Step: 40434, Action: 2, Reward: 8.5
# Episode: 1, Step: 40435, Action: 2, Reward: -1.75
# Episode: 1, Step: 40436, Action: 2, Reward: 12.75
# Episode: 1, Step: 40437, Action: 2, Reward: -8.75
# Episode: 1, Step: 40438, Action: 1, Reward: 6.25
# Episode: 1, Step: 40439, Action: 2, Reward: -9.5
# Episode: 1, Step: 40440, Action: 2, Reward: -17.5
# Episode: 1, Step: 40441, Action: 0, Reward: 0
# Episode: 1, Step: 40442, Action: 2, Reward: -0.5
# Episode: 1, Step: 40443, Action: 1, Reward: -2.25
# Episode: 1, Step: 40444, Action: 2, Reward: -24.25
# Episode: 1, Step: 40445, Action: 2, Reward: 7.25
# Episode: 1, Step: 40446, Action: 1, Reward: 6.25
# ...
# Episode: 7, Step: 48691, Action: 2, Reward: -1.25
# Episode: 7, Step: 48692, Action: 2, Reward: 10.5
# Episode: 7, Step: 48693, Action: 2, Reward: -3.75
# Episode: 7, Step: 48694, Action: 2, Reward: 8.5
# Episode: 7, Step: 48695, Action: 2, Reward: 6.75
# Episode: 7, Step: 48696, Action: 2, Reward: -12.25
# Episode: 7, Step: 48697, Action: 2, Reward: -10.25
# Episode: 7, Step: 48698, Action: 2, Reward: 11.0
# Episode: 7, Step: 48699, Action: 2, Reward: -7.5
# Episode: 7, Step: 48700, Action: 2, Reward: -10.0
# Episode: 7, Step: 48701, Action: 2, Reward: -5.5
# Episode: 7, Step: 48702, Action: 2, Reward: -2.25
# Episode: 7, Step: 48703, Action: 2, Reward: 11.0
# Episode: 7, Step: 48704, Action: 2, Reward: 8.75
# Episode: 7, Step: 48705, Action: 2, Reward: -23.25
# Episode: 7, Step: 48706, Action: 2, Reward: -3.0
# Episode: 7, Step: 48707, Action: 2, Reward: -9.0
# Episode: 7, Step: 48708, Action: 2, Reward: 16.25
# Episode: 7, Step: 48709, Action: 0, Reward: 0
# Episode: 7, Step: 48710, Action: 2, Reward: 2.25
# Episode: 7, Step: 48711, Action: 2, Reward: -4.75
# Episode: 7, Step: 48712, Action: 1, Reward: 9.0
# Episode: 7, Step: 48713, Action: 2, Reward: 11.75
# Episode: 7, Step: 48714, Action: 2, Reward: -1.0
# Episode: 7, Step: 48715, Action: 2, Reward: -10.5
# Episode: 7, Step: 48716, Action: 2, Reward: -2.0
# Episode: 7, Step: 48717, Action: 2, Reward: -2.25
# Episode: 7, Step: 48718, Action: 2, Reward: -10.25
# Episode: 7, Step: 48719, Action: 2, Reward: 5.5
# Episode: 7, Step: 48720, Action: 2, Reward: -6.5
# Episode: 7, Step: 50067, Action: 2, Reward: -2.5
# Episode: 7, Step: 50068, Action: 2, Reward: -25.75
# Episode: 7, Step: 50069, Action: 2, Reward: 22.75
# Episode: 7, Step: 50070, Action: 2, Reward: 6.5
# Episode: 7, Step: 50071, Action: 2, Reward: -2.25
# Episode: 7, Step: 50072, Action: 2, Reward: -5.25
# Episode: 7, Step: 50073, Action: 2, Reward: 13.5
# Episode: 7, Step: 50074, Action: 2, Reward: -13.5
# Episode: 7, Step: 50075, Action: 2, Reward: 0.5
# Episode: 7, Step: 50076, Action: 2, Reward: 17.75
# Episode: 7, Step: 50077, Action: 2, Reward: -3.25
# Episode: 7, Step: 50078, Action: 2, Reward: -9.5
# Episode: 7, Step: 50079, Action: 2, Reward: -7.5
# Episode: 7, Step: 50080, Action: 2, Reward: 5.5
# Episode: 7, Step: 50081, Action: 2, Reward: 16.25
# Episode: 7, Step: 50082, Action: 2, Reward: -7.75
# Episode: 7, Step: 50083, Action: 2, Reward: 2.25
# Episode: 7, Step: 50084, Action: 2, Reward: 13.0
# Episode: 7, Step: 50085, Action: 2, Reward: -5.0
# Episode: 7, Step: 50086, Action: 2, Reward: -13.75
# Episode: 7, Step: 50087, Action: 2, Reward: 13.75
# Episode: 7, Step: 50088, Action: 2, Reward: 15.0
# Episode: 7, Step: 50089, Action: 2, Reward: -9.75
# Episode: 7, Step: 50090, Action: 0, Reward: 0
# Episode: 7, Step: 50091, Action: 2, Reward: -20.0
# Episode: 7, Step: 50092, Action: 2, Reward: -8.25
# Episode: 7, Step: 50093, Action: 2, Reward: -2.0
# Episode: 7, Step: 50094, Action: 2, Reward: -12.25
# Episode: 7, Step: 50095, Action: 2, Reward: 5.0
# Episode: 7, Step: 50096, Action: 2, Reward: 12.25
# Episode: 7, Step: 50097, Action: 2, Reward: 10.0
# Episode: 7, Step: 51446, Action: 2, Reward: -6.5
# Episode: 7, Step: 51447, Action: 2, Reward: 15.0
# Episode: 7, Step: 51448, Action: 2, Reward: 20.5
# Episode: 7, Step: 51449, Action: 2, Reward: -1.5
# Episode: 7, Step: 51450, Action: 2, Reward: 10.5
# Episode: 7, Step: 51451, Action: 2, Reward: -4.75
# Episode: 7, Step: 51452, Action: 2, Reward: -14.25
# Episode: 7, Step: 51453, Action: 2, Reward: -1.75
# Episode: 7, Step: 51454, Action: 1, Reward: -4.75
# Episode: 7, Step: 51455, Action: 2, Reward: -0.25
# Episode: 7, Step: 51456, Action: 2, Reward: -8.5
# Episode: 7, Step: 51457, Action: 1, Reward: 4.0
# Episode: 7, Step: 51458, Action: 2, Reward: 3.5
# Episode: 7, Step: 51459, Action: 2, Reward: 8.0
# Episode: 7, Step: 51460, Action: 2, Reward: 2.5
# Episode: 7, Step: 51461, Action: 2, Reward: 3.5
# Episode: 7, Step: 51462, Action: 2, Reward: -8.5
# Episode: 7, Step: 51463, Action: 2, Reward: -8.75
# Episode: 7, Step: 51464, Action: 2, Reward: -2.0
# Episode: 7, Step: 51465, Action: 2, Reward: -15.5
# Episode: 7, Step: 51466, Action: 2, Reward: 3.25
# Episode: 7, Step: 51467, Action: 2, Reward: 0.5
# Episode: 7, Step: 51468, Action: 1, Reward: -4.5
# Episode: 7, Step: 51469, Action: 2, Reward: 14.0
# Episode: 7, Step: 51470, Action: 2, Reward: -9.5
# Episode: 7, Step: 51471, Action: 2, Reward: -14.75
# Episode: 7, Step: 51472, Action: 2, Reward: -4.5
# Episode: 7, Step: 51473, Action: 2, Reward: 7.5
# Episode: 7, Step: 51474, Action: 2, Reward: 17.0
# Episode: 7, Step: 51475, Action: 2, Reward: -4.0
# Episode: 7, Step: 51476, Action: 2, Reward: -17.5
# Episode: 7, Step: 52823, Action: 2, Reward: 7.0
# Episode: 7, Step: 52824, Action: 2, Reward: -5.0
# Episode: 7, Step: 52825, Action: 2, Reward: 8.0
# Episode: 7, Step: 52826, Action: 2, Reward: -18.0
# Episode: 7, Step: 52827, Action: 2, Reward: -16.25
# Episode: 7, Step: 52828, Action: 2, Reward: 1.5
# Episode: 7, Step: 52829, Action: 2, Reward: 16.25
# Episode: 7, Step: 52830, Action: 2, Reward: -2.25
# Episode: 7, Step: 52831, Action: 2, Reward: -19.25
# Episode: 7, Step: 52832, Action: 0, Reward: 0
# Episode: 7, Step: 52833, Action: 2, Reward: 0.25
# Episode: 7, Step: 52834, Action: 2, Reward: -0.5
# Episode: 7, Step: 52835, Action: 2, Reward: 15.75
# Episode: 7, Step: 52836, Action: 2, Reward: 6.0
# Episode: 7, Step: 52837, Action: 2, Reward: 9.75
# Episode: 7, Step: 52838, Action: 2, Reward: -5.75
# Episode: 7, Step: 52839, Action: 2, Reward: 16.0
# Episode: 7, Step: 52840, Action: 2, Reward: -2.0
# Episode: 7, Step: 52841, Action: 2, Reward: 1.0
# Episode: 7, Step: 52842, Action: 2, Reward: 7.25
# Episode: 7, Step: 52843, Action: 2, Reward: 2.75
# Episode: 7, Step: 52844, Action: 2, Reward: 0.75
# Episode: 7, Step: 52845, Action: 2, Reward: -4.5
# Episode: 7, Step: 52846, Action: 2, Reward: -10.75
# Episode: 7, Step: 52847, Action: 2, Reward: 3.5
# Episode: 7, Step: 52848, Action: 2, Reward: 22.25
# Episode: 7, Step: 52849, Action: 2, Reward: -11.75
# Episode: 7, Step: 52850, Action: 2, Reward: 2.25
# Episode: 7, Step: 52851, Action: 2, Reward: -3.0
# Episode: 7, Step: 52852, Action: 2, Reward: 5.75
# Episode: 7, Step: 52853, Action: 2, Reward: 1.0
# Episode: 7, Step: 54202, Action: 2, Reward: -11.75
# Episode: 7, Step: 54203, Action: 2, Reward: 9.75
# Episode: 7, Step: 54204, Action: 2, Reward: -2.25
# Episode: 7, Step: 54205, Action: 2, Reward: 4.5
# Episode: 7, Step: 54206, Action: 2, Reward: -23.25
# Episode: 7, Step: 54207, Action: 2, Reward: 17.5
# Episode: 7, Step: 54208, Action: 2, Reward: 6.25
# Episode: 7, Step: 54209, Action: 2, Reward: 0.5
# Episode: 7, Step: 54210, Action: 2, Reward: 20.0
# Episode: 7, Step: 54211, Action: 2, Reward: 11.0
# Episode: 7, Step: 54212, Action: 2, Reward: 6.5
# Episode: 7, Step: 54213, Action: 2, Reward: 15.75
# Episode: 7, Step: 54214, Action: 2, Reward: -25.25
# Episode: 7, Step: 54215, Action: 2, Reward: 9.0
# Episode: 7, Step: 54216, Action: 2, Reward: -3.5
# Episode: 7, Step: 54217, Action: 2, Reward: -1.5
# Episode: 7, Step: 54218, Action: 2, Reward: 24.75
# Episode: 7, Step: 54219, Action: 2, Reward: -5.75
# Episode: 7, Step: 54220, Action: 2, Reward: -7.5
# Episode: 7, Step: 54221, Action: 2, Reward: -31.25
# Episode: 7, Step: 54222, Action: 2, Reward: -1.5
# Episode: 7, Step: 54223, Action: 2, Reward: -18.5
# Episode: 7, Step: 54224, Action: 2, Reward: 4.5
# Episode: 7, Step: 54225, Action: 2, Reward: -25.25
# Episode: 7, Step: 54226, Action: 2, Reward: -19.0
# Episode: 7, Step: 54227, Action: 2, Reward: 1.75
# Episode: 7, Step: 54228, Action: 2, Reward: -11.75
# Episode: 7, Step: 54229, Action: 2, Reward: 13.25
# Episode: 7, Step: 54230, Action: 2, Reward: 11.25
# Episode: 7, Step: 54231, Action: 2, Reward: -7.25
# Episode: 7, Step: 54232, Action: 2, Reward: 3.25
# Episode: 7, Step: 55580, Action: 2, Reward: -6.75
# Episode: 7, Step: 55581, Action: 2, Reward: -28.25
# Episode: 7, Step: 55582, Action: 2, Reward: 5.75
# Episode: 7, Step: 55583, Action: 2, Reward: 5.75
# Episode: 7, Step: 55584, Action: 2, Reward: -4.0
# Episode: 7, Step: 55585, Action: 2, Reward: 16.75
# Episode: 7, Step: 55586, Action: 2, Reward: 8.5
# Episode: 7, Step: 55587, Action: 2, Reward: 14.25
# Episode: 7, Step: 55588, Action: 0, Reward: 0
# Episode: 7, Step: 55589, Action: 2, Reward: -2.75
# Episode: 7, Step: 55590, Action: 2, Reward: 27.0
# Episode: 7, Step: 55591, Action: 2, Reward: -20.75
# Episode: 7, Step: 55592, Action: 2, Reward: -5.5
# Episode: 7, Step: 55593, Action: 2, Reward: 10.75
# Episode: 7, Step: 55594, Action: 2, Reward: -2.0
# Episode: 7, Step: 55595, Action: 2, Reward: 16.25
# Episode: 7, Step: 55596, Action: 2, Reward: 10.25
# Episode: 7, Step: 55597, Action: 2, Reward: 8.5
# Episode: 7, Step: 55598, Action: 2, Reward: 5.25
# Episode: 7, Step: 55599, Action: 2, Reward: 5.0
# Episode: 7, Step: 55600, Action: 2, Reward: 5.5
# Episode: 7, Step: 55601, Action: 2, Reward: -8.25
# Episode: 7, Step: 55602, Action: 2, Reward: 5.25
# Episode: 7, Step: 55603, Action: 2, Reward: 4.0
# Episode: 7, Step: 55604, Action: 2, Reward: 10.75
# Episode: 7, Step: 55605, Action: 2, Reward: -14.75
# Episode: 7, Step: 55606, Action: 2, Reward: 3.5
# Episode: 7, Step: 55607, Action: 2, Reward: -2.75
# Episode: 7, Step: 55608, Action: 2, Reward: -12.5
# Episode: 7, Step: 55609, Action: 2, Reward: -0.5
# Episode: 7, Step: 55610, Action: 2, Reward: 5.5
# Episode: 7, Step: 56959, Action: 2, Reward: -4.25
# Episode: 7, Step: 56960, Action: 2, Reward: 12.75
# Episode: 7, Step: 56961, Action: 2, Reward: -45.5
# Episode: 7, Step: 56962, Action: 2, Reward: -17.25
# Episode: 7, Step: 56963, Action: 2, Reward: -19.75
# Episode: 7, Step: 56964, Action: 2, Reward: -23.25
# Episode: 7, Step: 56965, Action: 0, Reward: 0
# Episode: 7, Step: 56966, Action: 2, Reward: -13.75
# Episode: 7, Step: 56967, Action: 2, Reward: 28.75
# Episode: 7, Step: 56968, Action: 2, Reward: -4.0
# Episode: 7, Step: 56969, Action: 2, Reward: 3.75
# Episode: 7, Step: 56970, Action: 2, Reward: -5.75
# Episode: 7, Step: 56971, Action: 2, Reward: 29.75
# Episode: 7, Step: 56972, Action: 2, Reward: 14.25
# Episode: 7, Step: 56973, Action: 2, Reward: -9.0
# Episode: 7, Step: 56974, Action: 2, Reward: 3.25
# Episode: 7, Step: 56975, Action: 2, Reward: -17.5
# Episode: 7, Step: 56976, Action: 2, Reward: -2.25
# Episode: 7, Step: 56977, Action: 2, Reward: -33.0
# Episode: 7, Step: 56978, Action: 2, Reward: -3.75
# Episode: 7, Step: 56979, Action: 2, Reward: -18.5
# Episode: 7, Step: 56980, Action: 2, Reward: 41.25
# Episode: 7, Step: 56981, Action: 2, Reward: 2.25
# Episode: 7, Step: 56982, Action: 2, Reward: 20.75
# Episode: 7, Step: 56983, Action: 2, Reward: -15.5
# Episode: 7, Step: 56984, Action: 2, Reward: -16.25
# Episode: 7, Step: 56985, Action: 0, Reward: 0
# Episode: 7, Step: 56986, Action: 2, Reward: -17.75
# Episode: 7, Step: 56987, Action: 2, Reward: -7.0
# Episode: 7, Step: 56988, Action: 2, Reward: 10.0
# Episode: 7, Step: 56989, Action: 2, Reward: -11.25
# Episode: 7, Step: 58337, Action: 2, Reward: 1.5
# Episode: 7, Step: 58338, Action: 2, Reward: 2.0
# Episode: 7, Step: 58339, Action: 2, Reward: 16.75
# Episode: 7, Step: 58340, Action: 2, Reward: 3.25
# Episode: 7, Step: 58341, Action: 2, Reward: 10.5
# Episode: 7, Step: 58342, Action: 2, Reward: -11.25
# Episode: 7, Step: 58343, Action: 2, Reward: 15.75
# Episode: 7, Step: 58344, Action: 2, Reward: -10.25
# Episode: 7, Step: 58345, Action: 0, Reward: 0
# Episode: 7, Step: 58346, Action: 2, Reward: 2.75
# Episode: 7, Step: 58347, Action: 2, Reward: 17.25
# Episode: 7, Step: 58348, Action: 2, Reward: -12.25
# Episode: 7, Step: 58349, Action: 2, Reward: -21.75
# Episode: 7, Step: 58350, Action: 2, Reward: -0.25
# Episode: 7, Step: 58351, Action: 2, Reward: 0.0
# Episode: 7, Step: 58352, Action: 2, Reward: 4.25
# Episode: 7, Step: 58353, Action: 2, Reward: -22.0
# Episode: 7, Step: 58354, Action: 2, Reward: 3.25
# Episode: 7, Step: 58355, Action: 2, Reward: 23.0
# Episode: 7, Step: 58356, Action: 2, Reward: -6.75
# Episode: 7, Step: 58357, Action: 2, Reward: -3.0
# Episode: 7, Step: 58358, Action: 2, Reward: 23.25
# Episode: 7, Step: 58359, Action: 2, Reward: -47.0
# Episode: 7, Step: 58360, Action: 1, Reward: -9.0
# Episode: 7, Step: 58361, Action: 2, Reward: -16.5
# Episode: 7, Step: 58362, Action: 2, Reward: 12.25
# Episode: 7, Step: 58363, Action: 2, Reward: 1.5
# Episode: 7, Step: 58364, Action: 2, Reward: 5.5
# Episode: 7, Step: 58365, Action: 2, Reward: -9.5
# Episode: 7, Step: 58366, Action: 1, Reward: 10.25
# Episode: 7, Step: 58367, Action: 2, Reward: 1.25
# Episode: 7, Total Reward: -14074.0, Win Rate: 0.46, Win Total: 115746.75, Lose Total: -129820.75, Ação 0: 1934, Ação 1: 2845, Ação 2: 54008, Wins: 25016, Losses: 29934
# Tempo de Treinamento: 164.43 segundos
# Episode: 8, Step: 630, Action: 2, Reward: 0.5
# Episode: 8, Step: 631, Action: 2, Reward: 2.5
# Episode: 8, Step: 632, Action: 2, Reward: -1.0
# Episode: 8, Step: 633, Action: 2, Reward: -4.75
# Episode: 8, Step: 634, Action: 2, Reward: 1.0
# Episode: 8, Step: 635, Action: 2, Reward: 2.25
# Episode: 8, Step: 636, Action: 2, Reward: 0.5
# Episode: 8, Step: 637, Action: 2, Reward: 1.0
# Episode: 8, Step: 638, Action: 2, Reward: 0.0
# Episode: 8, Step: 639, Action: 2, Reward: -1.0
# Episode: 8, Step: 640, Action: 2, Reward: -1.75
# Episode: 8, Step: 641, Action: 0, Reward: 0
# Episode: 8, Step: 642, Action: 2, Reward: -3.0
# Episode: 8, Step: 643, Action: 2, Reward: -5.0
# Episode: 8, Step: 644, Action: 2, Reward: 1.5
# Episode: 8, Step: 645, Action: 2, Reward: -0.25
# Episode: 8, Step: 646, Action: 2, Reward: -0.75
# Episode: 8, Step: 647, Action: 2, Reward: -0.5
# Episode: 8, Step: 648, Action: 2, Reward: -2.75
# Episode: 8, Step: 649, Action: 2, Reward: 4.0
# Episode: 8, Step: 650, Action: 2, Reward: -2.5
# Episode: 8, Step: 651, Action: 2, Reward: -1.25
# Episode: 8, Step: 652, Action: 2, Reward: -5.0
# Episode: 8, Step: 653, Action: 2, Reward: -5.25
# Episode: 8, Step: 654, Action: 2, Reward: -1.0
# Episode: 8, Step: 655, Action: 2, Reward: -1.75
# Episode: 8, Step: 656, Action: 2, Reward: -0.5
# Episode: 8, Step: 657, Action: 2, Reward: -1.0
# Episode: 8, Step: 658, Action: 2, Reward: 3.0
# Episode: 8, Step: 659, Action: 2, Reward: -3.75
# Episode: 8, Step: 660, Action: 2, Reward: 3.75
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 155
#     153     logits = policy_net(obs)
#     154     dist = Categorical(logits=logits)
# --> 155     action = dist.sample()
#     156     log_prob = dist.log_prob(action)
#     158 obs_next, reward, done, _ = env.step(action.item())
#
# File c:\Users\fabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\categorical.py:132, in Categorical.sample(self, sample_shape)
#     130 if not isinstance(sample_shape, torch.Size):
#     131     sample_shape = torch.Size(sample_shape)
# --> 132 probs_2d = self.probs.reshape(-1, self._num_events)
#     133 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     134 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# File c:\Users\fabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\utils.py:148, in lazy_property.__get__(self, instance, obj_type)
#     146     return _lazy_property_and_property(self.wrapped)
#     147 with torch.enable_grad():
# --> 148     value = self.wrapped(instance)
#     149 setattr(instance, self.wrapped.__name__, value)
#     150 return value
#
# File c:\Users\fabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\categorical.py:101, in Categorical.probs(self)
#      99 @lazy_property
#     100 def probs(self):
# --> 101     return logits_to_probs(self.logits)
#
# File c:\Users\fabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\distributions\utils.py:90, in logits_to_probs(logits, is_binary)
#      88 if is_binary:
#      89     return torch.sigmoid(logits)
# ---> 90 return F.softmax(logits, dim=-1)
#
# File c:\Users\fabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:1888, in softmax(input, dim, _stacklevel, dtype)
#    1886     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1887 if dtype is None:
# -> 1888     ret = input.softmax(dim)
#    1889 else:
#    1890     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:
