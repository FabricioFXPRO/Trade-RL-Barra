# %%
# Bloco 1: Preparar os Dados

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time

# Carregar o dataset
data = pd.read_csv('D:\\dados\\bar_M1_data_07-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = ['Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior', 'Corpo', 'Range', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK', 'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram']
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# Bloco 2: Criar o Ambiente com Gerenciamento de Posição

import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender

        # Atualizar o tamanho da observação para incluir a posição atual
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )

    def reset(self):
        self.current_step = 0
        self.position = 0
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)  # Incluir a posição atual na observação
        return obs.astype(np.float32)

    def step(self, action):
        self.current_step += 1
        done = self.current_step >= len(self.data) - 1
        reward = 0

        # Calcular a mudança de preço
        price_change = self.data['Valor'].iloc[self.current_step] - self.data['Valor'].iloc[self.current_step - 1]

        if action == 1:  # Comprar
            if self.position == 0:
                self.position = 1  # Abrir posição comprada
                reward -= 0.25  # Custo de operação
            elif self.position == -1:
                self.position = 0  # Fechar posição vendida
                reward += -price_change - 0.25  # Ganho da posição vendida
        elif action == 2:  # Vender
            if self.position == 0:
                self.position = -1  # Abrir posição vendida
                reward -= 0.25  # Custo de operação
            elif self.position == 1:
                self.position = 0  # Fechar posição comprada
                reward += price_change - 0.25  # Ganho da posição comprada
        else:  # Manter
            if self.position == 1:
                reward += price_change  # Ganho da posição comprada
            elif self.position == -1:
                reward += -price_change  # Ganho da posição vendida

        obs = self._next_observation()
        return obs, reward, done, {}

# Bloco 3: Criar o Agente DQN usando PyTorch

import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Definir a rede DQN
class DQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(DQN, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.model(x)

# Instanciar a rede
q_net = DQN(obs_size, n_actions).to(device)
target_net = DQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=1e-4)

# Hiperparâmetros para DQN
memory_size = 10000
batch_size = 64
gamma = 0.99
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.995
target_update = 10  # Atualizar a rede alvo a cada 10 episódios

# Inicializar a memória de replay
memory = collections.deque(maxlen=memory_size)

# Função para selecionar ação usando epsilon-greedy
def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.choice([0, 1, 2])
    else:
        with torch.no_grad():
            q_values = q_net(state)
            return q_values.argmax().item()

# Bloco 4: Treinamento do Agente DQN com Logs

num_episodes = 100  # Defina o número de episódios de treinamento
epsilon = epsilon_start

for episode in range(num_episodes):
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0

    while not done:
        steps += 1

        # Selecionar ação
        action = select_action(obs, epsilon)

        # Executar ação no ambiente
        obs_next, reward, done, _ = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        memory.append((obs, action, reward, obs_next, done))

        # Atualizar o estado
        obs = obs_next
        total_reward += reward

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Atualizar ganhos e perdas
        if reward > 0:
            wins += 1
            win_total += reward
        elif reward < 0:
            losses += 1
            lose_total += reward

        # Imprimir logs quando o gatilho for igual a 1
        gatilho = int(data['Gatilho'].iloc[env.current_step])
        if gatilho == 1:
            print(f"Episode: {episode + 1}, Step: {env.current_step}, Action: {action}, Reward: {reward:.2f}, Position: {env.position}")

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(memory) >= batch_size:
            batch = random.sample(memory, batch_size)
            states, actions_batch, rewards_batch, next_states, dones = zip(*batch)

            states = torch.cat(states).to(device)
            actions_batch = torch.tensor(actions_batch, dtype=torch.long, device=device).unsqueeze(1)
            rewards_batch = torch.tensor(rewards_batch, dtype=torch.float32, device=device).unsqueeze(1)
            next_states = torch.cat(next_states).to(device)
            dones = torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando a rede alvo
            with torch.no_grad():
                next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
            target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular a perda
            loss = nn.MSELoss()(q_values, target_q_values)

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Decaimento de epsilon
    epsilon = max(epsilon_end, epsilon_decay * epsilon)

    # Atualizar a rede alvo
    if episode % target_update == 0:
        target_net.load_state_dict(q_net.state_dict())

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, Wins: {wins}, Losses: {losses}, Epsilon: {epsilon:.4f}, Steps: {steps}")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}\n")

print("Treinamento finalizado.")
# Out:
# Episode: 1, Step: 630, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 631, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 632, Action: 0, Reward: 0.75, Position: 1
# Episode: 1, Step: 633, Action: 0, Reward: 4.50, Position: 1
# Episode: 1, Step: 634, Action: 2, Reward: -1.50, Position: 0
# Episode: 1, Step: 635, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 636, Action: 0, Reward: -0.75, Position: 1
# Episode: 1, Step: 637, Action: 0, Reward: -1.25, Position: 1
# Episode: 1, Step: 638, Action: 2, Reward: -0.50, Position: 0
# Episode: 1, Step: 639, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 640, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 641, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 642, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 643, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 644, Action: 0, Reward: 1.75, Position: -1
# Episode: 1, Step: 645, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 646, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 647, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 648, Action: 0, Reward: -2.50, Position: -1
# Episode: 1, Step: 649, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 650, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 651, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 652, Action: 0, Reward: -4.75, Position: -1
# Episode: 1, Step: 653, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 654, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 655, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 656, Action: 0, Reward: -0.25, Position: -1
# Episode: 1, Step: 657, Action: 1, Reward: -1.00, Position: 0
# Episode: 1, Step: 658, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 659, Action: 2, Reward: 3.25, Position: 0
# Episode: 1, Step: 660, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 1949, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 1950, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 1951, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 1952, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 1953, Action: 0, Reward: 3.50, Position: -1
# Episode: 1, Step: 1954, Action: 0, Reward: -2.50, Position: -1
# Episode: 1, Step: 1955, Action: 0, Reward: -1.50, Position: -1
# Episode: 1, Step: 1956, Action: 0, Reward: 2.00, Position: -1
# Episode: 1, Step: 1957, Action: 0, Reward: -4.00, Position: -1
# Episode: 1, Step: 1958, Action: 1, Reward: 1.00, Position: 0
# Episode: 1, Step: 1959, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 1960, Action: 1, Reward: -0.75, Position: 0
# Episode: 1, Step: 1961, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 1962, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 1963, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 1964, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 1965, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 1966, Action: 0, Reward: 1.75, Position: 1
# Episode: 1, Step: 1967, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 1968, Action: 2, Reward: 0.00, Position: 0
# Episode: 1, Step: 1969, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 1970, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 1971, Action: 1, Reward: 1.25, Position: 0
# Episode: 1, Step: 1972, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 1973, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 1974, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 1975, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 1976, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 1977, Action: 0, Reward: -2.50, Position: -1
# Episode: 1, Step: 1978, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 1979, Action: 0, Reward: 1.00, Position: -1
# Episode: 1, Step: 3268, Action: 0, Reward: -1.50, Position: 1
# Episode: 1, Step: 3269, Action: 0, Reward: 2.00, Position: 1
# Episode: 1, Step: 3270, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 3271, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 3272, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 3273, Action: 0, Reward: 1.50, Position: 1
# Episode: 1, Step: 3274, Action: 0, Reward: -2.50, Position: 1
# Episode: 1, Step: 3275, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 3276, Action: 0, Reward: -1.75, Position: 1
# Episode: 1, Step: 3277, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 3278, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 3279, Action: 0, Reward: -1.75, Position: 1
# Episode: 1, Step: 3280, Action: 2, Reward: 2.75, Position: 0
# Episode: 1, Step: 3281, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 3282, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 3283, Action: 1, Reward: 1.75, Position: 0
# Episode: 1, Step: 3284, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 3285, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 3286, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 3287, Action: 0, Reward: -1.00, Position: 1
# Episode: 1, Step: 3288, Action: 2, Reward: -1.00, Position: 0
# Episode: 1, Step: 3289, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 3290, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 3291, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 3292, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 3293, Action: 1, Reward: 0.50, Position: 0
# Episode: 1, Step: 3294, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 3295, Action: 2, Reward: -1.25, Position: 0
# Episode: 1, Step: 3296, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 3297, Action: 0, Reward: 4.00, Position: -1
# Episode: 1, Step: 3298, Action: 1, Reward: 1.75, Position: 0
# Episode: 1, Step: 4237, Action: 0, Reward: -0.50, Position: -1
# Episode: 1, Step: 4238, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 4239, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4240, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 4241, Action: 0, Reward: 0.00, Position: -1
# Episode: 1, Step: 4242, Action: 0, Reward: 0.25, Position: -1
# Episode: 1, Step: 4243, Action: 0, Reward: 0.25, Position: -1
# Episode: 1, Step: 4244, Action: 1, Reward: -1.75, Position: 0
# Episode: 1, Step: 4245, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4246, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 4247, Action: 2, Reward: 0.25, Position: 0
# Episode: 1, Step: 4248, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4249, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4250, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4251, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 4252, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 4253, Action: 1, Reward: -1.25, Position: 0
# Episode: 1, Step: 4254, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4255, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 4256, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 4257, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 4258, Action: 0, Reward: 0.50, Position: 1
# Episode: 1, Step: 4259, Action: 2, Reward: 1.75, Position: 0
# Episode: 1, Step: 4260, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 4261, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 4262, Action: 0, Reward: 0.00, Position: -1
# Episode: 1, Step: 4263, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 4264, Action: 1, Reward: 0.25, Position: 0
# Episode: 1, Step: 4265, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 4266, Action: 2, Reward: -1.75, Position: 0
# Episode: 1, Step: 4267, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5194, Action: 2, Reward: 1.50, Position: 0
# Episode: 1, Step: 5195, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 5196, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 5197, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5198, Action: 1, Reward: -1.25, Position: 0
# Episode: 1, Step: 5199, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 5200, Action: 2, Reward: 1.50, Position: 0
# Episode: 1, Step: 5201, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5202, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 5203, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 5204, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 5205, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 5206, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 5207, Action: 2, Reward: 1.00, Position: 0
# Episode: 1, Step: 5208, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 5209, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5210, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 5211, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5212, Action: 0, Reward: 2.75, Position: -1
# Episode: 1, Step: 5213, Action: 1, Reward: -1.50, Position: 0
# Episode: 1, Step: 5214, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5215, Action: 1, Reward: -0.75, Position: 0
# Episode: 1, Step: 5216, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 5217, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 5218, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 5219, Action: 0, Reward: 2.75, Position: -1
# Episode: 1, Step: 5220, Action: 0, Reward: -0.75, Position: -1
# Episode: 1, Step: 5221, Action: 0, Reward: 1.25, Position: -1
# Episode: 1, Step: 5222, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 5223, Action: 0, Reward: 0.75, Position: -1
# Episode: 1, Step: 5224, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6393, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 6394, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 6395, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 6396, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6397, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6398, Action: 0, Reward: 1.00, Position: -1
# Episode: 1, Step: 6399, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6400, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6401, Action: 1, Reward: 0.50, Position: 0
# Episode: 1, Step: 6402, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 6403, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6404, Action: 0, Reward: 0.50, Position: -1
# Episode: 1, Step: 6405, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6406, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6407, Action: 0, Reward: -3.00, Position: -1
# Episode: 1, Step: 6408, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6409, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6410, Action: 1, Reward: 0.75, Position: 0
# Episode: 1, Step: 6411, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 6412, Action: 0, Reward: -0.25, Position: -1
# Episode: 1, Step: 6413, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6414, Action: 1, Reward: 0.00, Position: 0
# Episode: 1, Step: 6415, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 6416, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 6417, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 6418, Action: 2, Reward: 1.25, Position: 0
# Episode: 1, Step: 6419, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 6420, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 6421, Action: 1, Reward: -0.50, Position: 0
# Episode: 1, Step: 6422, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 6423, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 7711, Action: 0, Reward: -0.75, Position: 1
# Episode: 1, Step: 7712, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 7713, Action: 2, Reward: 1.25, Position: 0
# Episode: 1, Step: 7714, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 7715, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 7716, Action: 2, Reward: 1.00, Position: 0
# Episode: 1, Step: 7717, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 7718, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 7719, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 7720, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 7721, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 7722, Action: 0, Reward: 0.75, Position: 1
# Episode: 1, Step: 7723, Action: 0, Reward: -0.75, Position: 1
# Episode: 1, Step: 7724, Action: 0, Reward: 0.75, Position: 1
# Episode: 1, Step: 7725, Action: 2, Reward: -0.75, Position: 0
# Episode: 1, Step: 7726, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 7727, Action: 2, Reward: 0.25, Position: 0
# Episode: 1, Step: 7728, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 7729, Action: 1, Reward: 2.00, Position: 0
# Episode: 1, Step: 7730, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 7731, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 7732, Action: 1, Reward: -2.25, Position: 0
# Episode: 1, Step: 7733, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 7734, Action: 0, Reward: -0.50, Position: 1
# Episode: 1, Step: 7735, Action: 2, Reward: -2.00, Position: 0
# Episode: 1, Step: 7736, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 7737, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 7738, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 7739, Action: 1, Reward: -1.75, Position: 0
# Episode: 1, Step: 7740, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 7741, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 9030, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 9031, Action: 1, Reward: -2.00, Position: 0
# Episode: 1, Step: 9032, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 9033, Action: 1, Reward: 1.25, Position: 0
# Episode: 1, Step: 9034, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 9035, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 9036, Action: 0, Reward: -1.00, Position: 1
# Episode: 1, Step: 9037, Action: 0, Reward: 0.25, Position: 1
# Episode: 1, Step: 9038, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 9039, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 9040, Action: 2, Reward: 0.75, Position: 0
# Episode: 1, Step: 9041, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 9042, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9043, Action: 0, Reward: -0.25, Position: -1
# Episode: 1, Step: 9044, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9045, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9046, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9047, Action: 0, Reward: -0.75, Position: -1
# Episode: 1, Step: 9048, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9049, Action: 1, Reward: 3.25, Position: 0
# Episode: 1, Step: 9050, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 9051, Action: 1, Reward: 0.00, Position: 0
# Episode: 1, Step: 9052, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 9053, Action: 2, Reward: 0.50, Position: 0
# Episode: 1, Step: 9054, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 9055, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 9056, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 9057, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 9058, Action: 1, Reward: -0.50, Position: 0
# Episode: 1, Step: 9059, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 9060, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10348, Action: 2, Reward: -1.25, Position: 0
# Episode: 1, Step: 10349, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 10350, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 10351, Action: 0, Reward: 0.00, Position: -1
# Episode: 1, Step: 10352, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 10353, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 10354, Action: 1, Reward: 1.75, Position: 0
# Episode: 1, Step: 10355, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10356, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 10357, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 10358, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 10359, Action: 2, Reward: 1.00, Position: 0
# Episode: 1, Step: 10360, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10361, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10362, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10363, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10364, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 10365, Action: 1, Reward: 0.50, Position: 0
# Episode: 1, Step: 10366, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 10367, Action: 2, Reward: -1.75, Position: 0
# Episode: 1, Step: 10368, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 10369, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 10370, Action: 0, Reward: 0.00, Position: -1
# Episode: 1, Step: 10371, Action: 1, Reward: 1.00, Position: 0
# Episode: 1, Step: 10372, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 10373, Action: 0, Reward: 1.25, Position: 1
# Episode: 1, Step: 10374, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 10375, Action: 2, Reward: 1.25, Position: 0
# Episode: 1, Step: 10376, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 10377, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 10378, Action: 0, Reward: 0.25, Position: 1
# Episode: 1, Step: 11667, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11668, Action: 1, Reward: 2.75, Position: 0
# Episode: 1, Step: 11669, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 11670, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11671, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11672, Action: 1, Reward: -1.00, Position: 0
# Episode: 1, Step: 11673, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11674, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11675, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11676, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 11677, Action: 0, Reward: 1.00, Position: -1
# Episode: 1, Step: 11678, Action: 1, Reward: 1.25, Position: 0
# Episode: 1, Step: 11679, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 11680, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11681, Action: 0, Reward: -1.00, Position: -1
# Episode: 1, Step: 11682, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11683, Action: 1, Reward: 2.75, Position: 0
# Episode: 1, Step: 11684, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11685, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11686, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 11687, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 11688, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11689, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11690, Action: 0, Reward: -3.50, Position: -1
# Episode: 1, Step: 11691, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11692, Action: 0, Reward: -1.00, Position: -1
# Episode: 1, Step: 11693, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11694, Action: 0, Reward: -1.25, Position: -1
# Episode: 1, Step: 11695, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11696, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 11697, Action: 0, Reward: 0.75, Position: -1
# Episode: 1, Step: 12863, Action: 1, Reward: 1.25, Position: 0
# Episode: 1, Step: 12864, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 12865, Action: 1, Reward: -0.75, Position: 0
# Episode: 1, Step: 12866, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12867, Action: 2, Reward: 1.75, Position: 0
# Episode: 1, Step: 12868, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12869, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12870, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12871, Action: 2, Reward: -3.25, Position: 0
# Episode: 1, Step: 12872, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12873, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12874, Action: 2, Reward: 2.25, Position: 0
# Episode: 1, Step: 12875, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12876, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12877, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 12878, Action: 0, Reward: -1.25, Position: 1
# Episode: 1, Step: 12879, Action: 2, Reward: -0.50, Position: 0
# Episode: 1, Step: 12880, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 12881, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12882, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 12883, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12884, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 12885, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 12886, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12887, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 12888, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 12889, Action: 0, Reward: -0.25, Position: 1
# Episode: 1, Step: 12890, Action: 2, Reward: -1.75, Position: 0
# Episode: 1, Step: 12891, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 12892, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 12893, Action: 0, Reward: -2.25, Position: -1
# Episode: 1, Step: 14182, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 14183, Action: 0, Reward: 0.50, Position: -1
# Episode: 1, Step: 14184, Action: 0, Reward: -0.25, Position: -1
# Episode: 1, Step: 14185, Action: 1, Reward: -1.50, Position: 0
# Episode: 1, Step: 14186, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 14187, Action: 1, Reward: 0.25, Position: 0
# Episode: 1, Step: 14188, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 14189, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 14190, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 14191, Action: 1, Reward: 0.25, Position: 0
# Episode: 1, Step: 14192, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 14193, Action: 1, Reward: -6.00, Position: 0
# Episode: 1, Step: 14194, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14195, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 14196, Action: 1, Reward: 0.25, Position: 0
# Episode: 1, Step: 14197, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14198, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14199, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 14200, Action: 2, Reward: 0.00, Position: 0
# Episode: 1, Step: 14201, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14202, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 14203, Action: 2, Reward: -1.25, Position: 0
# Episode: 1, Step: 14204, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14205, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14206, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14207, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 14208, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 14209, Action: 2, Reward: -1.00, Position: 0
# Episode: 1, Step: 14210, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 14211, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 14212, Action: 2, Reward: 1.50, Position: 0
# Episode: 1, Step: 15502, Action: 0, Reward: 2.00, Position: -1
# Episode: 1, Step: 15503, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 15504, Action: 1, Reward: 0.00, Position: 0
# Episode: 1, Step: 15505, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 15506, Action: 0, Reward: -7.00, Position: -1
# Episode: 1, Step: 15507, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 15508, Action: 1, Reward: 3.00, Position: 0
# Episode: 1, Step: 15509, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 15510, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 15511, Action: 0, Reward: -2.00, Position: -1
# Episode: 1, Step: 15512, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 15513, Action: 0, Reward: -7.25, Position: -1
# Episode: 1, Step: 15514, Action: 1, Reward: 2.25, Position: 0
# Episode: 1, Step: 15515, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 15516, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 15517, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 15518, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 15519, Action: 1, Reward: -0.50, Position: 0
# Episode: 1, Step: 15520, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 15521, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 15522, Action: 0, Reward: -7.75, Position: 1
# Episode: 1, Step: 15523, Action: 2, Reward: 0.00, Position: 0
# Episode: 1, Step: 15524, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 15525, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 15526, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 15527, Action: 0, Reward: -7.75, Position: -1
# Episode: 1, Step: 15528, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 15529, Action: 1, Reward: 5.25, Position: 0
# Episode: 1, Step: 15530, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 15531, Action: 0, Reward: -5.25, Position: -1
# Episode: 1, Step: 15532, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 16822, Action: 1, Reward: 1.00, Position: 0
# Episode: 1, Step: 16823, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 16824, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16825, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 16826, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 16827, Action: 0, Reward: -7.75, Position: -1
# Episode: 1, Step: 16828, Action: 1, Reward: 1.50, Position: 0
# Episode: 1, Step: 16829, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 16830, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16831, Action: 0, Reward: -2.75, Position: 1
# Episode: 1, Step: 16832, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 16833, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16834, Action: 2, Reward: -2.00, Position: 0
# Episode: 1, Step: 16835, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16836, Action: 0, Reward: 2.25, Position: 1
# Episode: 1, Step: 16837, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 16838, Action: 2, Reward: -2.25, Position: 0
# Episode: 1, Step: 16839, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 16840, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16841, Action: 2, Reward: -9.50, Position: 0
# Episode: 1, Step: 16842, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 16843, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 16844, Action: 1, Reward: -7.75, Position: 0
# Episode: 1, Step: 16845, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 16846, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16847, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 16848, Action: 2, Reward: -4.75, Position: 0
# Episode: 1, Step: 16849, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 16850, Action: 0, Reward: 2.75, Position: 1
# Episode: 1, Step: 16851, Action: 2, Reward: -7.25, Position: 0
# Episode: 1, Step: 16852, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 18140, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 18141, Action: 1, Reward: 0.50, Position: 0
# Episode: 1, Step: 18142, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 18143, Action: 0, Reward: 3.50, Position: -1
# Episode: 1, Step: 18144, Action: 0, Reward: -1.25, Position: -1
# Episode: 1, Step: 18145, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 18146, Action: 0, Reward: 1.25, Position: -1
# Episode: 1, Step: 18147, Action: 0, Reward: -4.00, Position: -1
# Episode: 1, Step: 18148, Action: 1, Reward: -2.25, Position: 0
# Episode: 1, Step: 18149, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 18150, Action: 1, Reward: 9.75, Position: 0
# Episode: 1, Step: 18151, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 18152, Action: 0, Reward: 2.50, Position: 1
# Episode: 1, Step: 18153, Action: 2, Reward: 1.50, Position: 0
# Episode: 1, Step: 18154, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 18155, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 18156, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 18157, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 18158, Action: 1, Reward: -0.75, Position: 0
# Episode: 1, Step: 18159, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 18160, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 18161, Action: 0, Reward: 1.50, Position: 1
# Episode: 1, Step: 18162, Action: 0, Reward: 3.50, Position: 1
# Episode: 1, Step: 18163, Action: 0, Reward: -10.25, Position: 1
# Episode: 1, Step: 18164, Action: 0, Reward: 2.75, Position: 1
# Episode: 1, Step: 18165, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 18166, Action: 2, Reward: 3.00, Position: 0
# Episode: 1, Step: 18167, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 18168, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 18169, Action: 1, Reward: -5.25, Position: 0
# Episode: 1, Step: 18170, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 19339, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 19340, Action: 2, Reward: -1.25, Position: 0
# Episode: 1, Step: 19341, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19342, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19343, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19344, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 19345, Action: 0, Reward: -0.75, Position: -1
# Episode: 1, Step: 19346, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19347, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19348, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19349, Action: 0, Reward: 1.00, Position: -1
# Episode: 1, Step: 19350, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19351, Action: 0, Reward: 2.00, Position: -1
# Episode: 1, Step: 19352, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19353, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19354, Action: 0, Reward: -5.75, Position: -1
# Episode: 1, Step: 19355, Action: 1, Reward: 3.25, Position: 0
# Episode: 1, Step: 19356, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19357, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 19358, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19359, Action: 0, Reward: -2.50, Position: -1
# Episode: 1, Step: 19360, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19361, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 19362, Action: 0, Reward: 0.75, Position: -1
# Episode: 1, Step: 19363, Action: 0, Reward: 2.50, Position: -1
# Episode: 1, Step: 19364, Action: 0, Reward: -5.50, Position: -1
# Episode: 1, Step: 19365, Action: 0, Reward: 1.75, Position: -1
# Episode: 1, Step: 19366, Action: 1, Reward: 4.50, Position: 0
# Episode: 1, Step: 19367, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19368, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 19369, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20658, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 20659, Action: 2, Reward: 5.00, Position: 0
# Episode: 1, Step: 20660, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20661, Action: 2, Reward: -4.25, Position: 0
# Episode: 1, Step: 20662, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 20663, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20664, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 20665, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20666, Action: 0, Reward: -2.25, Position: 1
# Episode: 1, Step: 20667, Action: 2, Reward: 3.75, Position: 0
# Episode: 1, Step: 20668, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 20669, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 20670, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 20671, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 20672, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20673, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 20674, Action: 0, Reward: -1.00, Position: 1
# Episode: 1, Step: 20675, Action: 0, Reward: -2.00, Position: 1
# Episode: 1, Step: 20676, Action: 2, Reward: -1.50, Position: 0
# Episode: 1, Step: 20677, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20678, Action: 0, Reward: 2.75, Position: 1
# Episode: 1, Step: 20679, Action: 2, Reward: 3.25, Position: 0
# Episode: 1, Step: 20680, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 20681, Action: 1, Reward: -0.75, Position: 0
# Episode: 1, Step: 20682, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 20683, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 20684, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 20685, Action: 0, Reward: -3.50, Position: -1
# Episode: 1, Step: 20686, Action: 1, Reward: 5.75, Position: 0
# Episode: 1, Step: 20687, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 20688, Action: 2, Reward: -2.50, Position: 0
# Episode: 1, Step: 21977, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 21978, Action: 2, Reward: -3.75, Position: 0
# Episode: 1, Step: 21979, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 21980, Action: 0, Reward: 3.50, Position: -1
# Episode: 1, Step: 21981, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 21982, Action: 0, Reward: -3.25, Position: -1
# Episode: 1, Step: 21983, Action: 1, Reward: 2.50, Position: 0
# Episode: 1, Step: 21984, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 21985, Action: 0, Reward: -0.25, Position: 1
# Episode: 1, Step: 21986, Action: 2, Reward: 0.25, Position: 0
# Episode: 1, Step: 21987, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 21988, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 21989, Action: 0, Reward: -1.75, Position: 1
# Episode: 1, Step: 21990, Action: 2, Reward: -1.75, Position: 0
# Episode: 1, Step: 21991, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 21992, Action: 0, Reward: -1.75, Position: 1
# Episode: 1, Step: 21993, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 21994, Action: 0, Reward: -1.50, Position: 1
# Episode: 1, Step: 21995, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 21996, Action: 0, Reward: -3.50, Position: 1
# Episode: 1, Step: 21997, Action: 2, Reward: -0.75, Position: 0
# Episode: 1, Step: 21998, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 21999, Action: 1, Reward: -5.00, Position: 0
# Episode: 1, Step: 22000, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 22001, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 22002, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 22003, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 22004, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 22005, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 22006, Action: 2, Reward: 3.00, Position: 0
# Episode: 1, Step: 22007, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 23295, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23296, Action: 0, Reward: 0.75, Position: 1
# Episode: 1, Step: 23297, Action: 2, Reward: 9.50, Position: 0
# Episode: 1, Step: 23298, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23299, Action: 2, Reward: 21.00, Position: 0
# Episode: 1, Step: 23300, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23301, Action: 0, Reward: 1.00, Position: 1
# Episode: 1, Step: 23302, Action: 0, Reward: -17.00, Position: 1
# Episode: 1, Step: 23303, Action: 2, Reward: -2.75, Position: 0
# Episode: 1, Step: 23304, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 23305, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23306, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 23307, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 23308, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 23309, Action: 0, Reward: -4.25, Position: 1
# Episode: 1, Step: 23310, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 23311, Action: 2, Reward: 19.75, Position: 0
# Episode: 1, Step: 23312, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 23313, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23314, Action: 0, Reward: -7.50, Position: 1
# Episode: 1, Step: 23315, Action: 0, Reward: 3.75, Position: 1
# Episode: 1, Step: 23316, Action: 0, Reward: 4.50, Position: 1
# Episode: 1, Step: 23317, Action: 0, Reward: 7.75, Position: 1
# Episode: 1, Step: 23318, Action: 2, Reward: 1.00, Position: 0
# Episode: 1, Step: 23319, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 23320, Action: 0, Reward: -3.00, Position: -1
# Episode: 1, Step: 23321, Action: 1, Reward: -20.75, Position: 0
# Episode: 1, Step: 23322, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 23323, Action: 0, Reward: -5.25, Position: 1
# Episode: 1, Step: 23324, Action: 2, Reward: -8.25, Position: 0
# Episode: 1, Step: 23325, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 24610, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24611, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 24612, Action: 2, Reward: 1.75, Position: 0
# Episode: 1, Step: 24613, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 24614, Action: 0, Reward: -8.50, Position: -1
# Episode: 1, Step: 24615, Action: 1, Reward: 2.75, Position: 0
# Episode: 1, Step: 24616, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24617, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24618, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 24619, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 24620, Action: 0, Reward: 0.00, Position: 1
# Episode: 1, Step: 24621, Action: 2, Reward: 0.75, Position: 0
# Episode: 1, Step: 24622, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 24623, Action: 1, Reward: 1.00, Position: 0
# Episode: 1, Step: 24624, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 24625, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 24626, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 24627, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 24628, Action: 2, Reward: -5.00, Position: 0
# Episode: 1, Step: 24629, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24630, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 24631, Action: 2, Reward: 1.75, Position: 0
# Episode: 1, Step: 24632, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24633, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24634, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24635, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24636, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 24637, Action: 2, Reward: 2.25, Position: 0
# Episode: 1, Step: 24638, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 24639, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 24640, Action: 1, Reward: -3.25, Position: 0
# Episode: 1, Step: 25809, Action: 0, Reward: 0.50, Position: -1
# Episode: 1, Step: 25810, Action: 0, Reward: -0.50, Position: -1
# Episode: 1, Step: 25811, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25812, Action: 0, Reward: 2.50, Position: -1
# Episode: 1, Step: 25813, Action: 1, Reward: -3.25, Position: 0
# Episode: 1, Step: 25814, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 25815, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 25816, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25817, Action: 0, Reward: -1.00, Position: -1
# Episode: 1, Step: 25818, Action: 1, Reward: -1.50, Position: 0
# Episode: 1, Step: 25819, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 25820, Action: 0, Reward: -2.75, Position: -1
# Episode: 1, Step: 25821, Action: 0, Reward: 0.75, Position: -1
# Episode: 1, Step: 25822, Action: 1, Reward: 2.75, Position: 0
# Episode: 1, Step: 25823, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 25824, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 25825, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 25826, Action: 0, Reward: -0.75, Position: 1
# Episode: 1, Step: 25827, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 25828, Action: 2, Reward: -0.50, Position: 0
# Episode: 1, Step: 25829, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 25830, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 25831, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25832, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25833, Action: 1, Reward: 1.50, Position: 0
# Episode: 1, Step: 25834, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 25835, Action: 1, Reward: -3.00, Position: 0
# Episode: 1, Step: 25836, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 25837, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25838, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 25839, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 27127, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 27128, Action: 1, Reward: -4.00, Position: 0
# Episode: 1, Step: 27129, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 27130, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 27131, Action: 1, Reward: -5.75, Position: 0
# Episode: 1, Step: 27132, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 27133, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 27134, Action: 2, Reward: 0.75, Position: 0
# Episode: 1, Step: 27135, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 27136, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 27137, Action: 2, Reward: -3.00, Position: 0
# Episode: 1, Step: 27138, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 27139, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 27140, Action: 0, Reward: 3.75, Position: 1
# Episode: 1, Step: 27141, Action: 0, Reward: -2.75, Position: 1
# Episode: 1, Step: 27142, Action: 2, Reward: 0.25, Position: 0
# Episode: 1, Step: 27143, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 27144, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 27145, Action: 0, Reward: 1.00, Position: 1
# Episode: 1, Step: 27146, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 27147, Action: 0, Reward: -1.75, Position: 1
# Episode: 1, Step: 27148, Action: 0, Reward: -1.25, Position: 1
# Episode: 1, Step: 27149, Action: 0, Reward: 0.25, Position: 1
# Episode: 1, Step: 27150, Action: 2, Reward: 0.75, Position: 0
# Episode: 1, Step: 27151, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 27152, Action: 0, Reward: 1.75, Position: -1
# Episode: 1, Step: 27153, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 27154, Action: 0, Reward: 0.00, Position: -1
# Episode: 1, Step: 27155, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 27156, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 27157, Action: 0, Reward: -4.25, Position: -1
# Episode: 1, Step: 28446, Action: 2, Reward: -0.50, Position: 0
# Episode: 1, Step: 28447, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28448, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 28449, Action: 2, Reward: 2.50, Position: 0
# Episode: 1, Step: 28450, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28451, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 28452, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 28453, Action: 0, Reward: -1.75, Position: -1
# Episode: 1, Step: 28454, Action: 1, Reward: -2.25, Position: 0
# Episode: 1, Step: 28455, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28456, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28457, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 28458, Action: 1, Reward: -3.75, Position: 0
# Episode: 1, Step: 28459, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 28460, Action: 2, Reward: -1.75, Position: 0
# Episode: 1, Step: 28461, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28462, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 28463, Action: 0, Reward: 0.25, Position: -1
# Episode: 1, Step: 28464, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 28465, Action: 1, Reward: -3.50, Position: 0
# Episode: 1, Step: 28466, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28467, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 28468, Action: 2, Reward: -0.50, Position: 0
# Episode: 1, Step: 28469, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 28470, Action: 2, Reward: 1.00, Position: 0
# Episode: 1, Step: 28471, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28472, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28473, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 28474, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 28475, Action: 2, Reward: 3.25, Position: 0
# Episode: 1, Step: 28476, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29762, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 29763, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 29764, Action: 2, Reward: -7.75, Position: 0
# Episode: 1, Step: 29765, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29766, Action: 1, Reward: 7.75, Position: 0
# Episode: 1, Step: 29767, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 29768, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29769, Action: 0, Reward: -1.25, Position: -1
# Episode: 1, Step: 29770, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29771, Action: 0, Reward: -10.75, Position: -1
# Episode: 1, Step: 29772, Action: 1, Reward: -0.25, Position: 0
# Episode: 1, Step: 29773, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 29774, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 29775, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29776, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29777, Action: 1, Reward: -5.50, Position: 0
# Episode: 1, Step: 29778, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29779, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29780, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29781, Action: 0, Reward: -5.50, Position: -1
# Episode: 1, Step: 29782, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29783, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29784, Action: 0, Reward: 0.75, Position: -1
# Episode: 1, Step: 29785, Action: 0, Reward: 4.75, Position: -1
# Episode: 1, Step: 29786, Action: 1, Reward: -1.50, Position: 0
# Episode: 1, Step: 29787, Action: 2, Reward: -0.25, Position: -1
# Episode: 1, Step: 29788, Action: 2, Reward: 0.00, Position: -1
# Episode: 1, Step: 29789, Action: 0, Reward: 4.00, Position: -1
# Episode: 1, Step: 29790, Action: 0, Reward: -1.00, Position: -1
# Episode: 1, Step: 29791, Action: 1, Reward: 0.25, Position: 0
# Episode: 1, Step: 29792, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31081, Action: 2, Reward: -5.25, Position: 0
# Episode: 1, Step: 31082, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31083, Action: 2, Reward: 0.00, Position: 0
# Episode: 1, Step: 31084, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31085, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 31086, Action: 0, Reward: -11.25, Position: 1
# Episode: 1, Step: 31087, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 31088, Action: 0, Reward: 1.50, Position: 1
# Episode: 1, Step: 31089, Action: 2, Reward: 2.00, Position: 0
# Episode: 1, Step: 31090, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31091, Action: 2, Reward: -0.25, Position: 0
# Episode: 1, Step: 31092, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31093, Action: 2, Reward: 21.50, Position: 0
# Episode: 1, Step: 31094, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31095, Action: 2, Reward: -4.50, Position: 0
# Episode: 1, Step: 31096, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 31097, Action: 0, Reward: 0.00, Position: 0
# Episode: 1, Step: 31098, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31099, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 31100, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 31101, Action: 1, Reward: 0.00, Position: 1
# Episode: 1, Step: 31102, Action: 2, Reward: 3.50, Position: 0
# Episode: 1, Step: 31103, Action: 1, Reward: -0.25, Position: 1
# Episode: 1, Step: 31104, Action: 1, Reward: 0.00, Position: 1
# ...
# Episode: 13, Step: 41809, Action: 0, Reward: -10.50, Position: -1
# Episode: 13, Step: 41810, Action: 0, Reward: 10.50, Position: -1
# Episode: 13, Step: 41811, Action: 0, Reward: 1.00, Position: -1
# Episode: 13, Step: 41812, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 41813, Action: 1, Reward: 11.50, Position: 0
# Episode: 13, Step: 41814, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 41815, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 41816, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 41817, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 41818, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 41819, Action: 1, Reward: -1.00, Position: 0
# Episode: 13, Step: 41820, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 41821, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 41822, Action: 1, Reward: 21.75, Position: 0
# Episode: 13, Step: 41823, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 41824, Action: 2, Reward: -15.00, Position: 0
# Episode: 13, Step: 41825, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 41826, Action: 0, Reward: -12.50, Position: -1
# Episode: 13, Step: 41827, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 41828, Action: 0, Reward: 8.25, Position: -1
# Episode: 13, Step: 41829, Action: 0, Reward: -11.00, Position: -1
# Episode: 13, Step: 41830, Action: 1, Reward: 9.25, Position: 0
# Episode: 13, Step: 41831, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 41832, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 43179, Action: 0, Reward: 3.00, Position: 1
# Episode: 13, Step: 43180, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 43181, Action: 0, Reward: 11.25, Position: 1
# Episode: 13, Step: 43182, Action: 0, Reward: -28.75, Position: 1
# Episode: 13, Step: 43183, Action: 0, Reward: 10.25, Position: 1
# Episode: 13, Step: 43184, Action: 0, Reward: 14.50, Position: 1
# Episode: 13, Step: 43185, Action: 2, Reward: -6.50, Position: 0
# Episode: 13, Step: 43186, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 43187, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 43188, Action: 0, Reward: 6.25, Position: -1
# Episode: 13, Step: 43189, Action: 0, Reward: -11.75, Position: -1
# Episode: 13, Step: 43190, Action: 1, Reward: 17.25, Position: 0
# Episode: 13, Step: 43191, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 43192, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 43193, Action: 1, Reward: -13.25, Position: 0
# Episode: 13, Step: 43194, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 43195, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 43196, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 43197, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 43198, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 43199, Action: 2, Reward: 13.50, Position: 0
# Episode: 13, Step: 43200, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 43201, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 43202, Action: 0, Reward: -16.00, Position: -1
# Episode: 13, Step: 43203, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 43204, Action: 1, Reward: -4.25, Position: 0
# Episode: 13, Step: 43205, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 43206, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 43207, Action: 0, Reward: 4.00, Position: 1
# Episode: 13, Step: 43208, Action: 0, Reward: 11.75, Position: 1
# Episode: 13, Step: 43209, Action: 2, Reward: 2.25, Position: 0
# Episode: 13, Step: 44558, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 44559, Action: 1, Reward: 35.75, Position: 0
# Episode: 13, Step: 44560, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 44561, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 44562, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44563, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44564, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44565, Action: 0, Reward: -1.00, Position: 1
# Episode: 13, Step: 44566, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44567, Action: 2, Reward: 0.00, Position: 0
# Episode: 13, Step: 44568, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 44569, Action: 0, Reward: -20.75, Position: -1
# Episode: 13, Step: 44570, Action: 1, Reward: 6.25, Position: 0
# Episode: 13, Step: 44571, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 44572, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 44573, Action: 0, Reward: 3.75, Position: -1
# Episode: 13, Step: 44574, Action: 1, Reward: 15.00, Position: 0
# Episode: 13, Step: 44575, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 44576, Action: 0, Reward: 4.25, Position: 1
# Episode: 13, Step: 44577, Action: 2, Reward: 6.50, Position: 0
# Episode: 13, Step: 44578, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 44579, Action: 0, Reward: 16.75, Position: 1
# Episode: 13, Step: 44580, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44581, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44582, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 44583, Action: 0, Reward: -0.75, Position: 1
# Episode: 13, Step: 44584, Action: 2, Reward: -15.50, Position: 0
# Episode: 13, Step: 44585, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 44586, Action: 0, Reward: 0.50, Position: -1
# Episode: 13, Step: 44587, Action: 0, Reward: 9.00, Position: -1
# Episode: 13, Step: 44588, Action: 0, Reward: -5.00, Position: -1
# Episode: 13, Step: 45935, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 45936, Action: 0, Reward: 10.25, Position: -1
# Episode: 13, Step: 45937, Action: 1, Reward: 2.25, Position: 0
# Episode: 13, Step: 45938, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45939, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45940, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45941, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45942, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 45943, Action: 1, Reward: 12.00, Position: 0
# Episode: 13, Step: 45944, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 45945, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45946, Action: 2, Reward: 9.75, Position: 0
# Episode: 13, Step: 45947, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 45948, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45949, Action: 0, Reward: -8.75, Position: 1
# Episode: 13, Step: 45950, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45951, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45952, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45953, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45954, Action: 0, Reward: 10.00, Position: 1
# Episode: 13, Step: 45955, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45956, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45957, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45958, Action: 0, Reward: 9.75, Position: 1
# Episode: 13, Step: 45959, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 45960, Action: 2, Reward: -17.50, Position: 0
# Episode: 13, Step: 45961, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 45962, Action: 1, Reward: -16.25, Position: 0
# Episode: 13, Step: 45963, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45964, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 45965, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 47312, Action: 2, Reward: -1.50, Position: 0
# Episode: 13, Step: 47313, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 47314, Action: 0, Reward: -7.75, Position: -1
# Episode: 13, Step: 47315, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 47316, Action: 1, Reward: -7.00, Position: 0
# Episode: 13, Step: 47317, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 47318, Action: 0, Reward: -5.50, Position: 1
# Episode: 13, Step: 47319, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 47320, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 47321, Action: 0, Reward: 6.25, Position: 1
# Episode: 13, Step: 47322, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 47323, Action: 0, Reward: 3.75, Position: 1
# Episode: 13, Step: 47324, Action: 0, Reward: 12.75, Position: 1
# Episode: 13, Step: 47325, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 47326, Action: 0, Reward: -9.75, Position: 1
# Episode: 13, Step: 47327, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 47328, Action: 0, Reward: -1.75, Position: 1
# Episode: 13, Step: 47329, Action: 0, Reward: 1.75, Position: 1
# Episode: 13, Step: 47330, Action: 2, Reward: 0.00, Position: 0
# Episode: 13, Step: 47331, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 47332, Action: 1, Reward: -0.25, Position: 0
# Episode: 13, Step: 47333, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 47334, Action: 0, Reward: 8.25, Position: -1
# Episode: 13, Step: 47335, Action: 0, Reward: -11.75, Position: -1
# Episode: 13, Step: 47336, Action: 0, Reward: -3.75, Position: -1
# Episode: 13, Step: 47337, Action: 0, Reward: -11.00, Position: -1
# Episode: 13, Step: 47338, Action: 1, Reward: 0.25, Position: 0
# Episode: 13, Step: 47339, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 47340, Action: 1, Reward: -12.25, Position: 0
# Episode: 13, Step: 47341, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 47342, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 48690, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 48691, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 48692, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 48693, Action: 0, Reward: 3.50, Position: 1
# Episode: 13, Step: 48694, Action: 0, Reward: -8.75, Position: 1
# Episode: 13, Step: 48695, Action: 0, Reward: -7.00, Position: 1
# Episode: 13, Step: 48696, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 48697, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 48698, Action: 2, Reward: -11.50, Position: 0
# Episode: 13, Step: 48699, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 48700, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 48701, Action: 0, Reward: -5.25, Position: -1
# Episode: 13, Step: 48702, Action: 1, Reward: -2.25, Position: 0
# Episode: 13, Step: 48703, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 48704, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 48705, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 48706, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 48707, Action: 0, Reward: -8.75, Position: -1
# Episode: 13, Step: 48708, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 48709, Action: 0, Reward: -1.00, Position: -1
# Episode: 13, Step: 48710, Action: 1, Reward: 2.25, Position: 0
# Episode: 13, Step: 48711, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 48712, Action: 0, Reward: 9.25, Position: 1
# Episode: 13, Step: 48713, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 48714, Action: 0, Reward: 0.75, Position: 1
# Episode: 13, Step: 48715, Action: 2, Reward: 10.00, Position: 0
# Episode: 13, Step: 48716, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 48717, Action: 0, Reward: 2.00, Position: 1
# Episode: 13, Step: 48718, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 48719, Action: 2, Reward: -6.00, Position: 0
# Episode: 13, Step: 48720, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50067, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 50068, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 50069, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 50070, Action: 2, Reward: -7.00, Position: 0
# Episode: 13, Step: 50071, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50072, Action: 0, Reward: -5.00, Position: -1
# Episode: 13, Step: 50073, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 50074, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 50075, Action: 0, Reward: 0.75, Position: -1
# Episode: 13, Step: 50076, Action: 1, Reward: 17.75, Position: 0
# Episode: 13, Step: 50077, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 50078, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 50079, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50080, Action: 0, Reward: 5.75, Position: -1
# Episode: 13, Step: 50081, Action: 1, Reward: 16.25, Position: 0
# Episode: 13, Step: 50082, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 50083, Action: 1, Reward: 0.00, Position: 1
# Episode: 13, Step: 50084, Action: 2, Reward: -13.50, Position: 0
# Episode: 13, Step: 50085, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 50086, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50087, Action: 1, Reward: 13.75, Position: 0
# Episode: 13, Step: 50088, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 50089, Action: 2, Reward: 9.25, Position: 0
# Episode: 13, Step: 50090, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 50091, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50092, Action: 0, Reward: -8.00, Position: -1
# Episode: 13, Step: 50093, Action: 1, Reward: -2.00, Position: 0
# Episode: 13, Step: 50094, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 50095, Action: 0, Reward: 5.25, Position: -1
# Episode: 13, Step: 50096, Action: 0, Reward: 12.50, Position: -1
# Episode: 13, Step: 50097, Action: 1, Reward: 10.00, Position: 0
# Episode: 13, Step: 51446, Action: 1, Reward: -6.50, Position: 0
# Episode: 13, Step: 51447, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 51448, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51449, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51450, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51451, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51452, Action: 1, Reward: -14.25, Position: 0
# Episode: 13, Step: 51453, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51454, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51455, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 51456, Action: 0, Reward: -8.25, Position: -1
# Episode: 13, Step: 51457, Action: 1, Reward: -4.50, Position: 0
# Episode: 13, Step: 51458, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 51459, Action: 0, Reward: 8.25, Position: -1
# Episode: 13, Step: 51460, Action: 1, Reward: 2.50, Position: 0
# Episode: 13, Step: 51461, Action: 1, Reward: -0.25, Position: 1
# Episode: 13, Step: 51462, Action: 2, Reward: 8.00, Position: 0
# Episode: 13, Step: 51463, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51464, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51465, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 51466, Action: 0, Reward: 3.50, Position: -1
# Episode: 13, Step: 51467, Action: 0, Reward: 0.75, Position: -1
# Episode: 13, Step: 51468, Action: 1, Reward: 4.00, Position: 0
# Episode: 13, Step: 51469, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51470, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51471, Action: 0, Reward: 0.00, Position: 0
# Episode: 13, Step: 51472, Action: 2, Reward: -0.25, Position: -1
# Episode: 13, Step: 51473, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51474, Action: 2, Reward: 0.00, Position: -1
# Episode: 13, Step: 51475, Action: 1, Reward: -4.00, Position: 0
# Episode: 13, Step: 51476, Action: 1, Reward: -0.25, Position: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 198
#     195 batch = random.sample(memory, batch_size)
#     196 states, actions_batch, rewards_batch, next_states, dones = zip(*batch)
# --> 198 states = torch.cat(states).to(device)
#     199 actions_batch = torch.tensor(actions_batch, dtype=torch.long, device=device).unsqueeze(1)
#     200 rewards_batch = torch.tensor(rewards_batch, dtype=torch.float32, device=device).unsqueeze(1)
#
# KeyboardInterrupt:
