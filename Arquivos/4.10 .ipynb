# %%
# Bloco 1: Preparar os Dados
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time
import os
data = pd.read_csv('D:\\dados\\bar_M15_V03_data_01-01-2023_a_31-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])
# filtra o dataframe para pegar apenas o mês de 08 de 2024
#data = data[(data['DateTime'] >= '2024-08-01') & (data['DateTime'] <= '2024-08-31')]

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = [
    'Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior',
    'Corpo', 'Range','SMA4','SMA8','SMA12','SMA20', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK',
    'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram','atr8','atr14','atr28','dayO','dayH','dayL'
]
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None  # Novo atributo para armazenar o DateTime de entrada
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )
        self.trades = []  # Lista para armazenar as operações realizadas
        self.operation_limit = 0  # Variável de controle para limitar operações após perda

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.trades = []
        self.operation_limit = 0  # Resetar a limitação de operações ao resetar o ambiente
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)  # Incluir a posição atual na observação
        return obs.astype(np.float32)

    def step(self, action):
        done = self.current_step >= len(self.data) - 2  # Ajustado para evitar índice fora do intervalo
        reward = 0
        info = {}

        # Obter o valor atual e o próximo valor
        current_price = self.data['Valor'].iloc[self.current_step]
        next_price = self.data['Valor'].iloc[self.current_step + 1]
        price_change = next_price - current_price

        # Obter o valor do gatilho no passo atual
        gatilho = int(self.data['Gatilho'].iloc[self.current_step])

        # Se o gatilho estiver ativo e o agente não estiver limitado por perda anterior
        if gatilho == 1 and self.operation_limit == 0:
            if action == 1:  # Comprar
                if self.position == 0:
                    self.position = 1  # Abrir posição comprada
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == -1:
                    # Fechar posição vendida
                    self.exit_price = current_price
                    profit = self.entry_price - self.exit_price - 0.25  # Ganho da posição vendida
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_short',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    # Registrar a operação
                    self.trades.append({
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    # Resetar posição
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None

                    # Atualizar operation_limit caso a operação tenha dado prejuízo
                    if profit < 0:
                        self.operation_limit = 1

            elif action == 2:  # Vender
                if self.position == 0:
                    self.position = -1  # Abrir posição vendida
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == 1:
                    # Fechar posição comprada
                    self.exit_price = current_price
                    profit = self.exit_price - self.entry_price - 0.25  # Ganho da posição comprada
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_long',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    # Registrar a operação
                    self.trades.append({
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    # Resetar posição
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None

                    # Atualizar operation_limit caso a operação tenha dado prejuízo
                    if profit < 0:
                        self.operation_limit = 1
        elif gatilho == 0:
            # Quando o gatilho for zero, liberar a operação novamente
            self.operation_limit = 0

            # Fechar qualquer posição aberta
            if self.position == 1:  # Fechar posição comprada
                self.exit_price = current_price
                profit = self.exit_price - self.entry_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_long',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'buy',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None
            elif self.position == -1:  # Fechar posição vendida
                self.exit_price = current_price
                profit = self.entry_price - self.exit_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_short',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'sell',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None

        # Atualizar o passo atual
        self.current_step += 1

        obs = self._next_observation()
        return obs, reward, done, info


# Bloco 3: Criar o Agente DQN usando PyTorch

import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Definir a rede DQN
class DQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(DQN, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions)
        )

    def forward(self, x):
        return self.model(x)

# Instanciar a rede
q_net = DQN(obs_size, n_actions).to(device)
target_net = DQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=1e-4)

# Hiperparâmetros para DQN
memory_size = 10000
batch_size = 64
gamma = 0.99
epsilon_start = 0.5
epsilon_end = 0.05
epsilon_decay = 0.99
target_update = 10  # Atualizar a rede alvo a cada 10 episódios

# Inicializar a memória de replay
memory = collections.deque(maxlen=memory_size)

# Função para selecionar ação usando epsilon-greedy
def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.choice([0, 1, 2])
    else:
        with torch.no_grad():
            q_values = q_net(state)
            return q_values.argmax().item()

# Bloco 4: Treinamento do Agente DQN com Salvamento dos Melhores Episódios Após Cada Episódio

num_episodes = 100  # Defina o número de episódios de treinamento
epsilon = epsilon_start
best_episodes = []

save_dir = "4.10"
os.makedirs(save_dir, exist_ok=True)

for episode in range(num_episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0
    trades = []
    current_trade = None

    while not done:
        steps += 1

        # Selecionar ação
        action = select_action(obs, epsilon)

        # Executar ação no ambiente
        obs_next, reward, done, info = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        memory.append((obs, action, reward, obs_next, done))

        # Atualizar o estado
        obs = obs_next

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Processar informações de trade
        if 'trade' in info:
            trade_info = info['trade']
            if trade_info['type'] in ['buy', 'sell']:
                # Início de uma nova operação
                current_trade = {
                    'type': trade_info['type'],
                    'entry_step': trade_info['entry_step'],
                    'entry_price': trade_info['entry_price'],
                    'entry_datetime': trade_info['entry_datetime'],
                    'exit_step': None,
                    'exit_price': None,
                    'exit_datetime': None,
                    'profit': None
                }
            elif trade_info['type'] in ['close_long', 'close_short']:
                # Fechamento de uma operação existente
                current_trade['exit_step'] = trade_info['exit_step']
                current_trade['exit_price'] = trade_info['exit_price']
                current_trade['exit_datetime'] = trade_info['exit_datetime']
                current_trade['profit'] = trade_info['profit']
                trades.append(current_trade.copy())
                # Atualizar ganhos e perdas
                if current_trade['profit'] > 0:
                    wins += 1
                    win_total += current_trade['profit']
                elif current_trade['profit'] < 0:
                    losses += 1
                    lose_total += current_trade['profit']
                # Atualizar recompensa total
                total_reward += current_trade['profit']
                current_trade = None

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(memory) >= batch_size:
            batch = random.sample(memory, batch_size)
            states, actions_batch, rewards_batch, next_states, dones = zip(*batch)

            states = torch.cat(states).to(device)
            actions_batch = torch.tensor(actions_batch, dtype=torch.long, device=device).unsqueeze(1)
            rewards_batch = torch.tensor(rewards_batch, dtype=torch.float32, device=device).unsqueeze(1)
            next_states = torch.cat(next_states).to(device)
            dones = torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando a rede alvo
            with torch.no_grad():
                next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
            target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular a perda
            loss = nn.MSELoss()(q_values, target_q_values)

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Decaimento de epsilon
    epsilon = max(epsilon_end, epsilon_decay * epsilon)

    # Atualizar a rede alvo
    if episode % target_update == 0:
        target_net.load_state_dict(q_net.state_dict())

    # Cálculo do tempo de treinamento do episódio
    end_time = time.time()
    episode_time = end_time - start_time

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, "
          f"Wins: {wins}, Losses: {losses}, Epsilon: {epsilon:.4f}, Steps: {steps}, Time: {episode_time:.2f}s")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}")

    # Salvar informações do episódio
    episode_info = {
        'episode': episode + 1,
        'total_reward': total_reward,
        'win_rate': win_rate,
        'wins': wins,
        'losses': losses,
        'actions_count': actions_count.copy(),
        'win_total': win_total,
        'lose_total': lose_total,
        'steps': steps,
        'episode_time': episode_time,
        'model_state_dict': q_net.state_dict(),
        'trades': trades.copy()  # Salvar as operações do episódio
    }

    # Adicionar o episódio à lista e manter os top 10
    best_episodes.append(episode_info)
    best_episodes = sorted(best_episodes, key=lambda x: x['total_reward'], reverse=True)[:10]

    # Salvar o modelo e log se o episódio for um dos top 10
    if episode_info in best_episodes:
        model_path = os.path.join(save_dir, f"model_episode_{episode_info['episode']}.pth")
        torch.save(episode_info['model_state_dict'], model_path)
        episode_info['model_path'] = model_path

        # Salvar o log completo das operações
        log_path = os.path.join(save_dir, f"log_episode_{episode_info['episode']}.csv")
        trades_df = pd.DataFrame(episode_info['trades'])
        trades_df.to_csv(log_path, index=False)
        episode_info['log_path'] = log_path

        print(f"Modelo e log do episódio {episode_info['episode']} salvos em: {model_path} e {log_path}\n")

print("\nTreinamento finalizado.")
print("Top 10 Melhores Episódios:")
for idx, ep in enumerate(best_episodes, 1):
    print(f"Rank {idx}: Episode {ep['episode']}, Total Reward: {ep['total_reward']:.2f}, "
          f"Win Rate: {ep['win_rate']:.2f}, Wins: {ep['wins']}, Losses: {ep['losses']}, "
          f"Ações: {ep['actions_count']}, Steps: {ep['steps']}, Time: {ep['episode_time']:.2f}s")
# Out:
# Episode 1/100, Total Reward: -2453.25, Win Rate: 0.47, Wins: 370, Losses: 421, Epsilon: 0.4950, Steps: 36754, Time: 176.85s
# Ações: Manter=11697, Comprar=12387, Vender=12670
# Ganhos Totais: 7653.75, Perdas Totais: -10107.00
# Modelo e log do episódio 1 salvos em: 4.10\model_episode_1.pth e 4.10\log_episode_1.csv
#
# Episode 2/100, Total Reward: -1812.00, Win Rate: 0.47, Wins: 367, Losses: 419, Epsilon: 0.4900, Steps: 36754, Time: 182.10s
# Ações: Manter=11517, Comprar=12353, Vender=12884
# Ganhos Totais: 8106.25, Perdas Totais: -9918.25
# Modelo e log do episódio 2 salvos em: 4.10\model_episode_2.pth e 4.10\log_episode_2.csv
#
# Episode 3/100, Total Reward: 1262.25, Win Rate: 0.53, Wins: 459, Losses: 414, Epsilon: 0.4851, Steps: 36754, Time: 168.48s
# Ações: Manter=12033, Comprar=13029, Vender=11692
# Ganhos Totais: 10456.75, Perdas Totais: -9194.50
# Modelo e log do episódio 3 salvos em: 4.10\model_episode_3.pth e 4.10\log_episode_3.csv
#
# Episode 4/100, Total Reward: 367.25, Win Rate: 0.48, Wins: 393, Losses: 424, Epsilon: 0.4803, Steps: 36754, Time: 163.77s
# Ações: Manter=11698, Comprar=12784, Vender=12272
# Ganhos Totais: 8165.00, Perdas Totais: -7797.75
# Modelo e log do episódio 4 salvos em: 4.10\model_episode_4.pth e 4.10\log_episode_4.csv
#
# Episode 5/100, Total Reward: -388.25, Win Rate: 0.49, Wins: 402, Losses: 419, Epsilon: 0.4755, Steps: 36754, Time: 160.91s
# Ações: Manter=11453, Comprar=12214, Vender=13087
# Ganhos Totais: 7941.75, Perdas Totais: -8330.00
# Modelo e log do episódio 5 salvos em: 4.10\model_episode_5.pth e 4.10\log_episode_5.csv
#
# Episode 6/100, Total Reward: -629.75, Win Rate: 0.50, Wins: 427, Losses: 419, Epsilon: 0.4707, Steps: 36754, Time: 158.53s
# Ações: Manter=12402, Comprar=12057, Vender=12295
# Ganhos Totais: 8861.75, Perdas Totais: -9491.50
# Modelo e log do episódio 6 salvos em: 4.10\model_episode_6.pth e 4.10\log_episode_6.csv
#
# Episode 7/100, Total Reward: 668.00, Win Rate: 0.49, Wins: 408, Losses: 422, Epsilon: 0.4660, Steps: 36754, Time: 157.38s
# Ações: Manter=12827, Comprar=12414, Vender=11513
# Ganhos Totais: 8753.25, Perdas Totais: -8085.25
# Modelo e log do episódio 7 salvos em: 4.10\model_episode_7.pth e 4.10\log_episode_7.csv
#
# Episode 8/100, Total Reward: 279.25, Win Rate: 0.49, Wins: 402, Losses: 425, Epsilon: 0.4614, Steps: 36754, Time: 161.66s
# Ações: Manter=11191, Comprar=13187, Vender=12376
# Ganhos Totais: 8220.50, Perdas Totais: -7941.25
# Modelo e log do episódio 8 salvos em: 4.10\model_episode_8.pth e 4.10\log_episode_8.csv
#
# Episode 9/100, Total Reward: -1121.00, Win Rate: 0.51, Wins: 429, Losses: 415, Epsilon: 0.4568, Steps: 36754, Time: 159.68s
# Ações: Manter=11963, Comprar=12464, Vender=12327
# Ganhos Totais: 9087.50, Perdas Totais: -10208.50
# Modelo e log do episódio 9 salvos em: 4.10\model_episode_9.pth e 4.10\log_episode_9.csv
#
# Episode 10/100, Total Reward: -847.00, Win Rate: 0.50, Wins: 425, Losses: 418, Epsilon: 0.4522, Steps: 36754, Time: 158.29s
# Ações: Manter=12175, Comprar=12463, Vender=12116
# Ganhos Totais: 8660.25, Perdas Totais: -9507.25
# Modelo e log do episódio 10 salvos em: 4.10\model_episode_10.pth e 4.10\log_episode_10.csv
#
# Episode 11/100, Total Reward: -852.75, Win Rate: 0.49, Wins: 401, Losses: 418, Epsilon: 0.4477, Steps: 36754, Time: 138.82s
# Ações: Manter=12081, Comprar=11363, Vender=13310
# Ganhos Totais: 8158.75, Perdas Totais: -9011.50
# Modelo e log do episódio 11 salvos em: 4.10\model_episode_11.pth e 4.10\log_episode_11.csv
#
# Episode 12/100, Total Reward: -1808.75, Win Rate: 0.50, Wins: 415, Losses: 419, Epsilon: 0.4432, Steps: 36754, Time: 120.25s
# Ações: Manter=12592, Comprar=11913, Vender=12249
# Ganhos Totais: 8077.75, Perdas Totais: -9886.50
# Modelo e log do episódio 12 salvos em: 4.10\model_episode_12.pth e 4.10\log_episode_12.csv
#
# Episode 13/100, Total Reward: -1557.50, Win Rate: 0.46, Wins: 358, Losses: 424, Epsilon: 0.4388, Steps: 36754, Time: 123.80s
# Ações: Manter=11599, Comprar=12158, Vender=12997
# Ganhos Totais: 7502.50, Perdas Totais: -9060.00
# Modelo e log do episódio 13 salvos em: 4.10\model_episode_13.pth e 4.10\log_episode_13.csv
#
# Episode 14/100, Total Reward: 191.25, Win Rate: 0.49, Wins: 394, Losses: 415, Epsilon: 0.4344, Steps: 36754, Time: 131.44s
# Ações: Manter=12608, Comprar=12477, Vender=11669
# Ganhos Totais: 8734.25, Perdas Totais: -8543.00
# Modelo e log do episódio 14 salvos em: 4.10\model_episode_14.pth e 4.10\log_episode_14.csv
#
# Episode 15/100, Total Reward: -597.00, Win Rate: 0.50, Wins: 422, Losses: 420, Epsilon: 0.4300, Steps: 36754, Time: 121.99s
# Ações: Manter=11740, Comprar=12702, Vender=12312
# Ganhos Totais: 8097.50, Perdas Totais: -8694.50
# Modelo e log do episódio 15 salvos em: 4.10\model_episode_15.pth e 4.10\log_episode_15.csv
#
# Episode 16/100, Total Reward: -194.00, Win Rate: 0.50, Wins: 422, Losses: 419, Epsilon: 0.4257, Steps: 36754, Time: 121.70s
# Ações: Manter=11343, Comprar=12218, Vender=13193
# Ganhos Totais: 8611.00, Perdas Totais: -8805.00
# Modelo e log do episódio 16 salvos em: 4.10\model_episode_16.pth e 4.10\log_episode_16.csv
#
# Episode 17/100, Total Reward: 203.50, Win Rate: 0.51, Wins: 439, Losses: 418, Epsilon: 0.4215, Steps: 36754, Time: 121.71s
# Ações: Manter=13185, Comprar=12326, Vender=11243
# Ganhos Totais: 9411.50, Perdas Totais: -9208.00
# Modelo e log do episódio 17 salvos em: 4.10\model_episode_17.pth e 4.10\log_episode_17.csv
#
# Episode 18/100, Total Reward: -239.25, Win Rate: 0.51, Wins: 431, Losses: 415, Epsilon: 0.4173, Steps: 36754, Time: 121.65s
# Ações: Manter=12462, Comprar=11556, Vender=12736
# Ganhos Totais: 9020.75, Perdas Totais: -9260.00
# Modelo e log do episódio 18 salvos em: 4.10\model_episode_18.pth e 4.10\log_episode_18.csv
#
# Episode 19/100, Total Reward: 1527.50, Win Rate: 0.51, Wins: 421, Losses: 411, Epsilon: 0.4131, Steps: 36754, Time: 121.65s
# Ações: Manter=11877, Comprar=11561, Vender=13316
# Ganhos Totais: 9430.25, Perdas Totais: -7902.75
# Modelo e log do episódio 19 salvos em: 4.10\model_episode_19.pth e 4.10\log_episode_19.csv
#
# Episode 20/100, Total Reward: -2702.00, Win Rate: 0.47, Wins: 366, Losses: 417, Epsilon: 0.4090, Steps: 36754, Time: 121.95s
# Ações: Manter=12511, Comprar=10331, Vender=13912
# Ganhos Totais: 8272.00, Perdas Totais: -10974.00
# Episode 21/100, Total Reward: 1892.50, Win Rate: 0.54, Wins: 483, Losses: 414, Epsilon: 0.4049, Steps: 36754, Time: 121.84s
# Ações: Manter=11533, Comprar=11679, Vender=13542
# Ganhos Totais: 10637.50, Perdas Totais: -8745.00
# Modelo e log do episódio 21 salvos em: 4.10\model_episode_21.pth e 4.10\log_episode_21.csv
#
# Episode 22/100, Total Reward: 1681.75, Win Rate: 0.52, Wins: 443, Losses: 412, Epsilon: 0.4008, Steps: 36754, Time: 122.38s
# Ações: Manter=13345, Comprar=11175, Vender=12234
# Ganhos Totais: 10494.25, Perdas Totais: -8812.50
# Modelo e log do episódio 22 salvos em: 4.10\model_episode_22.pth e 4.10\log_episode_22.csv
#
# Episode 23/100, Total Reward: 100.25, Win Rate: 0.50, Wins: 417, Losses: 418, Epsilon: 0.3968, Steps: 36754, Time: 122.32s
# Ações: Manter=12823, Comprar=12477, Vender=11454
# Ganhos Totais: 8418.00, Perdas Totais: -8317.75
# Modelo e log do episódio 23 salvos em: 4.10\model_episode_23.pth e 4.10\log_episode_23.csv
#
# Episode 24/100, Total Reward: 1773.25, Win Rate: 0.49, Wins: 403, Losses: 419, Epsilon: 0.3928, Steps: 36754, Time: 122.70s
# Ações: Manter=10676, Comprar=13821, Vender=12257
# Ganhos Totais: 9394.25, Perdas Totais: -7621.00
# Modelo e log do episódio 24 salvos em: 4.10\model_episode_24.pth e 4.10\log_episode_24.csv
#
# Episode 25/100, Total Reward: 662.25, Win Rate: 0.52, Wins: 439, Losses: 411, Epsilon: 0.3889, Steps: 36754, Time: 122.47s
# Ações: Manter=12329, Comprar=12076, Vender=12349
# Ganhos Totais: 10045.75, Perdas Totais: -9383.50
# Modelo e log do episódio 25 salvos em: 4.10\model_episode_25.pth e 4.10\log_episode_25.csv
#
# Episode 26/100, Total Reward: -391.50, Win Rate: 0.49, Wins: 402, Losses: 418, Epsilon: 0.3850, Steps: 36754, Time: 122.21s
# Ações: Manter=11059, Comprar=11734, Vender=13961
# Ganhos Totais: 8551.75, Perdas Totais: -8943.25
# Episode 27/100, Total Reward: 1035.00, Win Rate: 0.48, Wins: 387, Losses: 416, Epsilon: 0.3812, Steps: 36754, Time: 122.78s
# Ações: Manter=11762, Comprar=14096, Vender=10896
# Ganhos Totais: 9528.00, Perdas Totais: -8493.00
# Modelo e log do episódio 27 salvos em: 4.10\model_episode_27.pth e 4.10\log_episode_27.csv
#
# Episode 28/100, Total Reward: -577.75, Win Rate: 0.51, Wins: 434, Losses: 416, Epsilon: 0.3774, Steps: 36754, Time: 122.33s
# Ações: Manter=12154, Comprar=12989, Vender=11611
# Ganhos Totais: 8779.75, Perdas Totais: -9357.50
# Episode 29/100, Total Reward: -1103.25, Win Rate: 0.51, Wins: 416, Losses: 406, Epsilon: 0.3736, Steps: 36754, Time: 122.70s
# Ações: Manter=11646, Comprar=13657, Vender=11451
# Ganhos Totais: 9375.75, Perdas Totais: -10479.00
# Episode 30/100, Total Reward: 1341.25, Win Rate: 0.52, Wins: 450, Losses: 412, Epsilon: 0.3699, Steps: 36754, Time: 122.67s
# Ações: Manter=12047, Comprar=12043, Vender=12664
# Ganhos Totais: 11029.00, Perdas Totais: -9687.75
# Modelo e log do episódio 30 salvos em: 4.10\model_episode_30.pth e 4.10\log_episode_30.csv
#
# Episode 31/100, Total Reward: -688.75, Win Rate: 0.50, Wins: 408, Losses: 411, Epsilon: 0.3662, Steps: 36754, Time: 122.68s
# Ações: Manter=11497, Comprar=12782, Vender=12475
# Ganhos Totais: 8427.25, Perdas Totais: -9116.00
# Episode 32/100, Total Reward: -700.00, Win Rate: 0.49, Wins: 387, Losses: 400, Epsilon: 0.3625, Steps: 36754, Time: 123.00s
# Ações: Manter=13534, Comprar=11751, Vender=11469
# Ganhos Totais: 8792.25, Perdas Totais: -9492.25
# Episode 33/100, Total Reward: -34.25, Win Rate: 0.50, Wins: 417, Losses: 415, Epsilon: 0.3589, Steps: 36754, Time: 122.83s
# Ações: Manter=11826, Comprar=13049, Vender=11879
# Ganhos Totais: 9526.25, Perdas Totais: -9560.50
# Episode 34/100, Total Reward: 490.75, Win Rate: 0.52, Wins: 446, Losses: 414, Epsilon: 0.3553, Steps: 36754, Time: 122.91s
# Ações: Manter=10433, Comprar=13700, Vender=12621
# Ganhos Totais: 9528.00, Perdas Totais: -9037.25
# Modelo e log do episódio 34 salvos em: 4.10\model_episode_34.pth e 4.10\log_episode_34.csv
#
# Episode 35/100, Total Reward: -126.25, Win Rate: 0.49, Wins: 399, Losses: 411, Epsilon: 0.3517, Steps: 36754, Time: 122.50s
# Ações: Manter=13251, Comprar=12700, Vender=10803
# Ganhos Totais: 9223.25, Perdas Totais: -9349.50
# Episode 36/100, Total Reward: 2079.25, Win Rate: 0.52, Wins: 449, Losses: 413, Epsilon: 0.3482, Steps: 36754, Time: 122.92s
# Ações: Manter=11797, Comprar=13755, Vender=11202
# Ganhos Totais: 10979.00, Perdas Totais: -8899.75
# Modelo e log do episódio 36 salvos em: 4.10\model_episode_36.pth e 4.10\log_episode_36.csv
#
# Episode 37/100, Total Reward: 1701.00, Win Rate: 0.53, Wins: 454, Losses: 409, Epsilon: 0.3447, Steps: 36754, Time: 122.66s
# Ações: Manter=14445, Comprar=11204, Vender=11105
# Ganhos Totais: 11362.75, Perdas Totais: -9661.75
# Modelo e log do episódio 37 salvos em: 4.10\model_episode_37.pth e 4.10\log_episode_37.csv
#
# Episode 38/100, Total Reward: -384.00, Win Rate: 0.51, Wins: 430, Losses: 410, Epsilon: 0.3413, Steps: 36754, Time: 122.54s
# Ações: Manter=13003, Comprar=11100, Vender=12651
# Ganhos Totais: 10698.25, Perdas Totais: -11082.25
# Episode 39/100, Total Reward: -1794.00, Win Rate: 0.50, Wins: 409, Losses: 416, Epsilon: 0.3379, Steps: 36754, Time: 122.62s
# Ações: Manter=10717, Comprar=12446, Vender=13591
# Ganhos Totais: 8922.75, Perdas Totais: -10716.75
# Episode 40/100, Total Reward: -1573.50, Win Rate: 0.46, Wins: 351, Losses: 417, Epsilon: 0.3345, Steps: 36754, Time: 123.06s
# Ações: Manter=11698, Comprar=12571, Vender=12485
# Ganhos Totais: 7941.25, Perdas Totais: -9514.75
# Episode 41/100, Total Reward: -1296.50, Win Rate: 0.51, Wins: 424, Losses: 409, Epsilon: 0.3311, Steps: 36754, Time: 123.09s
# Ações: Manter=12824, Comprar=13793, Vender=10137
# Ganhos Totais: 9725.50, Perdas Totais: -11022.00
# Episode 42/100, Total Reward: 1511.25, Win Rate: 0.54, Wins: 490, Losses: 414, Epsilon: 0.3278, Steps: 36754, Time: 123.06s
# Ações: Manter=11780, Comprar=12131, Vender=12843
# Ganhos Totais: 11161.00, Perdas Totais: -9649.75
# Modelo e log do episódio 42 salvos em: 4.10\model_episode_42.pth e 4.10\log_episode_42.csv
#
# Episode 43/100, Total Reward: -933.50, Win Rate: 0.51, Wins: 430, Losses: 413, Epsilon: 0.3246, Steps: 36754, Time: 123.16s
# Ações: Manter=11830, Comprar=12126, Vender=12798
# Ganhos Totais: 9802.00, Perdas Totais: -10735.50
# Episode 44/100, Total Reward: -417.75, Win Rate: 0.52, Wins: 447, Losses: 406, Epsilon: 0.3213, Steps: 36754, Time: 122.90s
# Ações: Manter=12561, Comprar=12314, Vender=11879
# Ganhos Totais: 10275.50, Perdas Totais: -10693.25
# Episode 45/100, Total Reward: -774.25, Win Rate: 0.50, Wins: 409, Losses: 410, Epsilon: 0.3181, Steps: 36754, Time: 123.03s
# Ações: Manter=12423, Comprar=12898, Vender=11433
# Ganhos Totais: 10447.75, Perdas Totais: -11222.00
# Episode 46/100, Total Reward: 1851.00, Win Rate: 0.50, Wins: 412, Losses: 408, Epsilon: 0.3149, Steps: 36754, Time: 123.28s
# Ações: Manter=12506, Comprar=12525, Vender=11723
# Ganhos Totais: 10687.50, Perdas Totais: -8836.50
# Modelo e log do episódio 46 salvos em: 4.10\model_episode_46.pth e 4.10\log_episode_46.csv
#
# Episode 47/100, Total Reward: -384.50, Win Rate: 0.51, Wins: 429, Losses: 417, Epsilon: 0.3118, Steps: 36754, Time: 124.88s
# Ações: Manter=10764, Comprar=13245, Vender=12745
# Ganhos Totais: 10709.00, Perdas Totais: -11093.50
# Episode 48/100, Total Reward: -1742.00, Win Rate: 0.50, Wins: 409, Losses: 413, Epsilon: 0.3086, Steps: 36754, Time: 123.44s
# Ações: Manter=11972, Comprar=13625, Vender=11157
# Ganhos Totais: 9067.75, Perdas Totais: -10809.75
# Episode 49/100, Total Reward: 949.25, Win Rate: 0.50, Wins: 405, Losses: 409, Epsilon: 0.3056, Steps: 36754, Time: 123.22s
# Ações: Manter=11613, Comprar=12541, Vender=12600
# Ganhos Totais: 10539.50, Perdas Totais: -9590.25
# Episode 50/100, Total Reward: -1397.25, Win Rate: 0.49, Wins: 395, Losses: 409, Epsilon: 0.3025, Steps: 36754, Time: 123.63s
# Ações: Manter=12528, Comprar=11446, Vender=12780
# Ganhos Totais: 8414.50, Perdas Totais: -9811.75
# Episode 51/100, Total Reward: 542.75, Win Rate: 0.53, Wins: 455, Losses: 408, Epsilon: 0.2995, Steps: 36754, Time: 123.67s
# Ações: Manter=13194, Comprar=11163, Vender=12397
# Ganhos Totais: 11685.50, Perdas Totais: -11142.75
# Episode 52/100, Total Reward: -1681.75, Win Rate: 0.48, Wins: 382, Losses: 414, Epsilon: 0.2965, Steps: 36754, Time: 123.73s
# Ações: Manter=11164, Comprar=12525, Vender=13065
# Ganhos Totais: 8837.25, Perdas Totais: -10519.00
# Episode 53/100, Total Reward: 1484.25, Win Rate: 0.53, Wins: 460, Losses: 408, Epsilon: 0.2935, Steps: 36754, Time: 123.85s
# Ações: Manter=12034, Comprar=12646, Vender=12074
# Ganhos Totais: 10865.75, Perdas Totais: -9381.50
# Modelo e log do episódio 53 salvos em: 4.10\model_episode_53.pth e 4.10\log_episode_53.csv
#
# Episode 54/100, Total Reward: -1145.25, Win Rate: 0.49, Wins: 401, Losses: 415, Epsilon: 0.2906, Steps: 36754, Time: 123.62s
# Ações: Manter=11805, Comprar=12155, Vender=12794
# Ganhos Totais: 9067.50, Perdas Totais: -10212.75
# Episode 55/100, Total Reward: -307.50, Win Rate: 0.50, Wins: 418, Losses: 411, Epsilon: 0.2877, Steps: 36754, Time: 123.75s
# Ações: Manter=12263, Comprar=12303, Vender=12188
# Ganhos Totais: 9716.50, Perdas Totais: -10024.00
# Episode 56/100, Total Reward: 1327.25, Win Rate: 0.53, Wins: 464, Losses: 405, Epsilon: 0.2848, Steps: 36754, Time: 124.15s
# Ações: Manter=11842, Comprar=10664, Vender=14248
# Ganhos Totais: 12151.50, Perdas Totais: -10824.25
# Episode 57/100, Total Reward: -2219.50, Win Rate: 0.47, Wins: 363, Losses: 410, Epsilon: 0.2820, Steps: 36754, Time: 124.36s
# Ações: Manter=13051, Comprar=12045, Vender=11658
# Ganhos Totais: 8712.00, Perdas Totais: -10931.50
# Episode 58/100, Total Reward: -760.00, Win Rate: 0.49, Wins: 390, Losses: 407, Epsilon: 0.2791, Steps: 36754, Time: 124.08s
# Ações: Manter=13363, Comprar=11078, Vender=12313
# Ganhos Totais: 10175.50, Perdas Totais: -10935.50
# Episode 59/100, Total Reward: -877.75, Win Rate: 0.49, Wins: 397, Losses: 416, Epsilon: 0.2763, Steps: 36754, Time: 124.24s
# Ações: Manter=11446, Comprar=12279, Vender=13029
# Ganhos Totais: 9098.00, Perdas Totais: -9975.75
# Episode 60/100, Total Reward: -863.00, Win Rate: 0.50, Wins: 404, Losses: 409, Epsilon: 0.2736, Steps: 36754, Time: 124.22s
# Ações: Manter=12262, Comprar=12379, Vender=12113
# Ganhos Totais: 9461.50, Perdas Totais: -10324.50
# Episode 61/100, Total Reward: 884.50, Win Rate: 0.52, Wins: 439, Losses: 407, Epsilon: 0.2708, Steps: 36754, Time: 124.33s
# Ações: Manter=12540, Comprar=11368, Vender=12846
# Ganhos Totais: 11829.50, Perdas Totais: -10945.00
# Episode 62/100, Total Reward: 858.50, Win Rate: 0.51, Wins: 420, Losses: 406, Epsilon: 0.2681, Steps: 36754, Time: 124.46s
# Ações: Manter=14249, Comprar=10859, Vender=11646
# Ganhos Totais: 12193.50, Perdas Totais: -11335.00
# Episode 63/100, Total Reward: 322.75, Win Rate: 0.49, Wins: 385, Losses: 406, Epsilon: 0.2655, Steps: 36754, Time: 124.61s
# Ações: Manter=13815, Comprar=10583, Vender=12356
# Ganhos Totais: 10082.75, Perdas Totais: -9760.00
# Episode 64/100, Total Reward: -742.50, Win Rate: 0.52, Wins: 443, Losses: 415, Epsilon: 0.2628, Steps: 36754, Time: 124.60s
# Ações: Manter=11091, Comprar=12399, Vender=13264
# Ganhos Totais: 10498.75, Perdas Totais: -11241.25
# Episode 65/100, Total Reward: -10.75, Win Rate: 0.50, Wins: 404, Losses: 404, Epsilon: 0.2602, Steps: 36754, Time: 124.24s
# Ações: Manter=13910, Comprar=10594, Vender=12250
# Ganhos Totais: 10394.50, Perdas Totais: -10405.25
# Episode 66/100, Total Reward: -3352.25, Win Rate: 0.49, Wins: 383, Losses: 402, Epsilon: 0.2576, Steps: 36754, Time: 124.49s
# Ações: Manter=11276, Comprar=9013, Vender=16465
# Ganhos Totais: 9605.50, Perdas Totais: -12957.75
# Episode 67/100, Total Reward: 189.25, Win Rate: 0.55, Wins: 489, Losses: 404, Epsilon: 0.2550, Steps: 36754, Time: 124.46s
# Ações: Manter=10954, Comprar=10474, Vender=15326
# Ganhos Totais: 12299.00, Perdas Totais: -12109.75
# Episode 68/100, Total Reward: -557.75, Win Rate: 0.54, Wins: 475, Losses: 406, Epsilon: 0.2524, Steps: 36754, Time: 124.32s
# Ações: Manter=12226, Comprar=12548, Vender=11980
# Ganhos Totais: 11241.00, Perdas Totais: -11798.75
# Episode 69/100, Total Reward: 397.50, Win Rate: 0.51, Wins: 415, Losses: 397, Epsilon: 0.2499, Steps: 36754, Time: 124.70s
# Ações: Manter=12367, Comprar=12189, Vender=12198
# Ganhos Totais: 10600.50, Perdas Totais: -10203.00
# Episode 70/100, Total Reward: -98.25, Win Rate: 0.54, Wins: 469, Losses: 404, Epsilon: 0.2474, Steps: 36754, Time: 124.43s
# Ações: Manter=12936, Comprar=12987, Vender=10831
# Ganhos Totais: 11782.50, Perdas Totais: -11880.75
# Episode 71/100, Total Reward: -792.25, Win Rate: 0.52, Wins: 445, Losses: 417, Epsilon: 0.2449, Steps: 36754, Time: 125.21s
# Ações: Manter=12190, Comprar=11646, Vender=12918
# Ganhos Totais: 9666.00, Perdas Totais: -10458.25
# Episode 72/100, Total Reward: 781.25, Win Rate: 0.54, Wins: 465, Losses: 404, Epsilon: 0.2425, Steps: 36754, Time: 124.50s
# Ações: Manter=12103, Comprar=12049, Vender=12602
# Ganhos Totais: 11159.25, Perdas Totais: -10378.00
# Episode 73/100, Total Reward: 344.00, Win Rate: 0.51, Wins: 419, Losses: 399, Epsilon: 0.2401, Steps: 36754, Time: 124.70s
# Ações: Manter=15958, Comprar=10852, Vender=9944
# Ganhos Totais: 11906.75, Perdas Totais: -11562.75
# Episode 74/100, Total Reward: 2884.50, Win Rate: 0.52, Wins: 442, Losses: 406, Epsilon: 0.2377, Steps: 36754, Time: 124.68s
# Ações: Manter=13663, Comprar=11696, Vender=11395
# Ganhos Totais: 12787.25, Perdas Totais: -9902.75
# Modelo e log do episódio 74 salvos em: 4.10\model_episode_74.pth e 4.10\log_episode_74.csv
#
# Episode 75/100, Total Reward: -1746.25, Win Rate: 0.51, Wins: 437, Losses: 412, Epsilon: 0.2353, Steps: 36754, Time: 125.22s
# Ações: Manter=15196, Comprar=9543, Vender=12015
# Ganhos Totais: 10365.00, Perdas Totais: -12111.25
# Episode 76/100, Total Reward: 1677.75, Win Rate: 0.53, Wins: 461, Losses: 409, Epsilon: 0.2329, Steps: 36754, Time: 125.39s
# Ações: Manter=12938, Comprar=12818, Vender=10998
# Ganhos Totais: 12794.25, Perdas Totais: -11116.50
# Modelo e log do episódio 76 salvos em: 4.10\model_episode_76.pth e 4.10\log_episode_76.csv
#
# Episode 77/100, Total Reward: -1583.50, Win Rate: 0.48, Wins: 377, Losses: 413, Epsilon: 0.2306, Steps: 36754, Time: 125.03s
# Ações: Manter=15579, Comprar=10587, Vender=10588
# Ganhos Totais: 9644.25, Perdas Totais: -11227.75
# Episode 78/100, Total Reward: 245.75, Win Rate: 0.51, Wins: 425, Losses: 410, Epsilon: 0.2283, Steps: 36754, Time: 124.78s
# Ações: Manter=10963, Comprar=12600, Vender=13191
# Ganhos Totais: 9725.25, Perdas Totais: -9479.50
# Episode 79/100, Total Reward: 885.00, Win Rate: 0.51, Wins: 429, Losses: 407, Epsilon: 0.2260, Steps: 36754, Time: 124.83s
# Ações: Manter=11442, Comprar=10902, Vender=14410
# Ganhos Totais: 12223.75, Perdas Totais: -11338.75
# Episode 80/100, Total Reward: 691.00, Win Rate: 0.51, Wins: 434, Losses: 409, Epsilon: 0.2238, Steps: 36754, Time: 124.82s
# Ações: Manter=10847, Comprar=12956, Vender=12951
# Ganhos Totais: 10365.75, Perdas Totais: -9674.75
# Episode 81/100, Total Reward: -1029.50, Win Rate: 0.51, Wins: 414, Losses: 405, Epsilon: 0.2215, Steps: 36754, Time: 124.76s
# Ações: Manter=14463, Comprar=11275, Vender=11016
# Ganhos Totais: 10922.00, Perdas Totais: -11951.50
# Episode 82/100, Total Reward: -55.25, Win Rate: 0.50, Wins: 402, Losses: 402, Epsilon: 0.2193, Steps: 36754, Time: 124.74s
# Ações: Manter=13328, Comprar=10007, Vender=13419
# Ganhos Totais: 11451.50, Perdas Totais: -11506.75
# Episode 83/100, Total Reward: -1693.25, Win Rate: 0.51, Wins: 420, Losses: 410, Epsilon: 0.2171, Steps: 36754, Time: 124.59s
# Ações: Manter=13587, Comprar=12107, Vender=11060
# Ganhos Totais: 10041.25, Perdas Totais: -11734.50
# Episode 84/100, Total Reward: 525.25, Win Rate: 0.51, Wins: 422, Losses: 407, Epsilon: 0.2149, Steps: 36754, Time: 124.65s
# Ações: Manter=14587, Comprar=11122, Vender=11045
# Ganhos Totais: 11242.75, Perdas Totais: -10717.50
# Episode 85/100, Total Reward: 1467.50, Win Rate: 0.53, Wins: 452, Losses: 406, Epsilon: 0.2128, Steps: 36754, Time: 125.45s
# Ações: Manter=11575, Comprar=11105, Vender=14074
# Ganhos Totais: 11672.50, Perdas Totais: -10205.00
# Episode 86/100, Total Reward: -682.00, Win Rate: 0.49, Wins: 398, Losses: 410, Epsilon: 0.2107, Steps: 36754, Time: 124.75s
# Ações: Manter=12071, Comprar=13051, Vender=11632
# Ganhos Totais: 9276.00, Perdas Totais: -9958.00
# Episode 87/100, Total Reward: -1328.00, Win Rate: 0.48, Wins: 382, Losses: 406, Epsilon: 0.2086, Steps: 36754, Time: 124.78s
# Ações: Manter=12788, Comprar=9506, Vender=14460
# Ganhos Totais: 9829.75, Perdas Totais: -11157.75
# Episode 88/100, Total Reward: 943.75, Win Rate: 0.51, Wins: 425, Losses: 404, Epsilon: 0.2065, Steps: 36754, Time: 129.72s
# Ações: Manter=13370, Comprar=10695, Vender=12689
# Ganhos Totais: 11748.75, Perdas Totais: -10805.00
# Episode 89/100, Total Reward: -2044.25, Win Rate: 0.53, Wins: 439, Losses: 392, Epsilon: 0.2044, Steps: 36754, Time: 125.47s
# Ações: Manter=14349, Comprar=10424, Vender=11981
# Ganhos Totais: 10042.50, Perdas Totais: -12086.75
# Episode 90/100, Total Reward: -1042.50, Win Rate: 0.50, Wins: 401, Losses: 399, Epsilon: 0.2024, Steps: 36754, Time: 124.28s
# Ações: Manter=14359, Comprar=9301, Vender=13094
# Ganhos Totais: 11488.00, Perdas Totais: -12530.50
# Episode 91/100, Total Reward: -248.00, Win Rate: 0.51, Wins: 423, Losses: 403, Epsilon: 0.2003, Steps: 36754, Time: 124.83s
# Ações: Manter=11721, Comprar=14547, Vender=10486
# Ganhos Totais: 9874.50, Perdas Totais: -10122.50
# Episode 92/100, Total Reward: -348.50, Win Rate: 0.49, Wins: 397, Losses: 415, Epsilon: 0.1983, Steps: 36754, Time: 124.91s
# Ações: Manter=11825, Comprar=11602, Vender=13327
# Ganhos Totais: 10004.00, Perdas Totais: -10352.50
# Episode 93/100, Total Reward: -1420.25, Win Rate: 0.51, Wins: 433, Losses: 408, Epsilon: 0.1964, Steps: 36754, Time: 125.27s
# Ações: Manter=13051, Comprar=9390, Vender=14313
# Ganhos Totais: 10219.00, Perdas Totais: -11639.25
# Episode 94/100, Total Reward: 252.25, Win Rate: 0.51, Wins: 412, Losses: 395, Epsilon: 0.1944, Steps: 36754, Time: 125.35s
# Ações: Manter=11118, Comprar=10694, Vender=14942
# Ganhos Totais: 10396.00, Perdas Totais: -10143.75
# Episode 95/100, Total Reward: -547.75, Win Rate: 0.49, Wins: 391, Losses: 410, Epsilon: 0.1924, Steps: 36754, Time: 125.06s
# Ações: Manter=13220, Comprar=11313, Vender=12221
# Ganhos Totais: 9420.00, Perdas Totais: -9967.75
# Episode 96/100, Total Reward: -1152.25, Win Rate: 0.52, Wins: 446, Losses: 404, Epsilon: 0.1905, Steps: 36754, Time: 125.32s
# Ações: Manter=11259, Comprar=13572, Vender=11923
# Ganhos Totais: 9314.25, Perdas Totais: -10466.50
# Episode 97/100, Total Reward: -20.75, Win Rate: 0.51, Wins: 426, Losses: 411, Epsilon: 0.1886, Steps: 36754, Time: 125.40s
# Ações: Manter=10503, Comprar=12665, Vender=13586
# Ganhos Totais: 10235.00, Perdas Totais: -10255.75
# Episode 98/100, Total Reward: 1303.00, Win Rate: 0.52, Wins: 449, Losses: 410, Epsilon: 0.1867, Steps: 36754, Time: 125.50s
# Ações: Manter=12462, Comprar=11663, Vender=12629
# Ganhos Totais: 11377.25, Perdas Totais: -10074.25
# Episode 99/100, Total Reward: -2526.00, Win Rate: 0.49, Wins: 384, Losses: 403, Epsilon: 0.1849, Steps: 36754, Time: 125.61s
# Ações: Manter=13831, Comprar=9710, Vender=13213
# Ganhos Totais: 9571.00, Perdas Totais: -12097.00
# Episode 100/100, Total Reward: 859.50, Win Rate: 0.52, Wins: 443, Losses: 403, Epsilon: 0.1830, Steps: 36754, Time: 130.77s
# Ações: Manter=12799, Comprar=12942, Vender=11013
# Ganhos Totais: 11959.75, Perdas Totais: -11100.25
#
# Treinamento finalizado.
# Top 10 Melhores Episódios:
# Rank 1: Episode 74, Total Reward: 2884.50, Win Rate: 0.52, Wins: 442, Losses: 406, Ações: {0: 13663, 1: 11696, 2: 11395}, Steps: 36754, Time: 124.68s
# Rank 2: Episode 36, Total Reward: 2079.25, Win Rate: 0.52, Wins: 449, Losses: 413, Ações: {0: 11797, 1: 13755, 2: 11202}, Steps: 36754, Time: 122.92s
# Rank 3: Episode 21, Total Reward: 1892.50, Win Rate: 0.54, Wins: 483, Losses: 414, Ações: {0: 11533, 1: 11679, 2: 13542}, Steps: 36754, Time: 121.84s
# Rank 4: Episode 46, Total Reward: 1851.00, Win Rate: 0.50, Wins: 412, Losses: 408, Ações: {0: 12506, 1: 12525, 2: 11723}, Steps: 36754, Time: 123.28s
# Rank 5: Episode 24, Total Reward: 1773.25, Win Rate: 0.49, Wins: 403, Losses: 419, Ações: {0: 10676, 1: 13821, 2: 12257}, Steps: 36754, Time: 122.70s
# Rank 6: Episode 37, Total Reward: 1701.00, Win Rate: 0.53, Wins: 454, Losses: 409, Ações: {0: 14445, 1: 11204, 2: 11105}, Steps: 36754, Time: 122.66s
# Rank 7: Episode 22, Total Reward: 1681.75, Win Rate: 0.52, Wins: 443, Losses: 412, Ações: {0: 13345, 1: 11175, 2: 12234}, Steps: 36754, Time: 122.38s
# Rank 8: Episode 76, Total Reward: 1677.75, Win Rate: 0.53, Wins: 461, Losses: 409, Ações: {0: 12938, 1: 12818, 2: 10998}, Steps: 36754, Time: 125.39s
# Rank 9: Episode 19, Total Reward: 1527.50, Win Rate: 0.51, Wins: 421, Losses: 411, Ações: {0: 11877, 1: 11561, 2: 13316}, Steps: 36754, Time: 121.65s
# Rank 10: Episode 42, Total Reward: 1511.25, Win Rate: 0.54, Wins: 490, Losses: 414, Ações: {0: 11780, 1: 12131, 2: 12843}, Steps: 36754, Time: 123.06s
