# %%
# Carregar o dataset
data = pd.read_csv('D:\\dados\\bar_M1_data_07-08-2024.csv')

# %%
# Bloco 1: Preparar os Dados

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Carregar o dataset
data = pd.read_csv('D:\\dados\\bar_M1_data_07-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = ['Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior', 'Corpo', 'Range', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK', 'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram']
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# Exibir as primeiras linhas do dataframe para verificação
#print(data.head())

# Bloco 2: Criar o Ambiente

import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data
        self.current_step = 0
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(low=0, high=1, shape=(len(data.columns) - 3,), dtype=np.float32)

    def reset(self):
        self.current_step = 0
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        return obs.astype(np.float32)

    def step(self, action):
        self.current_step += 1

        done = self.current_step >= len(self.data) - 1
        reward = 0

        if action == 1:  # Comprar
            reward = self.data['Valor'].iloc[self.current_step] - self.data['Valor'].iloc[self.current_step - 1]
        elif action == 2:  # Vender
            reward = self.data['Valor'].iloc[self.current_step - 1] - self.data['Valor'].iloc[self.current_step]

        obs = self._next_observation()
        return obs, reward, done, {}

# Bloco 3: Criar o Agente

from stable_baselines3 import PPO

# Criar o ambiente
env = TradingEnv(data)

# Criar o agente usando PPO (usando GPU)
agent = PPO('MlpPolicy', env, verbose=0, device='cuda')

# Bloco 4: Treinamento com Logs

episodes = 10
for episode in range(episodes):
    obs = env.reset()
    done = False
    while not done:
        action, _states = agent.predict(obs)
        obs, reward, done, _ = env.step(action)

        # Imprimir logs apenas quando o gatilho for igual a 1
        gatilho = int(data['Gatilho'].iloc[env.current_step])
        if gatilho == 1:
            print(f"Episode: {episode + 1}, Step: {env.current_step}, Action: {action}, Reward: {reward}")

print("Treinamento finalizado.")
# Out:
# c:\Python39\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Episode: 1, Step: 630, Action: 0, Reward: 0
# Episode: 1, Step: 631, Action: 1, Reward: -2.75
# Episode: 1, Step: 632, Action: 1, Reward: 0.75
# Episode: 1, Step: 633, Action: 1, Reward: 4.5
# Episode: 1, Step: 634, Action: 0, Reward: 0
# Episode: 1, Step: 635, Action: 1, Reward: -2.5
# Episode: 1, Step: 636, Action: 2, Reward: 0.75
# Episode: 1, Step: 637, Action: 1, Reward: -1.25
# Episode: 1, Step: 638, Action: 1, Reward: -0.25
# Episode: 1, Step: 639, Action: 2, Reward: -0.75
# Episode: 1, Step: 640, Action: 2, Reward: -1.5
# Episode: 1, Step: 641, Action: 1, Reward: 2.25
# Episode: 1, Step: 642, Action: 2, Reward: -2.75
# Episode: 1, Step: 643, Action: 2, Reward: -4.75
# Episode: 1, Step: 644, Action: 0, Reward: 0
# Episode: 1, Step: 645, Action: 1, Reward: 0.0
# Episode: 1, Step: 646, Action: 0, Reward: 0
# Episode: 1, Step: 647, Action: 1, Reward: 0.25
# Episode: 1, Step: 648, Action: 2, Reward: -2.5
# Episode: 1, Step: 649, Action: 2, Reward: 4.25
# Episode: 1, Step: 650, Action: 2, Reward: -2.25
# Episode: 1, Step: 651, Action: 1, Reward: 1.0
# Episode: 1, Step: 652, Action: 1, Reward: 4.75
# Episode: 1, Step: 653, Action: 0, Reward: 0
# Episode: 1, Step: 654, Action: 0, Reward: 0
# Episode: 1, Step: 655, Action: 1, Reward: 1.5
# Episode: 1, Step: 656, Action: 0, Reward: 0
# Episode: 1, Step: 657, Action: 1, Reward: 0.75
# Episode: 1, Step: 658, Action: 1, Reward: -3.25
# Episode: 1, Step: 659, Action: 1, Reward: 3.5
# Episode: 1, Step: 660, Action: 2, Reward: 4.0
# Episode: 1, Step: 1949, Action: 0, Reward: 0
# Episode: 1, Step: 1950, Action: 2, Reward: 0.0
# Episode: 1, Step: 1951, Action: 1, Reward: 0.0
# Episode: 1, Step: 1952, Action: 1, Reward: -1.25
# Episode: 1, Step: 1953, Action: 0, Reward: 0
# Episode: 1, Step: 1954, Action: 2, Reward: -2.5
# Episode: 1, Step: 1955, Action: 0, Reward: 0
# Episode: 1, Step: 1956, Action: 1, Reward: -2.0
# Episode: 1, Step: 1957, Action: 1, Reward: 4.0
# Episode: 1, Step: 1958, Action: 2, Reward: 1.25
# Episode: 1, Step: 1959, Action: 1, Reward: 2.75
# Episode: 1, Step: 1960, Action: 1, Reward: 0.5
# Episode: 1, Step: 1961, Action: 2, Reward: -3.75
# Episode: 1, Step: 1962, Action: 0, Reward: 0
# Episode: 1, Step: 1963, Action: 2, Reward: -1.75
# Episode: 1, Step: 1964, Action: 0, Reward: 0
# Episode: 1, Step: 1965, Action: 2, Reward: 0.0
# Episode: 1, Step: 1966, Action: 2, Reward: -1.75
# Episode: 1, Step: 1967, Action: 2, Reward: 3.5
# Episode: 1, Step: 1968, Action: 0, Reward: 0
# Episode: 1, Step: 1969, Action: 1, Reward: 0.5
# Episode: 1, Step: 1970, Action: 0, Reward: 0
# Episode: 1, Step: 1971, Action: 1, Reward: -1.5
# Episode: 1, Step: 1972, Action: 1, Reward: -1.0
# Episode: 1, Step: 1973, Action: 1, Reward: 0.0
# Episode: 1, Step: 1974, Action: 2, Reward: -3.0
# Episode: 1, Step: 1975, Action: 2, Reward: 1.0
# Episode: 1, Step: 1976, Action: 1, Reward: 0.0
# Episode: 1, Step: 1977, Action: 2, Reward: -2.5
# Episode: 1, Step: 1978, Action: 2, Reward: -1.25
# Episode: 1, Step: 1979, Action: 0, Reward: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 77
#      75 done = False
#      76 while not done:
# ---> 77     action, _states = agent.predict(obs)
#      78     obs, reward, done, _ = env.step(action)
#      80     # Imprimir logs apenas quando o gatilho for igual a 1
#
# File c:\Python39\lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Python39\lib\site-packages\stable_baselines3\common\policies.py:370, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
# --> 370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#     372 if isinstance(self.action_space, spaces.Box):
#     373     if self.squash_output:
#     374         # Rescale to proper domain when using squashing
#
# KeyboardInterrupt:
