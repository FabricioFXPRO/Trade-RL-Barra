# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time
import os

data = pd.read_csv('D:\\dados\\bar_M15_V03_data_01-01-2023_a_31-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = [
    'Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior',
    'Corpo', 'Range','SMA4','SMA8','SMA12','SMA20', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK',
    'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram','atr8','atr14','atr28','dayO','dayH','dayL'
]
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# %%
import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )
        self.trades = []

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)
        return obs.astype(np.float32)

    def step(self, action):
        done = self.current_step >= len(self.data) - 2
        reward = 0
        info = {}

        # Obter o valor atual e o próximo valor
        current_price = self.data['Valor'].iloc[self.current_step]
        next_price = self.data['Valor'].iloc[self.current_step + 1]

        # Obter o valor do gatilho no passo atual
        gatilho = int(self.data['Gatilho'].iloc[self.current_step])

        # Se o gatilho estiver ativo, o agente pode executar todas as ações
        if gatilho == 1:
            if action == 1:  # Comprar
                if self.position == 0:
                    self.position = 1  # Abrir posição comprada
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == -1:
                    # Fechar posição vendida
                    self.exit_price = current_price
                    profit = self.entry_price - self.exit_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_short',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            elif action == 2:  # Vender
                if self.position == 0:
                    self.position = -1  # Abrir posição vendida
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25
                    info['trade'] = {
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == 1:
                    # Fechar posição comprada
                    self.exit_price = current_price
                    profit = self.exit_price - self.entry_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_long',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            else:  # Manter
                pass
        else:
            # Fechar posição se o gatilho não estiver ativo
            if self.position == 1:
                self.exit_price = current_price
                profit = self.exit_price - self.entry_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_long',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'buy',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None
            elif self.position == -1:
                self.exit_price = current_price
                profit = self.entry_price - self.exit_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_short',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'sell',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None

        self.current_step += 1

        obs = self._next_observation()
        return obs, reward, done, info

# %% [markdown]
# ## Bloco 3: Criar o Agente Rainbow DQN usando PyTorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random
import math
import numpy as np

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Implementação da Camada Noisy Linear
class NoisyLinear(nn.Module):
    def __init__(self, in_features, out_features, sigma_init=0.017):
        super(NoisyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma_init = sigma_init

        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.register_buffer('weight_epsilon', torch.zeros(out_features, in_features))

        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        self.register_buffer('bias_epsilon', torch.zeros(out_features))

        self.reset_parameters()
        self.reset_noise()

    def reset_parameters(self):
        mu_range = 1 / math.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.sigma_init / math.sqrt(self.in_features))
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.sigma_init / math.sqrt(self.out_features))

    def reset_noise(self):
        epsilon_in = self._scale_noise(self.in_features)
        epsilon_out = self._scale_noise(self.out_features)
        self.weight_epsilon.copy_(epsilon_out.outer(epsilon_in))
        self.bias_epsilon.copy_(epsilon_out)

    def forward(self, x):
        if self.training:
            weight = self.weight_mu + self.weight_sigma * self.weight_epsilon
            bias = self.bias_mu + self.bias_sigma * self.bias_epsilon
        else:
            weight = self.weight_mu
            bias = self.bias_mu
        return nn.functional.linear(x, weight, bias)

    def _scale_noise(self, size):
        x = torch.randn(size)
        return x.sign().mul_(x.abs().sqrt())

# Implementação da Rede Rainbow DQN
class RainbowDQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(RainbowDQN, self).__init__()
        self.feature = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU()
        )
        # Advantage stream
        self.advantage = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, n_actions)
        )
        # Value stream
        self.value = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, 1)
        )

    def forward(self, x):
        x = self.feature(x)
        advantage = self.advantage(x)
        value = self.value(x)
        # Dueling Q-values
        q_values = value + advantage - advantage.mean()
        return q_values

    def reset_noise(self):
        for module in self.modules():
            if isinstance(module, NoisyLinear):
                module.reset_noise()

# Implementação do Prioritized Replay Buffer
class PrioritizedReplayBuffer(object):
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.alpha = alpha

        self.buffer = []
        self.pos = 0

        self.priorities = np.zeros((capacity,), dtype=np.float32)

    def push(self, *args):
        max_prio = self.priorities.max() if self.buffer else 1.0

        if len(self.buffer) < self.capacity:
            self.buffer.append((*args,))
        else:
            self.buffer[self.pos] = (*args,)

        self.priorities[self.pos] = max_prio
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, beta=0.4):
        if len(self.buffer) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.pos]

        probs = prios ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        total = len(self.buffer)
        weights = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = np.array(weights, dtype=np.float32)

        batch = list(zip(*samples))

        states = torch.cat(batch[0]).to(device)
        actions = torch.tensor(batch[1], dtype=torch.long, device=device).unsqueeze(1)
        rewards = torch.tensor(batch[2], dtype=torch.float32, device=device).unsqueeze(1)
        next_states = torch.cat(batch[3]).to(device)
        dones = torch.tensor(batch[4], dtype=torch.float32, device=device).unsqueeze(1)
        weights = torch.tensor(weights, dtype=torch.float32, device=device).unsqueeze(1)

        return states, actions, rewards, next_states, dones, indices, weights

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio

# %% [markdown]
# ## Bloco 4: Treinamento do Agente Rainbow DQN

# %%
# Configurações do treinamento
num_episodes = 100
gamma = 0.99
batch_size = 64
learning_rate = 1e-4
memory_size = 10000
target_update = 1000
beta_start = 0.4
beta_frames = num_episodes * len(data)
alpha = 0.6

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Instanciar a rede
q_net = RainbowDQN(obs_size, n_actions).to(device)
target_net = RainbowDQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=learning_rate)

# Inicializar o Prioritized Replay Buffer
replay_buffer = PrioritizedReplayBuffer(memory_size, alpha=alpha)

# Inicializar a lista de melhores episódios
best_episodes = []

# Função para selecionar ação usando Noisy Nets
def select_action(state):
    with torch.no_grad():
        q_values = q_net(state)
        return q_values.argmax().item()

save_dir = "4.18"
os.makedirs(save_dir, exist_ok=True)

beta = beta_start
frame_idx = 0  # Contador de frames para ajustar beta
for episode in range(num_episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0
    trades = []
    current_trade = None

    while not done:
        steps += 1
        frame_idx += 1

        # Selecionar ação
        action = select_action(obs)

        # Executar ação no ambiente
        obs_next, reward, done, info = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        replay_buffer.push(obs, action, reward, obs_next, done)

        # Atualizar o estado
        obs = obs_next

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Atualizar recompensa total
        total_reward += reward

        # Resetar ruído das Noisy Nets
        q_net.reset_noise()
        target_net.reset_noise()

        # Processar informações de trade
        if 'trade' in info:
            trade_info = info['trade']
            if trade_info['type'] in ['buy', 'sell']:
                current_trade = {
                    'type': trade_info['type'],
                    'entry_step': trade_info['entry_step'],
                    'entry_price': trade_info['entry_price'],
                    'entry_datetime': trade_info['entry_datetime'],
                    'exit_step': None,
                    'exit_price': None,
                    'exit_datetime': None,
                    'profit': None
                }
            elif trade_info['type'] in ['close_long', 'close_short']:
                current_trade['exit_step'] = trade_info['exit_step']
                current_trade['exit_price'] = trade_info['exit_price']
                current_trade['exit_datetime'] = trade_info['exit_datetime']
                current_trade['profit'] = trade_info['profit']
                trades.append(current_trade.copy())
                if current_trade['profit'] > 0:
                    wins += 1
                    win_total += current_trade['profit']
                elif current_trade['profit'] < 0:
                    losses += 1
                    lose_total += current_trade['profit']
                current_trade = None

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(replay_buffer.buffer) >= batch_size:
            beta = min(1.0, beta_start + frame_idx * (1.0 - beta_start) / beta_frames)
            states, actions_batch, rewards_batch, next_states, dones, indices, weights = replay_buffer.sample(batch_size, beta)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando Double DQN
            with torch.no_grad():
                next_actions = q_net(next_states).argmax(1, keepdim=True)
                next_q_values = target_net(next_states).gather(1, next_actions)
                target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular o erro para Prioritized Replay
            td_errors = (q_values - target_q_values).detach().cpu().numpy().flatten()
            new_priorities = np.abs(td_errors) + 1e-6
            replay_buffer.update_priorities(indices, new_priorities)

            # Calcular a perda ponderada
            loss = (weights * nn.functional.mse_loss(q_values, target_q_values, reduction='none')).mean()

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Atualizar a rede alvo
            if frame_idx % target_update == 0:
                target_net.load_state_dict(q_net.state_dict())

    # Cálculo do tempo de treinamento do episódio
    end_time = time.time()
    episode_time = end_time - start_time

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, "
          f"Wins: {wins}, Losses: {losses}, Steps: {steps}, Time: {episode_time:.2f}s")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}")

    # Salvar informações do episódio
    episode_info = {
        'episode': episode + 1,
        'total_reward': total_reward,
        'win_rate': win_rate,
        'wins': wins,
        'losses': losses,
        'actions_count': actions_count.copy(),
        'win_total': win_total,
        'lose_total': lose_total,
        'steps': steps,
        'episode_time': episode_time,
        'model_state_dict': q_net.state_dict(),
        'trades': trades.copy()
    }

    # Adicionar o episódio à lista dos melhores e manter os top 10
    best_episodes.append(episode_info)
    best_episodes = sorted(best_episodes, key=lambda x: x['total_reward'], reverse=True)[:10]

    # Salvar o modelo e log do episódio se for um dos top 10
    if episode_info in best_episodes:
        model_path = os.path.join(save_dir, f"model_episode_{episode_info['episode']}.pth")
        torch.save(episode_info['model_state_dict'], model_path)
        episode_info['model_path'] = model_path

        # Salvar o log completo das operações
        log_path = os.path.join(save_dir, f"log_episode_{episode_info['episode']}.csv")
        trades_df = pd.DataFrame(episode_info['trades'])
        trades_df.to_csv(log_path, index=False)
        episode_info['log_path'] = log_path

        print(f"Modelo e log do episódio {episode_info['episode']} salvos em: {model_path} e {log_path}\n")

# Exibir os top 10 episódios ao final do treinamento
print("\nTreinamento finalizado.")
print("Top 10 Melhores Episódios:")
for idx, ep in enumerate(best_episodes, 1):
    print(f"Rank {idx}: Episode {ep['episode']}, Total Reward: {ep['total_reward']:.2f}, "
          f"Win Rate: {ep['win_rate']:.2f}, Wins: {ep['wins']}, Losses: {ep['losses']}, "
          f"Ações: {ep['actions_count']}, Steps: {ep['steps']}, Time: {ep['episode_time']:.2f}s")
# Out:
# Episode 1/100, Total Reward: -307.25, Win Rate: 0.49, Wins: 824, Losses: 858, Steps: 36754, Time: 324.76s
# Ações: Manter=15571, Comprar=15066, Vender=6117
# Ganhos Totais: 30166.50, Perdas Totais: -30051.50
# Modelo e log do episódio 1 salvos em: 4.18\model_episode_1.pth e 4.18\log_episode_1.csv
#
# Episode 2/100, Total Reward: -504.75, Win Rate: 0.49, Wins: 822, Losses: 861, Steps: 36754, Time: 309.23s
# Ações: Manter=13385, Comprar=17264, Vender=6105
# Ganhos Totais: 29460.50, Perdas Totais: -29542.75
# Modelo e log do episódio 2 salvos em: 4.18\model_episode_2.pth e 4.18\log_episode_2.csv
#
# Episode 3/100, Total Reward: 2455.25, Win Rate: 0.53, Wins: 386, Losses: 340, Steps: 36754, Time: 308.85s
# Ações: Manter=11639, Comprar=21459, Vender=3656
# Ganhos Totais: 25055.00, Perdas Totais: -22418.25
# Modelo e log do episódio 3 salvos em: 4.18\model_episode_3.pth e 4.18\log_episode_3.csv
#
# Episode 4/100, Total Reward: 3050.50, Win Rate: 0.52, Wins: 383, Losses: 352, Steps: 36754, Time: 309.42s
# Ações: Manter=11912, Comprar=21382, Vender=3460
# Ganhos Totais: 25667.25, Perdas Totais: -22432.75
# Modelo e log do episódio 4 salvos em: 4.18\model_episode_4.pth e 4.18\log_episode_4.csv
#
# Episode 5/100, Total Reward: 3952.75, Win Rate: 0.57, Wins: 419, Losses: 310, Steps: 36754, Time: 309.92s
# Ações: Manter=15927, Comprar=18636, Vender=2191
# Ganhos Totais: 25416.75, Perdas Totais: -21281.25
# Modelo e log do episódio 5 salvos em: 4.18\model_episode_5.pth e 4.18\log_episode_5.csv
#
# Episode 6/100, Total Reward: 5992.75, Win Rate: 0.56, Wins: 572, Losses: 458, Steps: 36754, Time: 309.22s
# Ações: Manter=13149, Comprar=19231, Vender=4374
# Ganhos Totais: 28586.25, Perdas Totais: -22335.00
# Modelo e log do episódio 6 salvos em: 4.18\model_episode_6.pth e 4.18\log_episode_6.csv
#
# Episode 7/100, Total Reward: 4467.00, Win Rate: 0.57, Wins: 626, Losses: 478, Steps: 36754, Time: 309.06s
# Ações: Manter=12845, Comprar=21069, Vender=2840
# Ganhos Totais: 29158.25, Perdas Totais: -24414.25
# Modelo e log do episódio 7 salvos em: 4.18\model_episode_7.pth e 4.18\log_episode_7.csv
#
# Episode 8/100, Total Reward: 2714.75, Win Rate: 0.57, Wins: 759, Losses: 576, Steps: 36754, Time: 309.02s
# Ações: Manter=13175, Comprar=19339, Vender=4240
# Ganhos Totais: 28689.25, Perdas Totais: -25639.00
# Modelo e log do episódio 8 salvos em: 4.18\model_episode_8.pth e 4.18\log_episode_8.csv
#
# Episode 9/100, Total Reward: 2261.75, Win Rate: 0.55, Wins: 711, Losses: 575, Steps: 36754, Time: 309.00s
# Ações: Manter=12422, Comprar=18993, Vender=5339
# Ganhos Totais: 28082.00, Perdas Totais: -25497.25
# Modelo e log do episódio 9 salvos em: 4.18\model_episode_9.pth e 4.18\log_episode_9.csv
#
# Episode 10/100, Total Reward: 77.25, Win Rate: 0.55, Wins: 990, Losses: 822, Steps: 36754, Time: 309.06s
# Ações: Manter=10464, Comprar=20334, Vender=5956
# Ganhos Totais: 30102.50, Perdas Totais: -29569.25
# Modelo e log do episódio 10 salvos em: 4.18\model_episode_10.pth e 4.18\log_episode_10.csv
#
# Episode 11/100, Total Reward: -2107.75, Win Rate: 0.53, Wins: 908, Losses: 794, Steps: 36754, Time: 309.53s
# Ações: Manter=10446, Comprar=19460, Vender=6848
# Ganhos Totais: 29532.25, Perdas Totais: -31213.50
# Modelo e log do episódio 11 salvos em: 4.18\model_episode_11.pth e 4.18\log_episode_11.csv
#
# Episode 12/100, Total Reward: 1704.75, Win Rate: 0.59, Wins: 861, Losses: 610, Steps: 36754, Time: 309.16s
# Ações: Manter=11874, Comprar=20411, Vender=4469
# Ganhos Totais: 29312.25, Perdas Totais: -27238.50
# Modelo e log do episódio 12 salvos em: 4.18\model_episode_12.pth e 4.18\log_episode_12.csv
#
# Episode 13/100, Total Reward: 803.50, Win Rate: 0.57, Wins: 908, Losses: 686, Steps: 36754, Time: 308.72s
# Ações: Manter=12889, Comprar=19862, Vender=4003
# Ganhos Totais: 29435.00, Perdas Totais: -28232.25
# Modelo e log do episódio 13 salvos em: 4.18\model_episode_13.pth e 4.18\log_episode_13.csv
#
# Episode 14/100, Total Reward: 1493.50, Win Rate: 0.57, Wins: 977, Losses: 739, Steps: 36754, Time: 309.09s
# Ações: Manter=10556, Comprar=21223, Vender=4975
# Ganhos Totais: 31316.75, Perdas Totais: -29391.25
# Modelo e log do episódio 14 salvos em: 4.18\model_episode_14.pth e 4.18\log_episode_14.csv
#
# Episode 15/100, Total Reward: 3355.75, Win Rate: 0.58, Wins: 836, Losses: 599, Steps: 36754, Time: 308.85s
# Ações: Manter=12736, Comprar=20217, Vender=3801
# Ganhos Totais: 30078.00, Perdas Totais: -26363.00
# Modelo e log do episódio 15 salvos em: 4.18\model_episode_15.pth e 4.18\log_episode_15.csv
#
# Episode 16/100, Total Reward: 1218.25, Win Rate: 0.57, Wins: 1036, Losses: 781, Steps: 36754, Time: 308.91s
# Ações: Manter=10708, Comprar=19502, Vender=6544
# Ganhos Totais: 30746.50, Perdas Totais: -29072.25
# Modelo e log do episódio 16 salvos em: 4.18\model_episode_16.pth e 4.18\log_episode_16.csv
#
# Episode 17/100, Total Reward: 2053.25, Win Rate: 0.58, Wins: 915, Losses: 668, Steps: 36754, Time: 309.90s
# Ações: Manter=13176, Comprar=19790, Vender=3788
# Ganhos Totais: 31123.00, Perdas Totais: -28673.25
# Modelo e log do episódio 17 salvos em: 4.18\model_episode_17.pth e 4.18\log_episode_17.csv
#
# Episode 18/100, Total Reward: 1199.00, Win Rate: 0.56, Wins: 1020, Losses: 799, Steps: 36754, Time: 310.29s
# Ações: Manter=16816, Comprar=13680, Vender=6258
# Ganhos Totais: 30331.00, Perdas Totais: -28676.00
# Modelo e log do episódio 18 salvos em: 4.18\model_episode_18.pth e 4.18\log_episode_18.csv
#
# Episode 19/100, Total Reward: -644.50, Win Rate: 0.57, Wins: 800, Losses: 610, Steps: 36754, Time: 309.87s
# Ações: Manter=20035, Comprar=11132, Vender=5587
# Ganhos Totais: 27611.25, Perdas Totais: -27902.50
# Modelo e log do episódio 19 salvos em: 4.18\model_episode_19.pth e 4.18\log_episode_19.csv
#
# Episode 20/100, Total Reward: 834.00, Win Rate: 0.59, Wins: 736, Losses: 516, Steps: 36754, Time: 309.36s
# Ações: Manter=17584, Comprar=14238, Vender=4932
# Ganhos Totais: 27370.75, Perdas Totais: -26222.75
# Modelo e log do episódio 20 salvos em: 4.18\model_episode_20.pth e 4.18\log_episode_20.csv
#
# Episode 21/100, Total Reward: 4288.25, Win Rate: 0.59, Wins: 856, Losses: 595, Steps: 36754, Time: 310.35s
# Ações: Manter=18232, Comprar=12260, Vender=6262
# Ganhos Totais: 29101.00, Perdas Totais: -24449.25
# Modelo e log do episódio 21 salvos em: 4.18\model_episode_21.pth e 4.18\log_episode_21.csv
#
# Episode 22/100, Total Reward: 842.00, Win Rate: 0.55, Wins: 705, Losses: 571, Steps: 36754, Time: 309.92s
# Ações: Manter=21258, Comprar=9663, Vender=5833
# Ganhos Totais: 25700.00, Perdas Totais: -24537.75
# Modelo e log do episódio 22 salvos em: 4.18\model_episode_22.pth e 4.18\log_episode_22.csv
#
# Episode 23/100, Total Reward: 906.00, Win Rate: 0.54, Wins: 751, Losses: 644, Steps: 36754, Time: 309.99s
# Ações: Manter=13680, Comprar=16722, Vender=6352
# Ganhos Totais: 27783.25, Perdas Totais: -26526.75
# Modelo e log do episódio 23 salvos em: 4.18\model_episode_23.pth e 4.18\log_episode_23.csv
#
# Episode 24/100, Total Reward: 572.50, Win Rate: 0.54, Wins: 1022, Losses: 875, Steps: 36754, Time: 309.64s
# Ações: Manter=14940, Comprar=12524, Vender=9290
# Ganhos Totais: 30376.00, Perdas Totais: -29326.50
# Modelo e log do episódio 24 salvos em: 4.18\model_episode_24.pth e 4.18\log_episode_24.csv
#
# Episode 25/100, Total Reward: 4558.25, Win Rate: 0.56, Wins: 951, Losses: 737, Steps: 36754, Time: 309.97s
# Ações: Manter=14418, Comprar=18027, Vender=4309
# Ganhos Totais: 31022.75, Perdas Totais: -26040.50
# Modelo e log do episódio 25 salvos em: 4.18\model_episode_25.pth e 4.18\log_episode_25.csv
#
# Episode 26/100, Total Reward: 7014.25, Win Rate: 0.58, Wins: 825, Losses: 602, Steps: 36754, Time: 310.27s
# Ações: Manter=12345, Comprar=20148, Vender=4261
# Ganhos Totais: 32710.50, Perdas Totais: -25338.25
# Modelo e log do episódio 26 salvos em: 4.18\model_episode_26.pth e 4.18\log_episode_26.csv
#
# Episode 27/100, Total Reward: 4612.50, Win Rate: 0.58, Wins: 664, Losses: 485, Steps: 36754, Time: 309.98s
# Ações: Manter=10559, Comprar=23638, Vender=2557
# Ganhos Totais: 30639.75, Perdas Totais: -25738.75
# Modelo e log do episódio 27 salvos em: 4.18\model_episode_27.pth e 4.18\log_episode_27.csv
#
# Episode 28/100, Total Reward: 5159.75, Win Rate: 0.57, Wins: 964, Losses: 735, Steps: 36754, Time: 309.50s
# Ações: Manter=13622, Comprar=19959, Vender=3173
# Ganhos Totais: 33514.25, Perdas Totais: -27927.75
# Modelo e log do episódio 28 salvos em: 4.18\model_episode_28.pth e 4.18\log_episode_28.csv
#
# Episode 29/100, Total Reward: 771.75, Win Rate: 0.56, Wins: 666, Losses: 529, Steps: 36754, Time: 309.65s
# Ações: Manter=19180, Comprar=13566, Vender=4008
# Ganhos Totais: 26155.75, Perdas Totais: -25085.00
# Modelo e log do episódio 29 salvos em: 4.18\model_episode_29.pth e 4.18\log_episode_29.csv
#
# Episode 30/100, Total Reward: 4519.75, Win Rate: 0.58, Wins: 702, Losses: 500, Steps: 36754, Time: 309.15s
# Ações: Manter=10650, Comprar=22906, Vender=3198
# Ganhos Totais: 30357.75, Perdas Totais: -25536.75
# Modelo e log do episódio 30 salvos em: 4.18\model_episode_30.pth e 4.18\log_episode_30.csv
#
# Episode 31/100, Total Reward: 3190.75, Win Rate: 0.61, Wins: 882, Losses: 557, Steps: 36754, Time: 309.55s
# Ações: Manter=11182, Comprar=21920, Vender=3652
# Ganhos Totais: 30685.50, Perdas Totais: -27132.50
# Modelo e log do episódio 31 salvos em: 4.18\model_episode_31.pth e 4.18\log_episode_31.csv
#
# Episode 32/100, Total Reward: 6936.25, Win Rate: 0.59, Wins: 960, Losses: 656, Steps: 36754, Time: 310.10s
# Ações: Manter=10069, Comprar=21737, Vender=4948
# Ganhos Totais: 33517.00, Perdas Totais: -26176.00
# Modelo e log do episódio 32 salvos em: 4.18\model_episode_32.pth e 4.18\log_episode_32.csv
#
# Episode 33/100, Total Reward: 7009.50, Win Rate: 0.59, Wins: 826, Losses: 583, Steps: 36754, Time: 310.53s
# Ações: Manter=12461, Comprar=20106, Vender=4187
# Ganhos Totais: 32643.75, Perdas Totais: -25281.00
# Modelo e log do episódio 33 salvos em: 4.18\model_episode_33.pth e 4.18\log_episode_33.csv
#
# Episode 34/100, Total Reward: 5043.50, Win Rate: 0.58, Wins: 864, Losses: 628, Steps: 36754, Time: 311.70s
# Ações: Manter=11005, Comprar=22222, Vender=3527
# Ganhos Totais: 32135.75, Perdas Totais: -26717.25
# Modelo e log do episódio 34 salvos em: 4.18\model_episode_34.pth e 4.18\log_episode_34.csv
#
# Episode 35/100, Total Reward: 7589.50, Win Rate: 0.60, Wins: 904, Losses: 602, Steps: 36754, Time: 310.61s
# Ações: Manter=10471, Comprar=23589, Vender=2694
# Ganhos Totais: 32351.75, Perdas Totais: -24384.00
# Modelo e log do episódio 35 salvos em: 4.18\model_episode_35.pth e 4.18\log_episode_35.csv
#
# Episode 36/100, Total Reward: 2843.75, Win Rate: 0.59, Wins: 867, Losses: 591, Steps: 36754, Time: 310.91s
# Ações: Manter=8750, Comprar=26368, Vender=1636
# Ganhos Totais: 30613.75, Perdas Totais: -27403.75
# Modelo e log do episódio 36 salvos em: 4.18\model_episode_36.pth e 4.18\log_episode_36.csv
#
# Episode 37/100, Total Reward: 949.75, Win Rate: 0.59, Wins: 1046, Losses: 737, Steps: 36754, Time: 310.72s
# Ações: Manter=10531, Comprar=23021, Vender=3202
# Ganhos Totais: 30951.75, Perdas Totais: -29553.25
# Modelo e log do episódio 37 salvos em: 4.18\model_episode_37.pth e 4.18\log_episode_37.csv
#
# Episode 38/100, Total Reward: 1577.50, Win Rate: 0.58, Wins: 1002, Losses: 732, Steps: 36754, Time: 310.65s
# Ações: Manter=11137, Comprar=22153, Vender=3464
# Ganhos Totais: 31719.00, Perdas Totais: -29705.50
# Modelo e log do episódio 38 salvos em: 4.18\model_episode_38.pth e 4.18\log_episode_38.csv
#
# Episode 39/100, Total Reward: 999.75, Win Rate: 0.60, Wins: 920, Losses: 625, Steps: 36754, Time: 310.70s
# Ações: Manter=9262, Comprar=19862, Vender=7630
# Ganhos Totais: 30016.75, Perdas Totais: -28629.75
# Modelo e log do episódio 39 salvos em: 4.18\model_episode_39.pth e 4.18\log_episode_39.csv
#
# Episode 40/100, Total Reward: 2466.25, Win Rate: 0.57, Wins: 911, Losses: 687, Steps: 36754, Time: 311.52s
# Ações: Manter=11893, Comprar=20890, Vender=3971
# Ganhos Totais: 30774.75, Perdas Totais: -27907.25
# Modelo e log do episódio 40 salvos em: 4.18\model_episode_40.pth e 4.18\log_episode_40.csv
#
# Episode 41/100, Total Reward: 4081.50, Win Rate: 0.57, Wins: 974, Losses: 731, Steps: 36754, Time: 311.43s
# Ações: Manter=8334, Comprar=19899, Vender=8521
# Ganhos Totais: 33461.50, Perdas Totais: -28952.00
# Modelo e log do episódio 41 salvos em: 4.18\model_episode_41.pth e 4.18\log_episode_41.csv
#
# Episode 42/100, Total Reward: 3770.25, Win Rate: 0.58, Wins: 842, Losses: 603, Steps: 36754, Time: 311.44s
# Ações: Manter=11958, Comprar=18301, Vender=6495
# Ganhos Totais: 32308.00, Perdas Totais: -28175.00
# Modelo e log do episódio 42 salvos em: 4.18\model_episode_42.pth e 4.18\log_episode_42.csv
#
# Episode 43/100, Total Reward: 1325.00, Win Rate: 0.58, Wins: 776, Losses: 552, Steps: 36754, Time: 311.10s
# Ações: Manter=15749, Comprar=16730, Vender=4275
# Ganhos Totais: 28332.00, Perdas Totais: -26674.00
# Modelo e log do episódio 43 salvos em: 4.18\model_episode_43.pth e 4.18\log_episode_43.csv
#
# Episode 44/100, Total Reward: 5327.00, Win Rate: 0.59, Wins: 871, Losses: 613, Steps: 36754, Time: 311.42s
# Ações: Manter=13239, Comprar=17380, Vender=6135
# Ganhos Totais: 31625.50, Perdas Totais: -25927.00
# Modelo e log do episódio 44 salvos em: 4.18\model_episode_44.pth e 4.18\log_episode_44.csv
#
# Episode 45/100, Total Reward: 3384.25, Win Rate: 0.57, Wins: 616, Losses: 462, Steps: 36754, Time: 309.15s
# Ações: Manter=19697, Comprar=11139, Vender=5918
# Ganhos Totais: 26151.50, Perdas Totais: -22497.50
# Modelo e log do episódio 45 salvos em: 4.18\model_episode_45.pth e 4.18\log_episode_45.csv
#
# Episode 46/100, Total Reward: -1695.50, Win Rate: 0.52, Wins: 403, Losses: 369, Steps: 36754, Time: 309.82s
# Ações: Manter=16268, Comprar=4259, Vender=16227
# Ganhos Totais: 23272.00, Perdas Totais: -24773.75
# Modelo e log do episódio 46 salvos em: 4.18\model_episode_46.pth e 4.18\log_episode_46.csv
#
# Episode 47/100, Total Reward: -1412.00, Win Rate: 0.53, Wins: 325, Losses: 285, Steps: 36754, Time: 309.38s
# Ações: Manter=19197, Comprar=2532, Vender=15025
# Ganhos Totais: 21710.25, Perdas Totais: -22969.75
# Modelo e log do episódio 47 salvos em: 4.18\model_episode_47.pth e 4.18\log_episode_47.csv
#
# Episode 48/100, Total Reward: -2509.75, Win Rate: 0.53, Wins: 326, Losses: 292, Steps: 36754, Time: 309.32s
# Ações: Manter=22395, Comprar=2221, Vender=12138
# Ganhos Totais: 21870.00, Perdas Totais: -24225.00
# Modelo e log do episódio 48 salvos em: 4.18\model_episode_48.pth e 4.18\log_episode_48.csv
#
# Episode 49/100, Total Reward: 3374.00, Win Rate: 0.58, Wins: 341, Losses: 243, Steps: 36754, Time: 309.91s
# Ações: Manter=30657, Comprar=2413, Vender=3684
# Ganhos Totais: 17411.75, Perdas Totais: -13891.75
# Modelo e log do episódio 49 salvos em: 4.18\model_episode_49.pth e 4.18\log_episode_49.csv
#
# Episode 50/100, Total Reward: 1153.25, Win Rate: 0.62, Wins: 181, Losses: 113, Steps: 36754, Time: 310.04s
# Ações: Manter=35109, Comprar=1490, Vender=155
# Ganhos Totais: 11111.25, Perdas Totais: -9884.50
# Modelo e log do episódio 50 salvos em: 4.18\model_episode_50.pth e 4.18\log_episode_50.csv
#
# Episode 51/100, Total Reward: 2109.75, Win Rate: 0.61, Wins: 227, Losses: 145, Steps: 36754, Time: 309.07s
# Ações: Manter=33902, Comprar=2738, Vender=114
# Ganhos Totais: 13527.75, Perdas Totais: -11325.00
# Modelo e log do episódio 51 salvos em: 4.18\model_episode_51.pth e 4.18\log_episode_51.csv
#
# Episode 52/100, Total Reward: 4576.50, Win Rate: 0.63, Wins: 241, Losses: 141, Steps: 36754, Time: 310.18s
# Ações: Manter=33119, Comprar=3439, Vender=196
# Ganhos Totais: 14517.50, Perdas Totais: -9845.50
# Modelo e log do episódio 52 salvos em: 4.18\model_episode_52.pth e 4.18\log_episode_52.csv
#
# Episode 53/100, Total Reward: 6551.50, Win Rate: 0.61, Wins: 397, Losses: 259, Steps: 36754, Time: 309.09s
# Ações: Manter=29616, Comprar=3766, Vender=3372
# Ganhos Totais: 22559.25, Perdas Totais: -15843.50
# Modelo e log do episódio 53 salvos em: 4.18\model_episode_53.pth e 4.18\log_episode_53.csv
#
# Episode 54/100, Total Reward: 3731.00, Win Rate: 0.57, Wins: 304, Losses: 234, Steps: 36754, Time: 309.55s
# Ações: Manter=27224, Comprar=3724, Vender=5806
# Ganhos Totais: 20021.50, Perdas Totais: -16156.00
# Modelo e log do episódio 54 salvos em: 4.18\model_episode_54.pth e 4.18\log_episode_54.csv
#
# Episode 55/100, Total Reward: 2806.75, Win Rate: 0.57, Wins: 516, Losses: 391, Steps: 36754, Time: 309.45s
# Ações: Manter=27054, Comprar=4472, Vender=5228
# Ganhos Totais: 23185.00, Perdas Totais: -20150.75
# Modelo e log do episódio 55 salvos em: 4.18\model_episode_55.pth e 4.18\log_episode_55.csv
#
# Episode 56/100, Total Reward: 2257.50, Win Rate: 0.56, Wins: 353, Losses: 274, Steps: 36754, Time: 309.77s
# Ações: Manter=32032, Comprar=3156, Vender=1566
# Ganhos Totais: 18185.00, Perdas Totais: -15770.25
# Modelo e log do episódio 56 salvos em: 4.18\model_episode_56.pth e 4.18\log_episode_56.csv
#
# Episode 57/100, Total Reward: 3693.50, Win Rate: 0.57, Wins: 466, Losses: 355, Steps: 36754, Time: 309.32s
# Ações: Manter=23259, Comprar=4591, Vender=8904
# Ganhos Totais: 25137.25, Perdas Totais: -21238.25
# Modelo e log do episódio 57 salvos em: 4.18\model_episode_57.pth e 4.18\log_episode_57.csv
#
# Episode 58/100, Total Reward: 1260.00, Win Rate: 0.57, Wins: 492, Losses: 376, Steps: 36754, Time: 309.47s
# Ações: Manter=21824, Comprar=7036, Vender=7894
# Ganhos Totais: 23914.25, Perdas Totais: -22437.00
# Modelo e log do episódio 58 salvos em: 4.18\model_episode_58.pth e 4.18\log_episode_58.csv
#
# Episode 59/100, Total Reward: 3986.25, Win Rate: 0.60, Wins: 342, Losses: 228, Steps: 36754, Time: 308.93s
# Ações: Manter=24817, Comprar=11135, Vender=802
# Ganhos Totais: 20037.50, Perdas Totais: -15908.25
# Modelo e log do episódio 59 salvos em: 4.18\model_episode_59.pth e 4.18\log_episode_59.csv
#
# Episode 60/100, Total Reward: 6374.00, Win Rate: 0.59, Wins: 384, Losses: 271, Steps: 36754, Time: 308.98s
# Ações: Manter=24075, Comprar=10930, Vender=1749
# Ganhos Totais: 24360.75, Perdas Totais: -17822.25
# Modelo e log do episódio 60 salvos em: 4.18\model_episode_60.pth e 4.18\log_episode_60.csv
#
# Episode 61/100, Total Reward: 6887.25, Win Rate: 0.56, Wins: 445, Losses: 348, Steps: 36754, Time: 310.23s
# Ações: Manter=23169, Comprar=11734, Vender=1851
# Ganhos Totais: 25715.50, Perdas Totais: -18629.25
# Modelo e log do episódio 61 salvos em: 4.18\model_episode_61.pth e 4.18\log_episode_61.csv
#
# Episode 62/100, Total Reward: 7089.75, Win Rate: 0.55, Wins: 794, Losses: 648, Steps: 36754, Time: 309.45s
# Ações: Manter=21058, Comprar=11123, Vender=4573
# Ganhos Totais: 29591.00, Perdas Totais: -22138.00
# Modelo e log do episódio 62 salvos em: 4.18\model_episode_62.pth e 4.18\log_episode_62.csv
#
# Episode 63/100, Total Reward: 3106.50, Win Rate: 0.56, Wins: 486, Losses: 378, Steps: 36754, Time: 309.91s
# Ações: Manter=27192, Comprar=6734, Vender=2828
# Ganhos Totais: 19235.50, Perdas Totais: -15912.25
# Modelo e log do episódio 63 salvos em: 4.18\model_episode_63.pth e 4.18\log_episode_63.csv
#
# Episode 64/100, Total Reward: 4000.50, Win Rate: 0.58, Wins: 302, Losses: 217, Steps: 36754, Time: 310.27s
# Ações: Manter=31483, Comprar=3448, Vender=1823
# Ganhos Totais: 17574.75, Perdas Totais: -13443.50
# Modelo e log do episódio 64 salvos em: 4.18\model_episode_64.pth e 4.18\log_episode_64.csv
#
# Episode 65/100, Total Reward: 4068.75, Win Rate: 0.57, Wins: 333, Losses: 254, Steps: 36754, Time: 310.68s
# Ações: Manter=33165, Comprar=2050, Vender=1539
# Ganhos Totais: 17748.50, Perdas Totais: -13532.75
# Modelo e log do episódio 65 salvos em: 4.18\model_episode_65.pth e 4.18\log_episode_65.csv
#
# Episode 66/100, Total Reward: 1679.50, Win Rate: 0.57, Wins: 378, Losses: 288, Steps: 36754, Time: 312.01s
# Ações: Manter=27753, Comprar=1592, Vender=7409
# Ganhos Totais: 20395.50, Perdas Totais: -18549.25
# Modelo e log do episódio 66 salvos em: 4.18\model_episode_66.pth e 4.18\log_episode_66.csv
#
# Episode 67/100, Total Reward: 2853.00, Win Rate: 0.57, Wins: 380, Losses: 285, Steps: 36754, Time: 311.87s
# Ações: Manter=33063, Comprar=1974, Vender=1717
# Ganhos Totais: 17297.00, Perdas Totais: -14277.50
# Modelo e log do episódio 67 salvos em: 4.18\model_episode_67.pth e 4.18\log_episode_67.csv
#
# Episode 68/100, Total Reward: 6076.50, Win Rate: 0.59, Wins: 430, Losses: 302, Steps: 36754, Time: 311.72s
# Ações: Manter=29669, Comprar=3217, Vender=3868
# Ganhos Totais: 23167.00, Perdas Totais: -16907.50
# Modelo e log do episódio 68 salvos em: 4.18\model_episode_68.pth e 4.18\log_episode_68.csv
#
# Episode 69/100, Total Reward: 2079.00, Win Rate: 0.57, Wins: 422, Losses: 321, Steps: 36754, Time: 311.37s
# Ações: Manter=28894, Comprar=4233, Vender=3627
# Ganhos Totais: 23696.50, Perdas Totais: -21431.75
# Modelo e log do episódio 69 salvos em: 4.18\model_episode_69.pth e 4.18\log_episode_69.csv
#
# Episode 70/100, Total Reward: 5700.25, Win Rate: 0.58, Wins: 589, Losses: 425, Steps: 36754, Time: 311.30s
# Ações: Manter=21655, Comprar=6532, Vender=8567
# Ganhos Totais: 29185.75, Perdas Totais: -23231.50
# Modelo e log do episódio 70 salvos em: 4.18\model_episode_70.pth e 4.18\log_episode_70.csv
#
# Episode 71/100, Total Reward: 1350.00, Win Rate: 0.55, Wins: 553, Losses: 446, Steps: 36754, Time: 311.13s
# Ações: Manter=25854, Comprar=5489, Vender=5411
# Ganhos Totais: 23980.00, Perdas Totais: -22379.50
# Modelo e log do episódio 71 salvos em: 4.18\model_episode_71.pth e 4.18\log_episode_71.csv
#
# Episode 72/100, Total Reward: 6462.00, Win Rate: 0.60, Wins: 422, Losses: 278, Steps: 36754, Time: 311.82s
# Ações: Manter=28373, Comprar=5698, Vender=2683
# Ganhos Totais: 21865.25, Perdas Totais: -15227.75
# Modelo e log do episódio 72 salvos em: 4.18\model_episode_72.pth e 4.18\log_episode_72.csv
#
# Episode 73/100, Total Reward: 5644.00, Win Rate: 0.57, Wins: 369, Losses: 273, Steps: 36754, Time: 310.57s
# Ações: Manter=27740, Comprar=5083, Vender=3931
# Ganhos Totais: 21539.50, Perdas Totais: -15735.00
# Modelo e log do episódio 73 salvos em: 4.18\model_episode_73.pth e 4.18\log_episode_73.csv
#
# Episode 74/100, Total Reward: 4428.50, Win Rate: 0.56, Wins: 504, Losses: 397, Steps: 36754, Time: 310.40s
# Ações: Manter=27756, Comprar=3451, Vender=5547
# Ganhos Totais: 21581.50, Perdas Totais: -16927.00
# Modelo e log do episódio 74 salvos em: 4.18\model_episode_74.pth e 4.18\log_episode_74.csv
#
# Episode 75/100, Total Reward: 6698.00, Win Rate: 0.56, Wins: 607, Losses: 486, Steps: 36754, Time: 310.88s
# Ações: Manter=17504, Comprar=12333, Vender=6917
# Ganhos Totais: 29083.75, Perdas Totais: -22111.50
# Modelo e log do episódio 75 salvos em: 4.18\model_episode_75.pth e 4.18\log_episode_75.csv
#
# Episode 76/100, Total Reward: 4524.75, Win Rate: 0.57, Wins: 1018, Losses: 760, Steps: 36754, Time: 310.75s
# Ações: Manter=13704, Comprar=14286, Vender=8764
# Ganhos Totais: 33297.50, Perdas Totais: -28326.50
# Modelo e log do episódio 76 salvos em: 4.18\model_episode_76.pth e 4.18\log_episode_76.csv
#
# Episode 77/100, Total Reward: 2266.25, Win Rate: 0.56, Wins: 1233, Losses: 972, Steps: 36754, Time: 310.44s
# Ações: Manter=15358, Comprar=8831, Vender=12565
# Ganhos Totais: 33234.50, Perdas Totais: -30413.75
# Modelo e log do episódio 77 salvos em: 4.18\model_episode_77.pth e 4.18\log_episode_77.csv
#
# Episode 78/100, Total Reward: 3767.00, Win Rate: 0.55, Wins: 764, Losses: 626, Steps: 36754, Time: 311.24s
# Ações: Manter=20114, Comprar=6624, Vender=10016
# Ganhos Totais: 28067.75, Perdas Totais: -23951.75
# Modelo e log do episódio 78 salvos em: 4.18\model_episode_78.pth e 4.18\log_episode_78.csv
#
# Episode 79/100, Total Reward: 5794.00, Win Rate: 0.52, Wins: 760, Losses: 710, Steps: 36754, Time: 311.00s
# Ações: Manter=21622, Comprar=9794, Vender=5338
# Ganhos Totais: 26751.75, Perdas Totais: -20587.75
# Modelo e log do episódio 79 salvos em: 4.18\model_episode_79.pth e 4.18\log_episode_79.csv
#
# Episode 80/100, Total Reward: 6617.75, Win Rate: 0.57, Wins: 401, Losses: 304, Steps: 36754, Time: 310.91s
# Ações: Manter=26873, Comprar=4715, Vender=5166
# Ganhos Totais: 23383.00, Perdas Totais: -16588.25
# Modelo e log do episódio 80 salvos em: 4.18\model_episode_80.pth e 4.18\log_episode_80.csv
#
# Episode 81/100, Total Reward: 2730.00, Win Rate: 0.52, Wins: 488, Losses: 446, Steps: 36754, Time: 312.79s
# Ações: Manter=25429, Comprar=2980, Vender=8345
# Ganhos Totais: 23293.50, Perdas Totais: -20329.25
# Modelo e log do episódio 81 salvos em: 4.18\model_episode_81.pth e 4.18\log_episode_81.csv
#
# Episode 82/100, Total Reward: 5129.25, Win Rate: 0.55, Wins: 598, Losses: 488, Steps: 36754, Time: 313.56s
# Ações: Manter=25690, Comprar=3904, Vender=7160
# Ganhos Totais: 24630.75, Perdas Totais: -19229.25
# Modelo e log do episódio 82 salvos em: 4.18\model_episode_82.pth e 4.18\log_episode_82.csv
#
# Episode 83/100, Total Reward: 3898.50, Win Rate: 0.58, Wins: 386, Losses: 284, Steps: 36754, Time: 312.64s
# Ações: Manter=31341, Comprar=2143, Vender=3270
# Ganhos Totais: 21202.25, Perdas Totais: -17135.50
# Modelo e log do episódio 83 salvos em: 4.18\model_episode_83.pth e 4.18\log_episode_83.csv
#
# Episode 84/100, Total Reward: 5500.75, Win Rate: 0.60, Wins: 477, Losses: 314, Steps: 36754, Time: 311.77s
# Ações: Manter=30132, Comprar=2412, Vender=4210
# Ganhos Totais: 22657.50, Perdas Totais: -16958.50
# Modelo e log do episódio 84 salvos em: 4.18\model_episode_84.pth e 4.18\log_episode_84.csv
#
# Episode 85/100, Total Reward: 815.50, Win Rate: 0.58, Wins: 239, Losses: 175, Steps: 36754, Time: 311.60s
# Ações: Manter=33608, Comprar=2736, Vender=410
# Ganhos Totais: 12969.75, Perdas Totais: -12050.25
# Modelo e log do episódio 85 salvos em: 4.18\model_episode_85.pth e 4.18\log_episode_85.csv
#
# Episode 86/100, Total Reward: 3066.50, Win Rate: 0.56, Wins: 516, Losses: 405, Steps: 36754, Time: 312.72s
# Ações: Manter=29406, Comprar=2478, Vender=4870
# Ganhos Totais: 18139.25, Perdas Totais: -14841.50
# Modelo e log do episódio 86 salvos em: 4.18\model_episode_86.pth e 4.18\log_episode_86.csv
#
# Episode 87/100, Total Reward: 2385.00, Win Rate: 0.54, Wins: 717, Losses: 601, Steps: 36754, Time: 313.39s
# Ações: Manter=21202, Comprar=6360, Vender=9192
# Ganhos Totais: 25249.50, Perdas Totais: -22534.50
# Modelo e log do episódio 87 salvos em: 4.18\model_episode_87.pth e 4.18\log_episode_87.csv
#
# Episode 88/100, Total Reward: 3510.00, Win Rate: 0.53, Wins: 956, Losses: 859, Steps: 36754, Time: 312.27s
# Ações: Manter=19046, Comprar=7136, Vender=10572
# Ganhos Totais: 30270.50, Perdas Totais: -26304.75
# Modelo e log do episódio 88 salvos em: 4.18\model_episode_88.pth e 4.18\log_episode_88.csv
#
# Episode 89/100, Total Reward: 5572.00, Win Rate: 0.55, Wins: 659, Losses: 544, Steps: 36754, Time: 311.91s
# Ações: Manter=15629, Comprar=15818, Vender=5307
# Ganhos Totais: 29134.75, Perdas Totais: -23261.00
# Modelo e log do episódio 89 salvos em: 4.18\model_episode_89.pth e 4.18\log_episode_89.csv
#
# Episode 90/100, Total Reward: 5212.25, Win Rate: 0.51, Wins: 657, Losses: 627, Steps: 36754, Time: 312.94s
# Ações: Manter=18536, Comprar=14535, Vender=3683
# Ganhos Totais: 27930.25, Perdas Totais: -22396.50
# Modelo e log do episódio 90 salvos em: 4.18\model_episode_90.pth e 4.18\log_episode_90.csv
#
# Episode 91/100, Total Reward: 2544.75, Win Rate: 0.53, Wins: 1503, Losses: 1331, Steps: 36754, Time: 313.16s
# Ações: Manter=3474, Comprar=21804, Vender=11476
# Ganhos Totais: 39082.50, Perdas Totais: -35826.25
# Modelo e log do episódio 91 salvos em: 4.18\model_episode_91.pth e 4.18\log_episode_91.csv
#
# Episode 92/100, Total Reward: 5252.25, Win Rate: 0.55, Wins: 771, Losses: 629, Steps: 36754, Time: 313.26s
# Ações: Manter=8574, Comprar=20408, Vender=7772
# Ganhos Totais: 31889.75, Perdas Totais: -26286.25
# Modelo e log do episódio 92 salvos em: 4.18\model_episode_92.pth e 4.18\log_episode_92.csv
#
# Episode 93/100, Total Reward: 4073.25, Win Rate: 0.57, Wins: 597, Losses: 450, Steps: 36754, Time: 313.07s
# Ações: Manter=17964, Comprar=10246, Vender=8544
# Ganhos Totais: 29253.75, Perdas Totais: -24917.50
# Modelo e log do episódio 93 salvos em: 4.18\model_episode_93.pth e 4.18\log_episode_93.csv
#
# Episode 94/100, Total Reward: 7379.75, Win Rate: 0.56, Wins: 687, Losses: 532, Steps: 36754, Time: 314.09s
# Ações: Manter=7164, Comprar=17612, Vender=11978
# Ganhos Totais: 33929.75, Perdas Totais: -26244.25
# Modelo e log do episódio 94 salvos em: 4.18\model_episode_94.pth e 4.18\log_episode_94.csv
#
# Episode 95/100, Total Reward: 4411.25, Win Rate: 0.57, Wins: 726, Losses: 556, Steps: 36754, Time: 314.41s
# Ações: Manter=9570, Comprar=21660, Vender=5524
# Ganhos Totais: 31151.75, Perdas Totais: -26419.25
# Modelo e log do episódio 95 salvos em: 4.18\model_episode_95.pth e 4.18\log_episode_95.csv
#
# Episode 96/100, Total Reward: -1042.00, Win Rate: 0.55, Wins: 655, Losses: 537, Steps: 36754, Time: 312.68s
# Ações: Manter=8832, Comprar=22118, Vender=5804
# Ganhos Totais: 27780.75, Perdas Totais: -28523.50
# Modelo e log do episódio 96 salvos em: 4.18\model_episode_96.pth e 4.18\log_episode_96.csv
#
# Episode 97/100, Total Reward: 5870.50, Win Rate: 0.59, Wins: 600, Losses: 411, Steps: 36754, Time: 312.63s
# Ações: Manter=15717, Comprar=10388, Vender=10649
# Ganhos Totais: 28677.25, Perdas Totais: -22553.75
# Modelo e log do episódio 97 salvos em: 4.18\model_episode_97.pth e 4.18\log_episode_97.csv
#
# Episode 98/100, Total Reward: 2669.75, Win Rate: 0.59, Wins: 620, Losses: 435, Steps: 36754, Time: 311.69s
# Ações: Manter=10940, Comprar=15926, Vender=9888
# Ganhos Totais: 27972.25, Perdas Totais: -25038.25
# Modelo e log do episódio 98 salvos em: 4.18\model_episode_98.pth e 4.18\log_episode_98.csv
#
# Episode 99/100, Total Reward: -2185.00, Win Rate: 0.55, Wins: 392, Losses: 323, Steps: 36754, Time: 312.99s
# Ações: Manter=16568, Comprar=9275, Vender=10911
# Ganhos Totais: 21197.50, Perdas Totais: -23203.00
# Modelo e log do episódio 99 salvos em: 4.18\model_episode_99.pth e 4.18\log_episode_99.csv
#
# Episode 100/100, Total Reward: 5766.00, Win Rate: 0.57, Wins: 435, Losses: 333, Steps: 36754, Time: 312.97s
# Ações: Manter=16528, Comprar=12263, Vender=7963
# Ganhos Totais: 25014.00, Perdas Totais: -19055.50
# Modelo e log do episódio 100 salvos em: 4.18\model_episode_100.pth e 4.18\log_episode_100.csv
#
#
# Treinamento finalizado.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
