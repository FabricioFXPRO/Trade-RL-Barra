# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time
import os

data = pd.read_csv('D:\\dados\\bar_M15_V03_data_01-01-2023_a_31-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = [
    'Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior',
    'Corpo', 'Range','SMA4','SMA8','SMA12','SMA20', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK',
    'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram','atr8','atr14','atr28','dayO','dayH','dayL'
]
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# %%
import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )
        self.trades = []

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)
        return obs.astype(np.float32)

    def step(self, action):
        done = self.current_step >= len(self.data) - 2
        reward = 0
        info = {}

        # Obter o valor atual e o próximo valor
        current_price = self.data['Valor'].iloc[self.current_step]
        next_price = self.data['Valor'].iloc[self.current_step + 1]

        # Obter o valor do gatilho no passo atual
        gatilho = int(self.data['Gatilho'].iloc[self.current_step])

        # Se o gatilho estiver ativo, o agente pode executar todas as ações
        if gatilho == 1:
            if action == 1:  # Comprar
                if self.position == 0:
                    self.position = 1  # Abrir posição comprada
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == -1:
                    # Fechar posição vendida
                    self.exit_price = current_price
                    profit = self.entry_price - self.exit_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_short',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            elif action == 2:  # Vender
                if self.position == 0:
                    self.position = -1  # Abrir posição vendida
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25
                    info['trade'] = {
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == 1:
                    # Fechar posição comprada
                    self.exit_price = current_price
                    profit = self.exit_price - self.entry_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_long',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            else:  # Manter
                pass
        else:
            # Fechar posição se o gatilho não estiver ativo
            if self.position == 1:
                self.exit_price = current_price
                profit = self.exit_price - self.entry_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_long',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'buy',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None
            elif self.position == -1:
                self.exit_price = current_price
                profit = self.entry_price - self.exit_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_short',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'sell',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None

        self.current_step += 1

        obs = self._next_observation()
        return obs, reward, done, info

# %% [markdown]
# ## Bloco 3: Criar o Agente Rainbow DQN usando PyTorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random
import math
import numpy as np

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Implementação da Camada Noisy Linear
class NoisyLinear(nn.Module):
    def __init__(self, in_features, out_features, sigma_init=0.017):
        super(NoisyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma_init = sigma_init

        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.register_buffer('weight_epsilon', torch.zeros(out_features, in_features))

        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        self.register_buffer('bias_epsilon', torch.zeros(out_features))

        self.reset_parameters()
        self.reset_noise()

    def reset_parameters(self):
        mu_range = 1 / math.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.sigma_init / math.sqrt(self.in_features))
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.sigma_init / math.sqrt(self.out_features))

    def reset_noise(self):
        epsilon_in = self._scale_noise(self.in_features)
        epsilon_out = self._scale_noise(self.out_features)
        self.weight_epsilon.copy_(epsilon_out.outer(epsilon_in))
        self.bias_epsilon.copy_(epsilon_out)

    def forward(self, x):
        if self.training:
            weight = self.weight_mu + self.weight_sigma * self.weight_epsilon
            bias = self.bias_mu + self.bias_sigma * self.bias_epsilon
        else:
            weight = self.weight_mu
            bias = self.bias_mu
        return nn.functional.linear(x, weight, bias)

    def _scale_noise(self, size):
        x = torch.randn(size)
        return x.sign().mul_(x.abs().sqrt())

# Implementação da Rede Rainbow DQN
class RainbowDQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(RainbowDQN, self).__init__()
        self.feature = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU()
        )
        # Advantage stream
        self.advantage = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, n_actions)
        )
        # Value stream
        self.value = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, 1)
        )

    def forward(self, x):
        x = self.feature(x)
        advantage = self.advantage(x)
        value = self.value(x)
        # Dueling Q-values
        q_values = value + advantage - advantage.mean()
        return q_values

    def reset_noise(self):
        for module in self.modules():
            if isinstance(module, NoisyLinear):
                module.reset_noise()

# Implementação do Prioritized Replay Buffer
class PrioritizedReplayBuffer(object):
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.alpha = alpha

        self.buffer = []
        self.pos = 0

        self.priorities = np.zeros((capacity,), dtype=np.float32)

    def push(self, *args):
        max_prio = self.priorities.max() if self.buffer else 1.0

        if len(self.buffer) < self.capacity:
            self.buffer.append((*args,))
        else:
            self.buffer[self.pos] = (*args,)

        self.priorities[self.pos] = max_prio
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, beta=0.4):
        if len(self.buffer) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.pos]

        probs = prios ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        total = len(self.buffer)
        weights = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = np.array(weights, dtype=np.float32)

        batch = list(zip(*samples))

        states = torch.cat(batch[0]).to(device)
        actions = torch.tensor(batch[1], dtype=torch.long, device=device).unsqueeze(1)
        rewards = torch.tensor(batch[2], dtype=torch.float32, device=device).unsqueeze(1)
        next_states = torch.cat(batch[3]).to(device)
        dones = torch.tensor(batch[4], dtype=torch.float32, device=device).unsqueeze(1)
        weights = torch.tensor(weights, dtype=torch.float32, device=device).unsqueeze(1)

        return states, actions, rewards, next_states, dones, indices, weights

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio

# %% [markdown]
# ## Bloco 4: Treinamento do Agente Rainbow DQN

# %%
# Configurações do treinamento
num_episodes = 100
gamma = 0.99
batch_size = 128
learning_rate = 5e-4
memory_size = 10000
target_update = 1000
beta_start = 0.4
beta_frames = num_episodes * len(data)
alpha = 0.6

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Instanciar a rede
q_net = RainbowDQN(obs_size, n_actions).to(device)
target_net = RainbowDQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=learning_rate)

# Inicializar o Prioritized Replay Buffer
replay_buffer = PrioritizedReplayBuffer(memory_size, alpha=alpha)

# Inicializar a lista de melhores episódios
best_episodes = []

# Função para selecionar ação usando Noisy Nets
def select_action(state):
    with torch.no_grad():
        q_values = q_net(state)
        return q_values.argmax().item()

save_dir = "4.18.2"
os.makedirs(save_dir, exist_ok=True)

beta = beta_start
frame_idx = 0  # Contador de frames para ajustar beta
for episode in range(num_episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0
    trades = []
    current_trade = None

    while not done:
        steps += 1
        frame_idx += 1

        # Selecionar ação
        action = select_action(obs)

        # Executar ação no ambiente
        obs_next, reward, done, info = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        replay_buffer.push(obs, action, reward, obs_next, done)

        # Atualizar o estado
        obs = obs_next

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Atualizar recompensa total
        total_reward += reward

        # Resetar ruído das Noisy Nets
        q_net.reset_noise()
        target_net.reset_noise()

        # Processar informações de trade
        if 'trade' in info:
            trade_info = info['trade']
            if trade_info['type'] in ['buy', 'sell']:
                current_trade = {
                    'type': trade_info['type'],
                    'entry_step': trade_info['entry_step'],
                    'entry_price': trade_info['entry_price'],
                    'entry_datetime': trade_info['entry_datetime'],
                    'exit_step': None,
                    'exit_price': None,
                    'exit_datetime': None,
                    'profit': None
                }
            elif trade_info['type'] in ['close_long', 'close_short']:
                current_trade['exit_step'] = trade_info['exit_step']
                current_trade['exit_price'] = trade_info['exit_price']
                current_trade['exit_datetime'] = trade_info['exit_datetime']
                current_trade['profit'] = trade_info['profit']
                trades.append(current_trade.copy())
                if current_trade['profit'] > 0:
                    wins += 1
                    win_total += current_trade['profit']
                elif current_trade['profit'] < 0:
                    losses += 1
                    lose_total += current_trade['profit']
                current_trade = None

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(replay_buffer.buffer) >= batch_size:
            beta = min(1.0, beta_start + frame_idx * (1.0 - beta_start) / beta_frames)
            states, actions_batch, rewards_batch, next_states, dones, indices, weights = replay_buffer.sample(batch_size, beta)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando Double DQN
            with torch.no_grad():
                next_actions = q_net(next_states).argmax(1, keepdim=True)
                next_q_values = target_net(next_states).gather(1, next_actions)
                target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular o erro para Prioritized Replay
            td_errors = (q_values - target_q_values).detach().cpu().numpy().flatten()
            new_priorities = np.abs(td_errors) + 1e-6
            replay_buffer.update_priorities(indices, new_priorities)

            # Calcular a perda ponderada
            loss = (weights * nn.functional.mse_loss(q_values, target_q_values, reduction='none')).mean()

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Atualizar a rede alvo
            if frame_idx % target_update == 0:
                target_net.load_state_dict(q_net.state_dict())

    # Cálculo do tempo de treinamento do episódio
    end_time = time.time()
    episode_time = end_time - start_time

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, "
          f"Wins: {wins}, Losses: {losses}, Steps: {steps}, Time: {episode_time:.2f}s")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}")

    # Salvar informações do episódio
    episode_info = {
        'episode': episode + 1,
        'total_reward': total_reward,
        'win_rate': win_rate,
        'wins': wins,
        'losses': losses,
        'actions_count': actions_count.copy(),
        'win_total': win_total,
        'lose_total': lose_total,
        'steps': steps,
        'episode_time': episode_time,
        'model_state_dict': q_net.state_dict(),
        'trades': trades.copy()
    }

    # Adicionar o episódio à lista dos melhores e manter os top 10
    best_episodes.append(episode_info)
    best_episodes = sorted(best_episodes, key=lambda x: x['total_reward'], reverse=True)[:10]

    # Salvar o modelo e log do episódio se for um dos top 10
    if episode_info in best_episodes:
        model_path = os.path.join(save_dir, f"model_episode_{episode_info['episode']}.pth")
        torch.save(episode_info['model_state_dict'], model_path)
        episode_info['model_path'] = model_path

        # Salvar o log completo das operações
        log_path = os.path.join(save_dir, f"log_episode_{episode_info['episode']}.csv")
        trades_df = pd.DataFrame(episode_info['trades'])
        trades_df.to_csv(log_path, index=False)
        episode_info['log_path'] = log_path

        print(f"Modelo e log do episódio {episode_info['episode']} salvos em: {model_path} e {log_path}\n")

# Exibir os top 10 episódios ao final do treinamento
print("\nTreinamento finalizado.")
print("Top 10 Melhores Episódios:")
for idx, ep in enumerate(best_episodes, 1):
    print(f"Rank {idx}: Episode {ep['episode']}, Total Reward: {ep['total_reward']:.2f}, "
          f"Win Rate: {ep['win_rate']:.2f}, Wins: {ep['wins']}, Losses: {ep['losses']}, "
          f"Ações: {ep['actions_count']}, Steps: {ep['steps']}, Time: {ep['episode_time']:.2f}s")
# Out:
# Episode 1/100, Total Reward: -903.00, Win Rate: 0.53, Wins: 602, Losses: 525, Steps: 36754, Time: 335.72s
# Ações: Manter=16576, Comprar=15743, Vender=4435
# Ganhos Totais: 25531.25, Perdas Totais: -26151.50
# Modelo e log do episódio 1 salvos em: 4.18.2\model_episode_1.pth e 4.18.2\log_episode_1.csv
#
# Episode 2/100, Total Reward: 1081.25, Win Rate: 0.50, Wins: 1055, Losses: 1042, Steps: 36754, Time: 386.33s
# Ações: Manter=11439, Comprar=16310, Vender=9005
# Ganhos Totais: 33843.25, Perdas Totais: -32235.00
# Modelo e log do episódio 2 salvos em: 4.18.2\model_episode_2.pth e 4.18.2\log_episode_2.csv
#
# Episode 3/100, Total Reward: -2173.00, Win Rate: 0.52, Wins: 966, Losses: 886, Steps: 36754, Time: 387.93s
# Ações: Manter=12397, Comprar=17101, Vender=7256
# Ganhos Totais: 30631.75, Perdas Totais: -32339.50
# Modelo e log do episódio 3 salvos em: 4.18.2\model_episode_3.pth e 4.18.2\log_episode_3.csv
#
# Episode 4/100, Total Reward: -6051.00, Win Rate: 0.47, Wins: 859, Losses: 950, Steps: 36754, Time: 383.75s
# Ações: Manter=13668, Comprar=13395, Vender=9691
# Ganhos Totais: 26355.00, Perdas Totais: -31952.25
# Modelo e log do episódio 4 salvos em: 4.18.2\model_episode_4.pth e 4.18.2\log_episode_4.csv
#
# Episode 5/100, Total Reward: -1744.00, Win Rate: 0.50, Wins: 942, Losses: 929, Steps: 36754, Time: 385.17s
# Ações: Manter=10329, Comprar=16561, Vender=9864
# Ganhos Totais: 31593.25, Perdas Totais: -32867.25
# Modelo e log do episódio 5 salvos em: 4.18.2\model_episode_5.pth e 4.18.2\log_episode_5.csv
#
# Episode 6/100, Total Reward: -423.50, Win Rate: 0.54, Wins: 681, Losses: 573, Steps: 36754, Time: 383.84s
# Ações: Manter=8541, Comprar=22331, Vender=5882
# Ganhos Totais: 28321.25, Perdas Totais: -28429.50
# Modelo e log do episódio 6 salvos em: 4.18.2\model_episode_6.pth e 4.18.2\log_episode_6.csv
#
# Episode 7/100, Total Reward: -346.00, Win Rate: 0.53, Wins: 667, Losses: 590, Steps: 36754, Time: 359.83s
# Ações: Manter=10647, Comprar=17508, Vender=8599
# Ganhos Totais: 28090.00, Perdas Totais: -28120.75
# Modelo e log do episódio 7 salvos em: 4.18.2\model_episode_7.pth e 4.18.2\log_episode_7.csv
#
# Episode 8/100, Total Reward: 2163.00, Win Rate: 0.53, Wins: 396, Losses: 345, Steps: 36754, Time: 310.21s
# Ações: Manter=844, Comprar=29950, Vender=5960
# Ganhos Totais: 25162.50, Perdas Totais: -22813.50
# Modelo e log do episódio 8 salvos em: 4.18.2\model_episode_8.pth e 4.18.2\log_episode_8.csv
#
# Episode 9/100, Total Reward: 4618.25, Win Rate: 0.55, Wins: 245, Losses: 200, Steps: 36754, Time: 310.19s
# Ações: Manter=467, Comprar=36256, Vender=31
# Ganhos Totais: 24215.75, Perdas Totais: -19486.25
# Modelo e log do episódio 9 salvos em: 4.18.2\model_episode_9.pth e 4.18.2\log_episode_9.csv
#
# Episode 10/100, Total Reward: 4608.50, Win Rate: 0.54, Wins: 245, Losses: 211, Steps: 36754, Time: 308.97s
# Ações: Manter=1190, Comprar=35530, Vender=34
# Ganhos Totais: 24787.00, Perdas Totais: -20064.50
# Modelo e log do episódio 10 salvos em: 4.18.2\model_episode_10.pth e 4.18.2\log_episode_10.csv
#
# Episode 11/100, Total Reward: 4732.75, Win Rate: 0.54, Wins: 255, Losses: 216, Steps: 36754, Time: 308.07s
# Ações: Manter=642, Comprar=36013, Vender=99
# Ganhos Totais: 24678.50, Perdas Totais: -19828.00
# Modelo e log do episódio 11 salvos em: 4.18.2\model_episode_11.pth e 4.18.2\log_episode_11.csv
#
# Episode 12/100, Total Reward: 1533.25, Win Rate: 0.52, Wins: 379, Losses: 352, Steps: 36754, Time: 312.04s
# Ações: Manter=5673, Comprar=27145, Vender=3936
# Ganhos Totais: 25126.25, Perdas Totais: -23410.00
# Modelo e log do episódio 12 salvos em: 4.18.2\model_episode_12.pth e 4.18.2\log_episode_12.csv
#
# Episode 13/100, Total Reward: 4282.00, Win Rate: 0.55, Wins: 467, Losses: 380, Steps: 36754, Time: 342.83s
# Ações: Manter=997, Comprar=34561, Vender=1196
# Ganhos Totais: 28059.50, Perdas Totais: -23565.25
# Modelo e log do episódio 13 salvos em: 4.18.2\model_episode_13.pth e 4.18.2\log_episode_13.csv
#
# Episode 14/100, Total Reward: 4319.50, Win Rate: 0.54, Wins: 281, Losses: 236, Steps: 36754, Time: 342.07s
# Ações: Manter=4431, Comprar=32147, Vender=176
# Ganhos Totais: 24513.00, Perdas Totais: -20064.25
# Modelo e log do episódio 14 salvos em: 4.18.2\model_episode_14.pth e 4.18.2\log_episode_14.csv
#
# Episode 15/100, Total Reward: 665.75, Win Rate: 0.54, Wins: 86, Losses: 73, Steps: 36754, Time: 341.69s
# Ações: Manter=33985, Comprar=2695, Vender=74
# Ganhos Totais: 6545.50, Perdas Totais: -5839.75
# Modelo e log do episódio 15 salvos em: 4.18.2\model_episode_15.pth e 4.18.2\log_episode_15.csv
#
# Episode 16/100, Total Reward: 103.25, Win Rate: 0.56, Wins: 5, Losses: 4, Steps: 36754, Time: 342.55s
# Ações: Manter=36724, Comprar=12, Vender=18
# Ganhos Totais: 252.25, Perdas Totais: -146.75
# Modelo e log do episódio 16 salvos em: 4.18.2\model_episode_16.pth e 4.18.2\log_episode_16.csv
#
# Episode 17/100, Total Reward: 604.75, Win Rate: 0.54, Wins: 27, Losses: 23, Steps: 36754, Time: 343.61s
# Ações: Manter=36165, Comprar=589, Vender=0
# Ganhos Totais: 2389.25, Perdas Totais: -1772.00
# Modelo e log do episódio 17 salvos em: 4.18.2\model_episode_17.pth e 4.18.2\log_episode_17.csv
#
# Episode 18/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.98s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 19/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 339.96s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 20/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.92s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 21/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.76s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 22/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.63s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 23/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.11s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 24/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.24s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 25/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.95s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 26/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.83s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 27/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.42s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 28/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.18s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 29/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.59s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 30/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.25s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 31/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.55s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 32/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.99s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 33/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.08s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 34/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.16s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 35/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.31s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 36/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.72s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 37/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.43s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 38/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.04s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 39/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.47s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 40/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.49s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 41/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.27s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 42/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.73s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 43/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.58s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 44/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.19s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 45/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.63s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 46/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.22s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 47/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.16s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 48/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.46s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 49/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.42s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 50/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.29s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 51/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.36s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 52/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.89s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 53/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.58s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 54/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.51s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 55/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.39s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 56/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.78s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 57/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.77s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 58/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.60s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 59/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.45s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 60/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.05s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 61/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.85s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 62/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.23s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 63/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.19s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 64/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 340.24s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 65/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.27s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 66/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.64s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 67/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.53s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 68/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.33s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 69/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.49s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 70/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.46s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 71/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.60s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 72/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.10s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 73/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.18s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 74/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.23s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 75/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.33s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 76/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.19s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 77/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.82s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 78/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.00s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 79/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.30s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 80/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.76s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 81/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.35s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 82/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.28s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 83/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.37s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 84/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.84s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 85/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.30s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 86/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.38s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 87/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.37s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 88/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.88s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 89/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.76s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 90/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.74s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 91/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.82s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 92/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.81s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 93/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 343.57s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 94/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.95s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 95/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 341.70s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 96/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.25s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 97/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.62s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 98/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.30s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 99/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.41s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 100/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 342.27s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
#
# Treinamento finalizado.
# Top 10 Melhores Episódios:
# Rank 1: Episode 11, Total Reward: 4732.75, Win Rate: 0.54, Wins: 255, Losses: 216, Ações: {0: 642, 1: 36013, 2: 99}, Steps: 36754, Time: 308.07s
# Rank 2: Episode 9, Total Reward: 4618.25, Win Rate: 0.55, Wins: 245, Losses: 200, Ações: {0: 467, 1: 36256, 2: 31}, Steps: 36754, Time: 310.19s
# Rank 3: Episode 10, Total Reward: 4608.50, Win Rate: 0.54, Wins: 245, Losses: 211, Ações: {0: 1190, 1: 35530, 2: 34}, Steps: 36754, Time: 308.97s
# Rank 4: Episode 14, Total Reward: 4319.50, Win Rate: 0.54, Wins: 281, Losses: 236, Ações: {0: 4431, 1: 32147, 2: 176}, Steps: 36754, Time: 342.07s
# Rank 5: Episode 13, Total Reward: 4282.00, Win Rate: 0.55, Wins: 467, Losses: 380, Ações: {0: 997, 1: 34561, 2: 1196}, Steps: 36754, Time: 342.83s
# Rank 6: Episode 8, Total Reward: 2163.00, Win Rate: 0.53, Wins: 396, Losses: 345, Ações: {0: 844, 1: 29950, 2: 5960}, Steps: 36754, Time: 310.21s
# Rank 7: Episode 12, Total Reward: 1533.25, Win Rate: 0.52, Wins: 379, Losses: 352, Ações: {0: 5673, 1: 27145, 2: 3936}, Steps: 36754, Time: 312.04s
# Rank 8: Episode 2, Total Reward: 1081.25, Win Rate: 0.50, Wins: 1055, Losses: 1042, Ações: {0: 11439, 1: 16310, 2: 9005}, Steps: 36754, Time: 386.33s
# Rank 9: Episode 15, Total Reward: 665.75, Win Rate: 0.54, Wins: 86, Losses: 73, Ações: {0: 33985, 1: 2695, 2: 74}, Steps: 36754, Time: 341.69s
# Rank 10: Episode 17, Total Reward: 604.75, Win Rate: 0.54, Wins: 27, Losses: 23, Ações: {0: 36165, 1: 589, 2: 0}, Steps: 36754, Time: 343.61s
