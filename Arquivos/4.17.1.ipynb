# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time
import os

data = pd.read_csv('D:\\dados\\bar_M15_V02_data_01-01-2023_a_31-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = [
    'Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior',
    'Corpo', 'Range', 'SMA4', 'SMA8', 'SMA12', 'SMA20', 'SMA50', 'SMA100', 'SMA200',
    'StochasticoK', 'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram',
    'atr8', 'atr14', 'atr28'
]
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# %%
import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )
        self.trades = []

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)
        return obs.astype(np.float32)

    def step(self, action):
        done = self.current_step >= len(self.data) - 2
        reward = 0
        info = {}

        # Obter o valor atual e o próximo valor
        current_price = self.data['Valor'].iloc[self.current_step]
        next_price = self.data['Valor'].iloc[self.current_step + 1]

        # Obter o valor do gatilho no passo atual
        gatilho = int(self.data['Gatilho'].iloc[self.current_step])

        # Se o gatilho estiver ativo, o agente pode executar todas as ações
        if gatilho == 1:
            if action == 1:  # Comprar
                if self.position == 0:
                    self.position = 1  # Abrir posição comprada
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == -1:
                    # Fechar posição vendida
                    self.exit_price = current_price
                    profit = self.entry_price - self.exit_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_short',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            elif action == 2:  # Vender
                if self.position == 0:
                    self.position = -1  # Abrir posição vendida
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25
                    info['trade'] = {
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == 1:
                    # Fechar posição comprada
                    self.exit_price = current_price
                    profit = self.exit_price - self.entry_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_long',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            else:  # Manter
                pass
        else:
            # Fechar posição se o gatilho não estiver ativo
            if self.position == 1:
                self.exit_price = current_price
                profit = self.exit_price - self.entry_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_long',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'buy',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None
            elif self.position == -1:
                self.exit_price = current_price
                profit = self.entry_price - self.exit_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_short',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'sell',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None

        self.current_step += 1

        obs = self._next_observation()
        return obs, reward, done, info

# %% [markdown]
# ## Bloco 3: Criar o Agente Rainbow DQN usando PyTorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random
import math
import numpy as np

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Implementação da Camada Noisy Linear
class NoisyLinear(nn.Module):
    def __init__(self, in_features, out_features, sigma_init=0.017):
        super(NoisyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma_init = sigma_init

        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.register_buffer('weight_epsilon', torch.zeros(out_features, in_features))

        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        self.register_buffer('bias_epsilon', torch.zeros(out_features))

        self.reset_parameters()
        self.reset_noise()

    def reset_parameters(self):
        mu_range = 1 / math.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.sigma_init / math.sqrt(self.in_features))
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.sigma_init / math.sqrt(self.out_features))

    def reset_noise(self):
        epsilon_in = self._scale_noise(self.in_features)
        epsilon_out = self._scale_noise(self.out_features)
        self.weight_epsilon.copy_(epsilon_out.outer(epsilon_in))
        self.bias_epsilon.copy_(epsilon_out)

    def forward(self, x):
        if self.training:
            weight = self.weight_mu + self.weight_sigma * self.weight_epsilon
            bias = self.bias_mu + self.bias_sigma * self.bias_epsilon
        else:
            weight = self.weight_mu
            bias = self.bias_mu
        return nn.functional.linear(x, weight, bias)

    def _scale_noise(self, size):
        x = torch.randn(size)
        return x.sign().mul_(x.abs().sqrt())

# Implementação da Rede Rainbow DQN
class RainbowDQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(RainbowDQN, self).__init__()
        self.feature = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU()
        )
        # Advantage stream
        self.advantage = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, n_actions)
        )
        # Value stream
        self.value = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, 1)
        )

    def forward(self, x):
        x = self.feature(x)
        advantage = self.advantage(x)
        value = self.value(x)
        # Dueling Q-values
        q_values = value + advantage - advantage.mean()
        return q_values

    def reset_noise(self):
        for module in self.modules():
            if isinstance(module, NoisyLinear):
                module.reset_noise()

# Implementação do Prioritized Replay Buffer
class PrioritizedReplayBuffer(object):
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.alpha = alpha

        self.buffer = []
        self.pos = 0

        self.priorities = np.zeros((capacity,), dtype=np.float32)

    def push(self, *args):
        max_prio = self.priorities.max() if self.buffer else 1.0

        if len(self.buffer) < self.capacity:
            self.buffer.append((*args,))
        else:
            self.buffer[self.pos] = (*args,)

        self.priorities[self.pos] = max_prio
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, beta=0.4):
        if len(self.buffer) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.pos]

        probs = prios ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        total = len(self.buffer)
        weights = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = np.array(weights, dtype=np.float32)

        batch = list(zip(*samples))

        states = torch.cat(batch[0]).to(device)
        actions = torch.tensor(batch[1], dtype=torch.long, device=device).unsqueeze(1)
        rewards = torch.tensor(batch[2], dtype=torch.float32, device=device).unsqueeze(1)
        next_states = torch.cat(batch[3]).to(device)
        dones = torch.tensor(batch[4], dtype=torch.float32, device=device).unsqueeze(1)
        weights = torch.tensor(weights, dtype=torch.float32, device=device).unsqueeze(1)

        return states, actions, rewards, next_states, dones, indices, weights

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio

# %% [markdown]
# ## Bloco 4: Treinamento do Agente Rainbow DQN

# %%
# Configurações do treinamento
num_episodes = 100
gamma = 0.99
batch_size = 64
learning_rate = 5e-4
memory_size = 10000
target_update = 1000
beta_start = 0.4
beta_frames = num_episodes * len(data)
alpha = 0.6

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Instanciar a rede
q_net = RainbowDQN(obs_size, n_actions).to(device)
target_net = RainbowDQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=learning_rate)

# Inicializar o Prioritized Replay Buffer
replay_buffer = PrioritizedReplayBuffer(memory_size, alpha=alpha)

# Inicializar a lista de melhores episódios
best_episodes = []

# Função para selecionar ação usando Noisy Nets
def select_action(state):
    with torch.no_grad():
        q_values = q_net(state)
        return q_values.argmax().item()

save_dir = "4.17.1"
os.makedirs(save_dir, exist_ok=True)

beta = beta_start
frame_idx = 0  # Contador de frames para ajustar beta
for episode in range(num_episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0
    trades = []
    current_trade = None

    while not done:
        steps += 1
        frame_idx += 1

        # Selecionar ação
        action = select_action(obs)

        # Executar ação no ambiente
        obs_next, reward, done, info = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        replay_buffer.push(obs, action, reward, obs_next, done)

        # Atualizar o estado
        obs = obs_next

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Atualizar recompensa total
        total_reward += reward

        # Resetar ruído das Noisy Nets
        q_net.reset_noise()
        target_net.reset_noise()

        # Processar informações de trade
        if 'trade' in info:
            trade_info = info['trade']
            if trade_info['type'] in ['buy', 'sell']:
                current_trade = {
                    'type': trade_info['type'],
                    'entry_step': trade_info['entry_step'],
                    'entry_price': trade_info['entry_price'],
                    'entry_datetime': trade_info['entry_datetime'],
                    'exit_step': None,
                    'exit_price': None,
                    'exit_datetime': None,
                    'profit': None
                }
            elif trade_info['type'] in ['close_long', 'close_short']:
                current_trade['exit_step'] = trade_info['exit_step']
                current_trade['exit_price'] = trade_info['exit_price']
                current_trade['exit_datetime'] = trade_info['exit_datetime']
                current_trade['profit'] = trade_info['profit']
                trades.append(current_trade.copy())
                if current_trade['profit'] > 0:
                    wins += 1
                    win_total += current_trade['profit']
                elif current_trade['profit'] < 0:
                    losses += 1
                    lose_total += current_trade['profit']
                current_trade = None

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(replay_buffer.buffer) >= batch_size:
            beta = min(1.0, beta_start + frame_idx * (1.0 - beta_start) / beta_frames)
            states, actions_batch, rewards_batch, next_states, dones, indices, weights = replay_buffer.sample(batch_size, beta)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando Double DQN
            with torch.no_grad():
                next_actions = q_net(next_states).argmax(1, keepdim=True)
                next_q_values = target_net(next_states).gather(1, next_actions)
                target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular o erro para Prioritized Replay
            td_errors = (q_values - target_q_values).detach().cpu().numpy().flatten()
            new_priorities = np.abs(td_errors) + 1e-6
            replay_buffer.update_priorities(indices, new_priorities)

            # Calcular a perda ponderada
            loss = (weights * nn.functional.mse_loss(q_values, target_q_values, reduction='none')).mean()

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Atualizar a rede alvo
            if frame_idx % target_update == 0:
                target_net.load_state_dict(q_net.state_dict())

    # Cálculo do tempo de treinamento do episódio
    end_time = time.time()
    episode_time = end_time - start_time

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, "
          f"Wins: {wins}, Losses: {losses}, Steps: {steps}, Time: {episode_time:.2f}s")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}")

    # Salvar informações do episódio
    episode_info = {
        'episode': episode + 1,
        'total_reward': total_reward,
        'win_rate': win_rate,
        'wins': wins,
        'losses': losses,
        'actions_count': actions_count.copy(),
        'win_total': win_total,
        'lose_total': lose_total,
        'steps': steps,
        'episode_time': episode_time,
        'model_state_dict': q_net.state_dict(),
        'trades': trades.copy()
    }

    # Adicionar o episódio à lista dos melhores e manter os top 10
    best_episodes.append(episode_info)
    best_episodes = sorted(best_episodes, key=lambda x: x['total_reward'], reverse=True)[:10]

    # Salvar o modelo e log do episódio se for um dos top 10
    if episode_info in best_episodes:
        model_path = os.path.join(save_dir, f"model_episode_{episode_info['episode']}.pth")
        torch.save(episode_info['model_state_dict'], model_path)
        episode_info['model_path'] = model_path

        # Salvar o log completo das operações
        log_path = os.path.join(save_dir, f"log_episode_{episode_info['episode']}.csv")
        trades_df = pd.DataFrame(episode_info['trades'])
        trades_df.to_csv(log_path, index=False)
        episode_info['log_path'] = log_path

        print(f"Modelo e log do episódio {episode_info['episode']} salvos em: {model_path} e {log_path}\n")

# Exibir os top 10 episódios ao final do treinamento
print("\nTreinamento finalizado.")
print("Top 10 Melhores Episódios:")
for idx, ep in enumerate(best_episodes, 1):
    print(f"Rank {idx}: Episode {ep['episode']}, Total Reward: {ep['total_reward']:.2f}, "
          f"Win Rate: {ep['win_rate']:.2f}, Wins: {ep['wins']}, Losses: {ep['losses']}, "
          f"Ações: {ep['actions_count']}, Steps: {ep['steps']}, Time: {ep['episode_time']:.2f}s")
# Out:
# Episode 1/100, Total Reward: -5101.75, Win Rate: 0.51, Wins: 306, Losses: 294, Steps: 36754, Time: 308.86s
# Ações: Manter=27576, Comprar=3915, Vender=5263
# Ganhos Totais: 16489.75, Perdas Totais: -21441.00
# Modelo e log do episódio 1 salvos em: 4.17.1\model_episode_1.pth e 4.17.1\log_episode_1.csv
#
# Episode 2/100, Total Reward: 83.50, Win Rate: 0.52, Wins: 853, Losses: 782, Steps: 36754, Time: 307.11s
# Ações: Manter=13442, Comprar=15455, Vender=7857
# Ganhos Totais: 31112.25, Perdas Totais: -30619.25
# Modelo e log do episódio 2 salvos em: 4.17.1\model_episode_2.pth e 4.17.1\log_episode_2.csv
#
# Episode 3/100, Total Reward: -1403.00, Win Rate: 0.51, Wins: 963, Losses: 914, Steps: 36754, Time: 291.93s
# Ações: Manter=11189, Comprar=12882, Vender=12683
# Ganhos Totais: 31858.75, Perdas Totais: -32790.50
# Modelo e log do episódio 3 salvos em: 4.17.1\model_episode_3.pth e 4.17.1\log_episode_3.csv
#
# Episode 4/100, Total Reward: -3167.75, Win Rate: 0.52, Wins: 1122, Losses: 1024, Steps: 36754, Time: 287.59s
# Ações: Manter=11719, Comprar=11875, Vender=13160
# Ganhos Totais: 32486.00, Perdas Totais: -35114.00
# Modelo e log do episódio 4 salvos em: 4.17.1\model_episode_4.pth e 4.17.1\log_episode_4.csv
#
# Episode 5/100, Total Reward: -2796.50, Win Rate: 0.54, Wins: 929, Losses: 786, Steps: 36754, Time: 288.34s
# Ações: Manter=12913, Comprar=11656, Vender=12185
# Ganhos Totais: 29849.00, Perdas Totais: -32214.75
# Modelo e log do episódio 5 salvos em: 4.17.1\model_episode_5.pth e 4.17.1\log_episode_5.csv
#
# Episode 6/100, Total Reward: 2246.50, Win Rate: 0.54, Wins: 1202, Losses: 1041, Steps: 36754, Time: 287.98s
# Ações: Manter=12487, Comprar=14327, Vender=9940
# Ganhos Totais: 34108.50, Perdas Totais: -31297.75
# Modelo e log do episódio 6 salvos em: 4.17.1\model_episode_6.pth e 4.17.1\log_episode_6.csv
#
# Episode 7/100, Total Reward: 655.75, Win Rate: 0.54, Wins: 775, Losses: 657, Steps: 36754, Time: 288.44s
# Ações: Manter=13138, Comprar=13900, Vender=9716
# Ganhos Totais: 29389.75, Perdas Totais: -28375.25
# Modelo e log do episódio 7 salvos em: 4.17.1\model_episode_7.pth e 4.17.1\log_episode_7.csv
#
# Episode 8/100, Total Reward: -1360.75, Win Rate: 0.52, Wins: 694, Losses: 633, Steps: 36754, Time: 288.31s
# Ações: Manter=9532, Comprar=13909, Vender=13313
# Ganhos Totais: 27925.25, Perdas Totais: -28953.75
# Modelo e log do episódio 8 salvos em: 4.17.1\model_episode_8.pth e 4.17.1\log_episode_8.csv
#
# Episode 9/100, Total Reward: -5613.00, Win Rate: 0.48, Wins: 332, Losses: 357, Steps: 36754, Time: 287.97s
# Ações: Manter=3785, Comprar=621, Vender=32348
# Ganhos Totais: 21630.00, Perdas Totais: -27070.50
# Modelo e log do episódio 9 salvos em: 4.17.1\model_episode_9.pth e 4.17.1\log_episode_9.csv
#
# Episode 10/100, Total Reward: -5243.00, Win Rate: 0.48, Wins: 280, Losses: 303, Steps: 36754, Time: 288.16s
# Ações: Manter=3097, Comprar=398, Vender=33259
# Ganhos Totais: 20838.00, Perdas Totais: -25935.00
# Modelo e log do episódio 10 salvos em: 4.17.1\model_episode_10.pth e 4.17.1\log_episode_10.csv
#
# Episode 11/100, Total Reward: -4883.25, Win Rate: 0.45, Wins: 204, Losses: 248, Steps: 36754, Time: 287.24s
# Ações: Manter=2393, Comprar=40, Vender=34321
# Ganhos Totais: 19651.25, Perdas Totais: -24421.50
# Modelo e log do episódio 11 salvos em: 4.17.1\model_episode_11.pth e 4.17.1\log_episode_11.csv
#
# Episode 12/100, Total Reward: -5220.75, Win Rate: 0.47, Wins: 226, Losses: 252, Steps: 36754, Time: 287.42s
# Ações: Manter=2179, Comprar=64, Vender=34511
# Ganhos Totais: 19881.50, Perdas Totais: -24982.75
# Modelo e log do episódio 12 salvos em: 4.17.1\model_episode_12.pth e 4.17.1\log_episode_12.csv
#
# Episode 13/100, Total Reward: -4796.75, Win Rate: 0.46, Wins: 215, Losses: 256, Steps: 36754, Time: 287.58s
# Ações: Manter=3173, Comprar=63, Vender=33518
# Ganhos Totais: 19962.50, Perdas Totais: -24641.25
# Modelo e log do episódio 13 salvos em: 4.17.1\model_episode_13.pth e 4.17.1\log_episode_13.csv
#
# Episode 14/100, Total Reward: -4897.00, Win Rate: 0.45, Wins: 199, Losses: 240, Steps: 36754, Time: 290.63s
# Ações: Manter=6116, Comprar=18, Vender=30620
# Ganhos Totais: 19364.00, Perdas Totais: -24151.25
# Modelo e log do episódio 14 salvos em: 4.17.1\model_episode_14.pth e 4.17.1\log_episode_14.csv
#
# Episode 15/100, Total Reward: -4153.00, Win Rate: 0.49, Wins: 287, Losses: 301, Steps: 36754, Time: 287.20s
# Ações: Manter=9867, Comprar=244, Vender=26643
# Ganhos Totais: 19602.25, Perdas Totais: -23608.00
# Modelo e log do episódio 15 salvos em: 4.17.1\model_episode_15.pth e 4.17.1\log_episode_15.csv
#
# Episode 16/100, Total Reward: -5977.50, Win Rate: 0.47, Wins: 405, Losses: 450, Steps: 36754, Time: 288.24s
# Ações: Manter=984, Comprar=561, Vender=35209
# Ganhos Totais: 22702.50, Perdas Totais: -28465.25
# Episode 17/100, Total Reward: -5642.50, Win Rate: 0.47, Wins: 624, Losses: 692, Steps: 36754, Time: 287.04s
# Ações: Manter=976, Comprar=1570, Vender=34208
# Ganhos Totais: 25854.75, Perdas Totais: -31165.75
# Episode 18/100, Total Reward: -5019.25, Win Rate: 0.53, Wins: 447, Losses: 404, Steps: 36754, Time: 287.07s
# Ações: Manter=12709, Comprar=588, Vender=23457
# Ganhos Totais: 20723.00, Perdas Totais: -25528.00
# Episode 19/100, Total Reward: -2032.50, Win Rate: 0.55, Wins: 446, Losses: 367, Steps: 36754, Time: 286.14s
# Ações: Manter=13797, Comprar=632, Vender=22325
# Ganhos Totais: 22799.00, Perdas Totais: -24627.75
# Modelo e log do episódio 19 salvos em: 4.17.1\model_episode_19.pth e 4.17.1\log_episode_19.csv
#
# Episode 20/100, Total Reward: -6119.25, Win Rate: 0.52, Wins: 510, Losses: 468, Steps: 36754, Time: 286.51s
# Ações: Manter=8568, Comprar=723, Vender=27463
# Ganhos Totais: 24612.50, Perdas Totais: -30487.00
# Episode 21/100, Total Reward: -2092.25, Win Rate: 0.57, Wins: 472, Losses: 361, Steps: 36754, Time: 286.20s
# Ações: Manter=15872, Comprar=656, Vender=20226
# Ganhos Totais: 20784.00, Perdas Totais: -22667.50
# Modelo e log do episódio 21 salvos em: 4.17.1\model_episode_21.pth e 4.17.1\log_episode_21.csv
#
# Episode 22/100, Total Reward: -4535.00, Win Rate: 0.56, Wins: 558, Losses: 431, Steps: 36754, Time: 285.97s
# Ações: Manter=19898, Comprar=765, Vender=16091
# Ganhos Totais: 22989.00, Perdas Totais: -27276.00
# Episode 23/100, Total Reward: -1646.75, Win Rate: 0.56, Wins: 484, Losses: 377, Steps: 36754, Time: 286.66s
# Ações: Manter=20663, Comprar=701, Vender=15390
# Ganhos Totais: 20541.75, Perdas Totais: -21972.50
# Modelo e log do episódio 23 salvos em: 4.17.1\model_episode_23.pth e 4.17.1\log_episode_23.csv
#
# Episode 24/100, Total Reward: -4196.75, Win Rate: 0.51, Wins: 304, Losses: 292, Steps: 36754, Time: 286.47s
# Ações: Manter=16438, Comprar=296, Vender=20020
# Ganhos Totais: 18928.50, Perdas Totais: -22976.00
# Episode 25/100, Total Reward: -5596.50, Win Rate: 0.49, Wins: 294, Losses: 303, Steps: 36754, Time: 286.52s
# Ações: Manter=17867, Comprar=302, Vender=18585
# Ganhos Totais: 18452.25, Perdas Totais: -23899.25
# Episode 26/100, Total Reward: -1435.50, Win Rate: 0.54, Wins: 287, Losses: 247, Steps: 36754, Time: 286.36s
# Ações: Manter=27378, Comprar=369, Vender=9007
# Ganhos Totais: 16401.75, Perdas Totais: -17703.50
# Modelo e log do episódio 26 salvos em: 4.17.1\model_episode_26.pth e 4.17.1\log_episode_26.csv
#
# Episode 27/100, Total Reward: -916.50, Win Rate: 0.47, Wins: 153, Losses: 174, Steps: 36754, Time: 287.10s
# Ações: Manter=27934, Comprar=93, Vender=8727
# Ganhos Totais: 13526.00, Perdas Totais: -14360.75
# Modelo e log do episódio 27 salvos em: 4.17.1\model_episode_27.pth e 4.17.1\log_episode_27.csv
#
# Episode 28/100, Total Reward: -4352.25, Win Rate: 0.41, Wins: 104, Losses: 150, Steps: 36754, Time: 287.54s
# Ações: Manter=30133, Comprar=711, Vender=5910
# Ganhos Totais: 7039.00, Perdas Totais: -11327.50
# Episode 29/100, Total Reward: 123.75, Win Rate: 0.51, Wins: 81, Losses: 78, Steps: 36754, Time: 286.66s
# Ações: Manter=26190, Comprar=4386, Vender=6178
# Ganhos Totais: 9436.25, Perdas Totais: -9272.75
# Modelo e log do episódio 29 salvos em: 4.17.1\model_episode_29.pth e 4.17.1\log_episode_29.csv
#
# Episode 30/100, Total Reward: -1167.75, Win Rate: 0.47, Wins: 317, Losses: 360, Steps: 36754, Time: 286.32s
# Ações: Manter=9, Comprar=4931, Vender=31814
# Ganhos Totais: 23386.50, Perdas Totais: -24384.75
# Modelo e log do episódio 30 salvos em: 4.17.1\model_episode_30.pth e 4.17.1\log_episode_30.csv
#
# Episode 31/100, Total Reward: -1433.00, Win Rate: 0.48, Wins: 445, Losses: 487, Steps: 36754, Time: 285.98s
# Ações: Manter=2, Comprar=4898, Vender=31854
# Ganhos Totais: 25909.25, Perdas Totais: -27107.50
# Modelo e log do episódio 31 salvos em: 4.17.1\model_episode_31.pth e 4.17.1\log_episode_31.csv
#
# Episode 32/100, Total Reward: -1370.50, Win Rate: 0.51, Wins: 701, Losses: 687, Steps: 36754, Time: 286.03s
# Ações: Manter=0, Comprar=10240, Vender=26514
# Ganhos Totais: 29086.50, Perdas Totais: -30108.50
# Modelo e log do episódio 32 salvos em: 4.17.1\model_episode_32.pth e 4.17.1\log_episode_32.csv
#
# Episode 33/100, Total Reward: -2881.25, Win Rate: 0.50, Wins: 611, Losses: 610, Steps: 36754, Time: 286.92s
# Ações: Manter=40, Comprar=5403, Vender=31311
# Ganhos Totais: 27278.25, Perdas Totais: -29853.25
# Episode 34/100, Total Reward: -2307.50, Win Rate: 0.54, Wins: 592, Losses: 500, Steps: 36754, Time: 286.44s
# Ações: Manter=30, Comprar=5333, Vender=31391
# Ganhos Totais: 27238.25, Perdas Totais: -29272.00
# Episode 35/100, Total Reward: -1375.00, Win Rate: 0.53, Wins: 723, Losses: 650, Steps: 36754, Time: 286.39s
# Ações: Manter=25, Comprar=5103, Vender=31626
# Ganhos Totais: 30315.75, Perdas Totais: -31347.25
# Modelo e log do episódio 35 salvos em: 4.17.1\model_episode_35.pth e 4.17.1\log_episode_35.csv
#
# Episode 36/100, Total Reward: -692.25, Win Rate: 0.53, Wins: 803, Losses: 713, Steps: 36754, Time: 286.18s
# Ações: Manter=1082, Comprar=5435, Vender=30237
# Ganhos Totais: 29841.00, Perdas Totais: -30152.50
# Modelo e log do episódio 36 salvos em: 4.17.1\model_episode_36.pth e 4.17.1\log_episode_36.csv
#
# Episode 37/100, Total Reward: -1651.75, Win Rate: 0.54, Wins: 440, Losses: 375, Steps: 36754, Time: 286.75s
# Ações: Manter=29, Comprar=4871, Vender=31854
# Ganhos Totais: 25647.50, Perdas Totais: -27095.50
# Episode 38/100, Total Reward: -1295.00, Win Rate: 0.54, Wins: 431, Losses: 373, Steps: 36754, Time: 286.65s
# Ações: Manter=1, Comprar=4894, Vender=31859
# Ganhos Totais: 25891.75, Perdas Totais: -26985.75
# Modelo e log do episódio 38 salvos em: 4.17.1\model_episode_38.pth e 4.17.1\log_episode_38.csv
#
# Episode 39/100, Total Reward: -1401.25, Win Rate: 0.55, Wins: 425, Losses: 346, Steps: 36754, Time: 287.47s
# Ações: Manter=4, Comprar=4817, Vender=31933
# Ganhos Totais: 25697.75, Perdas Totais: -26906.00
# Episode 40/100, Total Reward: -1596.25, Win Rate: 0.55, Wins: 551, Losses: 447, Steps: 36754, Time: 287.21s
# Ações: Manter=4, Comprar=5186, Vender=31564
# Ganhos Totais: 26561.50, Perdas Totais: -27908.00
# Episode 41/100, Total Reward: -1788.25, Win Rate: 0.55, Wins: 554, Losses: 461, Steps: 36754, Time: 286.16s
# Ações: Manter=4, Comprar=5078, Vender=31672
# Ganhos Totais: 27460.00, Perdas Totais: -28994.25
# Episode 42/100, Total Reward: -1997.75, Win Rate: 0.54, Wins: 512, Losses: 439, Steps: 36754, Time: 287.00s
# Ações: Manter=27, Comprar=5020, Vender=31707
# Ganhos Totais: 26006.25, Perdas Totais: -27765.00
# Episode 43/100, Total Reward: -958.00, Win Rate: 0.54, Wins: 488, Losses: 424, Steps: 36754, Time: 286.23s
# Ações: Manter=222, Comprar=4756, Vender=31776
# Ganhos Totais: 24847.50, Perdas Totais: -25577.00
# Modelo e log do episódio 43 salvos em: 4.17.1\model_episode_43.pth e 4.17.1\log_episode_43.csv
#
# Episode 44/100, Total Reward: -1028.00, Win Rate: 0.51, Wins: 268, Losses: 258, Steps: 36754, Time: 286.20s
# Ações: Manter=258, Comprar=4546, Vender=31950
# Ganhos Totais: 22311.25, Perdas Totais: -23207.50
# Modelo e log do episódio 44 salvos em: 4.17.1\model_episode_44.pth e 4.17.1\log_episode_44.csv
#
# Episode 45/100, Total Reward: -602.50, Win Rate: 0.52, Wins: 269, Losses: 248, Steps: 36754, Time: 286.31s
# Ações: Manter=229, Comprar=4544, Vender=31981
# Ganhos Totais: 22844.50, Perdas Totais: -23317.75
# Modelo e log do episódio 45 salvos em: 4.17.1\model_episode_45.pth e 4.17.1\log_episode_45.csv
#
# Episode 46/100, Total Reward: -1646.00, Win Rate: 0.51, Wins: 280, Losses: 266, Steps: 36754, Time: 286.07s
# Ações: Manter=157, Comprar=4580, Vender=32017
# Ganhos Totais: 22270.00, Perdas Totais: -23779.25
# Episode 47/100, Total Reward: -1104.25, Win Rate: 0.50, Wins: 265, Losses: 260, Steps: 36754, Time: 286.07s
# Ações: Manter=135, Comprar=4538, Vender=32081
# Ganhos Totais: 22266.00, Perdas Totais: -23239.00
# Modelo e log do episódio 47 salvos em: 4.17.1\model_episode_47.pth e 4.17.1\log_episode_47.csv
#
# Episode 48/100, Total Reward: -571.25, Win Rate: 0.54, Wins: 412, Losses: 351, Steps: 36754, Time: 286.42s
# Ações: Manter=16, Comprar=5249, Vender=31489
# Ganhos Totais: 26554.50, Perdas Totais: -26934.25
# Modelo e log do episódio 48 salvos em: 4.17.1\model_episode_48.pth e 4.17.1\log_episode_48.csv
#
# Episode 49/100, Total Reward: 1696.25, Win Rate: 0.49, Wins: 441, Losses: 465, Steps: 36754, Time: 286.30s
# Ações: Manter=572, Comprar=29608, Vender=6574
# Ganhos Totais: 25978.50, Perdas Totais: -24054.75
# Modelo e log do episódio 49 salvos em: 4.17.1\model_episode_49.pth e 4.17.1\log_episode_49.csv
#
# Episode 50/100, Total Reward: 2596.75, Win Rate: 0.55, Wins: 218, Losses: 182, Steps: 36754, Time: 286.90s
# Ações: Manter=16411, Comprar=18597, Vender=1746
# Ganhos Totais: 15676.75, Perdas Totais: -12979.75
# Modelo e log do episódio 50 salvos em: 4.17.1\model_episode_50.pth e 4.17.1\log_episode_50.csv
#
# Episode 51/100, Total Reward: 210.00, Win Rate: 0.63, Wins: 38, Losses: 22, Steps: 36754, Time: 287.19s
# Ações: Manter=33624, Comprar=1193, Vender=1937
# Ganhos Totais: 2943.75, Perdas Totais: -2718.75
# Modelo e log do episódio 51 salvos em: 4.17.1\model_episode_51.pth e 4.17.1\log_episode_51.csv
#
# Episode 52/100, Total Reward: 1682.75, Win Rate: 0.60, Wins: 47, Losses: 31, Steps: 36754, Time: 286.66s
# Ações: Manter=31822, Comprar=4856, Vender=76
# Ganhos Totais: 4690.25, Perdas Totais: -2988.00
# Modelo e log do episódio 52 salvos em: 4.17.1\model_episode_52.pth e 4.17.1\log_episode_52.csv
#
# Episode 53/100, Total Reward: -1906.00, Win Rate: 0.34, Wins: 25, Losses: 49, Steps: 36754, Time: 286.20s
# Ações: Manter=33842, Comprar=568, Vender=2344
# Ganhos Totais: 2288.25, Perdas Totais: -4175.75
# Episode 54/100, Total Reward: 678.25, Win Rate: 0.51, Wins: 159, Losses: 151, Steps: 36754, Time: 286.10s
# Ações: Manter=14689, Comprar=20200, Vender=1865
# Ganhos Totais: 15300.25, Perdas Totais: -14544.50
# Modelo e log do episódio 54 salvos em: 4.17.1\model_episode_54.pth e 4.17.1\log_episode_54.csv
#
# Episode 55/100, Total Reward: 4559.25, Win Rate: 0.54, Wins: 234, Losses: 199, Steps: 36754, Time: 286.80s
# Ações: Manter=1, Comprar=36747, Vender=6
# Ganhos Totais: 24135.00, Perdas Totais: -19467.50
# Modelo e log do episódio 55 salvos em: 4.17.1\model_episode_55.pth e 4.17.1\log_episode_55.csv
#
# Episode 56/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.41s
# Ações: Manter=1, Comprar=36753, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 56 salvos em: 4.17.1\model_episode_56.pth e 4.17.1\log_episode_56.csv
#
# Episode 57/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.16s
# Ações: Manter=0, Comprar=36753, Vender=1
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 57 salvos em: 4.17.1\model_episode_57.pth e 4.17.1\log_episode_57.csv
#
# Episode 58/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.38s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 58 salvos em: 4.17.1\model_episode_58.pth e 4.17.1\log_episode_58.csv
#
# Episode 59/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 285.79s
# Ações: Manter=1, Comprar=36753, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 59 salvos em: 4.17.1\model_episode_59.pth e 4.17.1\log_episode_59.csv
#
# Episode 60/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 285.84s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 60 salvos em: 4.17.1\model_episode_60.pth e 4.17.1\log_episode_60.csv
#
# Episode 61/100, Total Reward: 4553.50, Win Rate: 0.54, Wins: 233, Losses: 197, Steps: 36754, Time: 286.63s
# Ações: Manter=0, Comprar=36752, Vender=2
# Ganhos Totais: 24092.50, Perdas Totais: -19431.50
# Modelo e log do episódio 61 salvos em: 4.17.1\model_episode_61.pth e 4.17.1\log_episode_61.csv
#
# Episode 62/100, Total Reward: 4564.00, Win Rate: 0.54, Wins: 234, Losses: 196, Steps: 36754, Time: 287.12s
# Ações: Manter=23, Comprar=36730, Vender=1
# Ganhos Totais: 24117.00, Perdas Totais: -19445.50
# Modelo e log do episódio 62 salvos em: 4.17.1\model_episode_62.pth e 4.17.1\log_episode_62.csv
#
# Episode 63/100, Total Reward: 4509.50, Win Rate: 0.54, Wins: 234, Losses: 196, Steps: 36754, Time: 286.79s
# Ações: Manter=21, Comprar=36732, Vender=1
# Ganhos Totais: 24111.25, Perdas Totais: -19494.25
# Modelo e log do episódio 63 salvos em: 4.17.1\model_episode_63.pth e 4.17.1\log_episode_63.csv
#
# Episode 64/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.33s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 64 salvos em: 4.17.1\model_episode_64.pth e 4.17.1\log_episode_64.csv
#
# Episode 65/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.37s
# Ações: Manter=1, Comprar=36753, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Modelo e log do episódio 65 salvos em: 4.17.1\model_episode_65.pth e 4.17.1\log_episode_65.csv
#
# Episode 66/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.45s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 67/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.79s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 68/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.76s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 69/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.77s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 70/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.87s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 71/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 288.07s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 72/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.35s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 73/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.01s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 74/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.93s
# Ações: Manter=0, Comprar=36752, Vender=2
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 75/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.18s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 76/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.51s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 77/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.65s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 78/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.05s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 79/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.00s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 80/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.66s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 81/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.65s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 82/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.44s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 83/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.73s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 84/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.44s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 85/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.53s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 86/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.59s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 87/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.93s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 88/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 290.03s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 89/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.17s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 90/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.16s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 91/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.91s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 92/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.63s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 93/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.10s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 94/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.74s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 95/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.97s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 96/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.48s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 97/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.11s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 98/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.03s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 99/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 287.07s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
# Episode 100/100, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Steps: 36754, Time: 286.74s
# Ações: Manter=0, Comprar=36754, Vender=0
# Ganhos Totais: 24092.50, Perdas Totais: -19465.75
#
# Treinamento finalizado.
# Top 10 Melhores Episódios:
# Rank 1: Episode 62, Total Reward: 4564.00, Win Rate: 0.54, Wins: 234, Losses: 196, Ações: {0: 23, 1: 36730, 2: 1}, Steps: 36754, Time: 287.12s
# Rank 2: Episode 55, Total Reward: 4559.25, Win Rate: 0.54, Wins: 234, Losses: 199, Ações: {0: 1, 1: 36747, 2: 6}, Steps: 36754, Time: 286.80s
# Rank 3: Episode 61, Total Reward: 4553.50, Win Rate: 0.54, Wins: 233, Losses: 197, Ações: {0: 0, 1: 36752, 2: 2}, Steps: 36754, Time: 286.63s
# Rank 4: Episode 56, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 1, 1: 36753, 2: 0}, Steps: 36754, Time: 286.41s
# Rank 5: Episode 57, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 0, 1: 36753, 2: 1}, Steps: 36754, Time: 286.16s
# Rank 6: Episode 58, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 0, 1: 36754, 2: 0}, Steps: 36754, Time: 286.38s
# Rank 7: Episode 59, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 1, 1: 36753, 2: 0}, Steps: 36754, Time: 285.79s
# Rank 8: Episode 60, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 0, 1: 36754, 2: 0}, Steps: 36754, Time: 285.84s
# Rank 9: Episode 64, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 0, 1: 36754, 2: 0}, Steps: 36754, Time: 287.33s
# Rank 10: Episode 65, Total Reward: 4519.50, Win Rate: 0.54, Wins: 233, Losses: 196, Ações: {0: 1, 1: 36753, 2: 0}, Steps: 36754, Time: 286.37s
