# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import time
import os

data = pd.read_csv('D:\\dados\\bar_M15_V03_data_01-01-2023_a_31-08-2024.csv')
data['DateTime'] = pd.to_datetime(data['DateTime'])

# Criar a coluna "Valor", que é uma cópia de "Close" e não será normalizada
data['Valor'] = data['Close']

# Normalizar as colunas necessárias (exceto "Valor" e "Gatilho")
scaler = MinMaxScaler()
cols_to_normalize = [
    'Open', 'High', 'Low', 'Close', 'Volume', 'PavioSuperior', 'PavioInferior',
    'Corpo', 'Range','SMA4','SMA8','SMA12','SMA20', 'SMA50', 'SMA100', 'SMA200', 'StochasticoK',
    'StochasticoD', 'RSI', 'MACD', 'MACDSignal', 'MACDHistogram','atr8','atr14','atr28','dayO','dayH','dayL'
]
data[cols_to_normalize] = scaler.fit_transform(data[cols_to_normalize])

# Converter todos os valores para tipo float32 para evitar problemas de tipo
data = data.astype({col: 'float32' for col in cols_to_normalize + ['Valor']})

# %%
import gym
from gym import spaces

class TradingEnv(gym.Env):
    def __init__(self, data):
        super(TradingEnv, self).__init__()
        self.data = data.reset_index(drop=True)
        self.current_step = 0
        self.position = 0  # 0 = neutro, 1 = comprado, -1 = vendido
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.action_space = spaces.Discrete(3)  # 0 = Manter, 1 = Comprar, 2 = Vender
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(len(data.columns) - 3 + 1,), dtype=np.float32
        )
        self.trades = []

    def reset(self):
        self.current_step = 0
        self.position = 0
        self.entry_price = 0.0
        self.entry_step = None
        self.entry_datetime = None
        self.trades = []
        return self._next_observation()

    def _next_observation(self):
        obs = self.data.iloc[self.current_step].drop(['Valor', 'DateTime', 'Gatilho']).values
        obs = np.append(obs, self.position)
        return obs.astype(np.float32)

    def step(self, action):
        done = self.current_step >= len(self.data) - 2
        reward = 0
        info = {}

        # Obter o valor atual e o próximo valor
        current_price = self.data['Valor'].iloc[self.current_step]
        next_price = self.data['Valor'].iloc[self.current_step + 1]

        # Obter o valor do gatilho no passo atual
        gatilho = int(self.data['Gatilho'].iloc[self.current_step])

        # Se o gatilho estiver ativo, o agente pode executar todas as ações
        if gatilho == 1:
            if action == 1:  # Comprar
                if self.position == 0:
                    self.position = 1  # Abrir posição comprada
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25  # Custo de operação
                    info['trade'] = {
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == -1:
                    # Fechar posição vendida
                    self.exit_price = current_price
                    profit = self.entry_price - self.exit_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_short',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            elif action == 2:  # Vender
                if self.position == 0:
                    self.position = -1  # Abrir posição vendida
                    self.entry_price = current_price
                    self.entry_step = self.current_step
                    self.entry_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward -= 0.25
                    info['trade'] = {
                        'type': 'sell',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime
                    }
                elif self.position == 1:
                    # Fechar posição comprada
                    self.exit_price = current_price
                    profit = self.exit_price - self.entry_price - 0.25
                    self.exit_step = self.current_step
                    self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                    reward += profit
                    info['trade'] = {
                        'type': 'close_long',
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    }
                    self.trades.append({
                        'type': 'buy',
                        'entry_step': self.entry_step,
                        'entry_price': self.entry_price,
                        'entry_datetime': self.entry_datetime,
                        'exit_step': self.exit_step,
                        'exit_price': self.exit_price,
                        'exit_datetime': self.exit_datetime,
                        'profit': profit
                    })
                    self.position = 0
                    self.entry_step = None
                    self.entry_datetime = None
            else:  # Manter
                pass
        else:
            # Fechar posição se o gatilho não estiver ativo
            if self.position == 1:
                self.exit_price = current_price
                profit = self.exit_price - self.entry_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_long',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'buy',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None
            elif self.position == -1:
                self.exit_price = current_price
                profit = self.entry_price - self.exit_price - 0.25
                self.exit_step = self.current_step
                self.exit_datetime = self.data['DateTime'].iloc[self.current_step]
                reward += profit
                info['trade'] = {
                    'type': 'close_short',
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                }
                self.trades.append({
                    'type': 'sell',
                    'entry_step': self.entry_step,
                    'entry_price': self.entry_price,
                    'entry_datetime': self.entry_datetime,
                    'exit_step': self.exit_step,
                    'exit_price': self.exit_price,
                    'exit_datetime': self.exit_datetime,
                    'profit': profit
                })
                self.position = 0
                self.entry_step = None
                self.entry_datetime = None

        self.current_step += 1

        obs = self._next_observation()
        return obs, reward, done, info

# %% [markdown]
# ## Bloco 3: Criar o Agente Rainbow DQN usando PyTorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import random
import math
import numpy as np

# Configurações do dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Implementação da Camada Noisy Linear
class NoisyLinear(nn.Module):
    def __init__(self, in_features, out_features, sigma_init=0.017):
        super(NoisyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma_init = sigma_init

        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.register_buffer('weight_epsilon', torch.zeros(out_features, in_features))

        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        self.register_buffer('bias_epsilon', torch.zeros(out_features))

        self.reset_parameters()
        self.reset_noise()

    def reset_parameters(self):
        mu_range = 1 / math.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.sigma_init / math.sqrt(self.in_features))
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.sigma_init / math.sqrt(self.out_features))

    def reset_noise(self):
        epsilon_in = self._scale_noise(self.in_features)
        epsilon_out = self._scale_noise(self.out_features)
        self.weight_epsilon.copy_(epsilon_out.outer(epsilon_in))
        self.bias_epsilon.copy_(epsilon_out)

    def forward(self, x):
        if self.training:
            weight = self.weight_mu + self.weight_sigma * self.weight_epsilon
            bias = self.bias_mu + self.bias_sigma * self.bias_epsilon
        else:
            weight = self.weight_mu
            bias = self.bias_mu
        return nn.functional.linear(x, weight, bias)

    def _scale_noise(self, size):
        x = torch.randn(size)
        return x.sign().mul_(x.abs().sqrt())

# Implementação da Rede Rainbow DQN
class RainbowDQN(nn.Module):
    def __init__(self, obs_size, n_actions):
        super(RainbowDQN, self).__init__()
        self.feature = nn.Sequential(
            nn.Linear(obs_size, 128),
            nn.ReLU()
        )
        # Advantage stream
        self.advantage = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, n_actions)
        )
        # Value stream
        self.value = nn.Sequential(
            NoisyLinear(128, 128),
            nn.ReLU(),
            NoisyLinear(128, 1)
        )

    def forward(self, x):
        x = self.feature(x)
        advantage = self.advantage(x)
        value = self.value(x)
        # Dueling Q-values
        q_values = value + advantage - advantage.mean()
        return q_values

    def reset_noise(self):
        for module in self.modules():
            if isinstance(module, NoisyLinear):
                module.reset_noise()

# Implementação do Prioritized Replay Buffer
class PrioritizedReplayBuffer(object):
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.alpha = alpha

        self.buffer = []
        self.pos = 0

        self.priorities = np.zeros((capacity,), dtype=np.float32)

    def push(self, *args):
        max_prio = self.priorities.max() if self.buffer else 1.0

        if len(self.buffer) < self.capacity:
            self.buffer.append((*args,))
        else:
            self.buffer[self.pos] = (*args,)

        self.priorities[self.pos] = max_prio
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size, beta=0.4):
        if len(self.buffer) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.pos]

        probs = prios ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        total = len(self.buffer)
        weights = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = np.array(weights, dtype=np.float32)

        batch = list(zip(*samples))

        states = torch.cat(batch[0]).to(device)
        actions = torch.tensor(batch[1], dtype=torch.long, device=device).unsqueeze(1)
        rewards = torch.tensor(batch[2], dtype=torch.float32, device=device).unsqueeze(1)
        next_states = torch.cat(batch[3]).to(device)
        dones = torch.tensor(batch[4], dtype=torch.float32, device=device).unsqueeze(1)
        weights = torch.tensor(weights, dtype=torch.float32, device=device).unsqueeze(1)

        return states, actions, rewards, next_states, dones, indices, weights

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio

# %% [markdown]
# ## Bloco 4: Treinamento do Agente Rainbow DQN

# %%
# Configurações do treinamento
num_episodes = 100
gamma = 0.99
batch_size = 256
learning_rate = 5e-4
memory_size = 10000
target_update = 1000
beta_start = 0.4
beta_frames = num_episodes * len(data)
alpha = 0.6

# Criar o ambiente
env = TradingEnv(data)

obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Instanciar a rede
q_net = RainbowDQN(obs_size, n_actions).to(device)
target_net = RainbowDQN(obs_size, n_actions).to(device)
target_net.load_state_dict(q_net.state_dict())

# Definir o otimizador
optimizer = optim.Adam(q_net.parameters(), lr=learning_rate)

# Inicializar o Prioritized Replay Buffer
replay_buffer = PrioritizedReplayBuffer(memory_size, alpha=alpha)

# Inicializar a lista de melhores episódios
best_episodes = []

# Função para selecionar ação usando Noisy Nets
def select_action(state):
    with torch.no_grad():
        q_values = q_net(state)
        return q_values.argmax().item()

save_dir = "4.18.3.1"
os.makedirs(save_dir, exist_ok=True)

beta = beta_start
frame_idx = 0  # Contador de frames para ajustar beta
for episode in range(num_episodes):
    start_time = time.time()
    obs = env.reset()
    obs = torch.FloatTensor(obs).unsqueeze(0).to(device)
    done = False
    total_reward = 0
    steps = 0
    actions_count = {0: 0, 1: 0, 2: 0}
    wins = 0
    losses = 0
    win_total = 0
    lose_total = 0
    trades = []
    current_trade = None

    while not done:
        steps += 1
        frame_idx += 1

        # Selecionar ação
        action = select_action(obs)

        # Executar ação no ambiente
        obs_next, reward, done, info = env.step(action)
        obs_next = torch.FloatTensor(obs_next).unsqueeze(0).to(device)

        # Armazenar na memória de replay
        replay_buffer.push(obs, action, reward, obs_next, done)

        # Atualizar o estado
        obs = obs_next

        # Atualizar contagem de ações
        actions_count[action] += 1

        # Atualizar recompensa total
        total_reward += reward

        # Resetar ruído das Noisy Nets
        q_net.reset_noise()
        target_net.reset_noise()

        # Processar informações de trade
        if 'trade' in info:
            trade_info = info['trade']
            if trade_info['type'] in ['buy', 'sell']:
                current_trade = {
                    'type': trade_info['type'],
                    'entry_step': trade_info['entry_step'],
                    'entry_price': trade_info['entry_price'],
                    'entry_datetime': trade_info['entry_datetime'],
                    'exit_step': None,
                    'exit_price': None,
                    'exit_datetime': None,
                    'profit': None
                }
            elif trade_info['type'] in ['close_long', 'close_short']:
                current_trade['exit_step'] = trade_info['exit_step']
                current_trade['exit_price'] = trade_info['exit_price']
                current_trade['exit_datetime'] = trade_info['exit_datetime']
                current_trade['profit'] = trade_info['profit']
                trades.append(current_trade.copy())
                if current_trade['profit'] > 0:
                    wins += 1
                    win_total += current_trade['profit']
                elif current_trade['profit'] < 0:
                    losses += 1
                    lose_total += current_trade['profit']
                current_trade = None

        # Treinar a rede se a memória tiver tamanho suficiente
        if len(replay_buffer.buffer) >= batch_size:
            beta = min(1.0, beta_start + frame_idx * (1.0 - beta_start) / beta_frames)
            states, actions_batch, rewards_batch, next_states, dones, indices, weights = replay_buffer.sample(batch_size, beta)

            # Computar Q-valor atual
            q_values = q_net(states).gather(1, actions_batch)

            # Computar Q-valor alvo usando Double DQN
            with torch.no_grad():
                next_actions = q_net(next_states).argmax(1, keepdim=True)
                next_q_values = target_net(next_states).gather(1, next_actions)
                target_q_values = rewards_batch + gamma * next_q_values * (1 - dones)

            # Calcular o erro para Prioritized Replay
            td_errors = (q_values - target_q_values).detach().cpu().numpy().flatten()
            new_priorities = np.abs(td_errors) + 1e-6
            replay_buffer.update_priorities(indices, new_priorities)

            # Calcular a perda ponderada
            loss = (weights * nn.functional.mse_loss(q_values, target_q_values, reduction='none')).mean()

            # Otimizar a rede
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Atualizar a rede alvo
            if frame_idx % target_update == 0:
                target_net.load_state_dict(q_net.state_dict())

    # Cálculo do tempo de treinamento do episódio
    end_time = time.time()
    episode_time = end_time - start_time

    win_rate = wins / (wins + losses) if (wins + losses) > 0 else 0
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward:.2f}, Win Rate: {win_rate:.2f}, "
          f"Wins: {wins}, Losses: {losses}, Steps: {steps}, Time: {episode_time:.2f}s")
    print(f"Ações: Manter={actions_count[0]}, Comprar={actions_count[1]}, Vender={actions_count[2]}")
    print(f"Ganhos Totais: {win_total:.2f}, Perdas Totais: {lose_total:.2f}")

    # Salvar informações do episódio
    episode_info = {
        'episode': episode + 1,
        'total_reward': total_reward,
        'win_rate': win_rate,
        'wins': wins,
        'losses': losses,
        'actions_count': actions_count.copy(),
        'win_total': win_total,
        'lose_total': lose_total,
        'steps': steps,
        'episode_time': episode_time,
        'model_state_dict': q_net.state_dict(),
        'trades': trades.copy()
    }

    # Adicionar o episódio à lista dos melhores e manter os top 10
    best_episodes.append(episode_info)
    best_episodes = sorted(best_episodes, key=lambda x: x['total_reward'], reverse=True)[:10]

    # Salvar o modelo e log do episódio se for um dos top 10
    if episode_info in best_episodes:
        model_path = os.path.join(save_dir, f"model_episode_{episode_info['episode']}.pth")
        torch.save(episode_info['model_state_dict'], model_path)
        episode_info['model_path'] = model_path

        # Salvar o log completo das operações
        log_path = os.path.join(save_dir, f"log_episode_{episode_info['episode']}.csv")
        trades_df = pd.DataFrame(episode_info['trades'])
        trades_df.to_csv(log_path, index=False)
        episode_info['log_path'] = log_path

        print(f"Modelo e log do episódio {episode_info['episode']} salvos em: {model_path} e {log_path}\n")

# Exibir os top 10 episódios ao final do treinamento
print("\nTreinamento finalizado.")
print("Top 10 Melhores Episódios:")
for idx, ep in enumerate(best_episodes, 1):
    print(f"Rank {idx}: Episode {ep['episode']}, Total Reward: {ep['total_reward']:.2f}, "
          f"Win Rate: {ep['win_rate']:.2f}, Wins: {ep['wins']}, Losses: {ep['losses']}, "
          f"Ações: {ep['actions_count']}, Steps: {ep['steps']}, Time: {ep['episode_time']:.2f}s")
# Out:
# Episode 1/100, Total Reward: -519.25, Win Rate: 0.50, Wins: 679, Losses: 677, Steps: 36754, Time: 365.83s
# Ações: Manter=22467, Comprar=7943, Vender=6344
# Ganhos Totais: 20170.00, Perdas Totais: -20349.25
# Modelo e log do episódio 1 salvos em: 4.18.3.1\model_episode_1.pth e 4.18.3.1\log_episode_1.csv
#
# Episode 2/100, Total Reward: -291.25, Win Rate: 0.45, Wins: 286, Losses: 345, Steps: 36754, Time: 394.33s
# Ações: Manter=26202, Comprar=4110, Vender=6442
# Ganhos Totais: 14333.75, Perdas Totais: -14465.50
# Modelo e log do episódio 2 salvos em: 4.18.3.1\model_episode_2.pth e 4.18.3.1\log_episode_2.csv
#
# Episode 3/100, Total Reward: -919.00, Win Rate: 0.48, Wins: 347, Losses: 372, Steps: 36754, Time: 395.97s
# Ações: Manter=27863, Comprar=3049, Vender=5842
# Ganhos Totais: 14505.00, Perdas Totais: -15243.75
# Modelo e log do episódio 3 salvos em: 4.18.3.1\model_episode_3.pth e 4.18.3.1\log_episode_3.csv
#
# Episode 4/100, Total Reward: -2070.50, Win Rate: 0.46, Wins: 345, Losses: 404, Steps: 36754, Time: 392.08s
# Ações: Manter=29848, Comprar=2162, Vender=4744
# Ganhos Totais: 13978.75, Perdas Totais: -15861.25
# Modelo e log do episódio 4 salvos em: 4.18.3.1\model_episode_4.pth e 4.18.3.1\log_episode_4.csv
#
# Episode 5/100, Total Reward: 1450.50, Win Rate: 0.49, Wins: 354, Losses: 363, Steps: 36754, Time: 394.93s
# Ações: Manter=29779, Comprar=2594, Vender=4381
# Ganhos Totais: 15993.25, Perdas Totais: -14362.25
# Modelo e log do episódio 5 salvos em: 4.18.3.1\model_episode_5.pth e 4.18.3.1\log_episode_5.csv
#
# Episode 6/100, Total Reward: -2424.75, Win Rate: 0.46, Wins: 428, Losses: 500, Steps: 36754, Time: 402.98s
# Ações: Manter=27619, Comprar=2991, Vender=6144
# Ganhos Totais: 19544.00, Perdas Totais: -21735.50
# Modelo e log do episódio 6 salvos em: 4.18.3.1\model_episode_6.pth e 4.18.3.1\log_episode_6.csv
#
# Episode 7/100, Total Reward: -1942.25, Win Rate: 0.47, Wins: 470, Losses: 525, Steps: 36754, Time: 330.37s
# Ações: Manter=20210, Comprar=1893, Vender=14651
# Ganhos Totais: 24501.25, Perdas Totais: -26193.75
# Modelo e log do episódio 7 salvos em: 4.18.3.1\model_episode_7.pth e 4.18.3.1\log_episode_7.csv
#
# Episode 8/100, Total Reward: -1679.25, Win Rate: 0.53, Wins: 679, Losses: 601, Steps: 36754, Time: 318.64s
# Ações: Manter=16690, Comprar=3717, Vender=16347
# Ganhos Totais: 28016.50, Perdas Totais: -29374.00
# Modelo e log do episódio 8 salvos em: 4.18.3.1\model_episode_8.pth e 4.18.3.1\log_episode_8.csv
#
# Episode 9/100, Total Reward: -3698.50, Win Rate: 0.51, Wins: 1013, Losses: 962, Steps: 36754, Time: 317.22s
# Ações: Manter=13804, Comprar=6821, Vender=16129
# Ganhos Totais: 30933.25, Perdas Totais: -34136.00
# Modelo e log do episódio 9 salvos em: 4.18.3.1\model_episode_9.pth e 4.18.3.1\log_episode_9.csv
#
# Episode 10/100, Total Reward: -2760.00, Win Rate: 0.55, Wins: 683, Losses: 567, Steps: 36754, Time: 315.54s
# Ações: Manter=16537, Comprar=5708, Vender=14509
# Ganhos Totais: 27440.75, Perdas Totais: -29887.75
# Modelo e log do episódio 10 salvos em: 4.18.3.1\model_episode_10.pth e 4.18.3.1\log_episode_10.csv
#
# Episode 11/100, Total Reward: -3157.00, Win Rate: 0.52, Wins: 862, Losses: 780, Steps: 36754, Time: 314.97s
# Ações: Manter=15369, Comprar=6141, Vender=15244
# Ganhos Totais: 28974.75, Perdas Totais: -31721.00
# Modelo e log do episódio 11 salvos em: 4.18.3.1\model_episode_11.pth e 4.18.3.1\log_episode_11.csv
#
# Episode 12/100, Total Reward: -8123.00, Win Rate: 0.54, Wins: 844, Losses: 731, Steps: 36754, Time: 338.96s
# Ações: Manter=15860, Comprar=4978, Vender=15916
# Ganhos Totais: 25420.00, Perdas Totais: -33148.00
# Episode 13/100, Total Reward: -7256.00, Win Rate: 0.55, Wins: 887, Losses: 731, Steps: 36754, Time: 352.89s
# Ações: Manter=19219, Comprar=5245, Vender=12290
# Ganhos Totais: 25951.00, Perdas Totais: -32800.00
# Episode 14/100, Total Reward: 2293.25, Win Rate: 0.55, Wins: 814, Losses: 669, Steps: 36754, Time: 352.42s
# Ações: Manter=19813, Comprar=7257, Vender=9684
# Ganhos Totais: 29026.25, Perdas Totais: -26361.75
# Modelo e log do episódio 14 salvos em: 4.18.3.1\model_episode_14.pth e 4.18.3.1\log_episode_14.csv
#
# Episode 15/100, Total Reward: 2148.00, Win Rate: 0.56, Wins: 835, Losses: 655, Steps: 36754, Time: 352.12s
# Ações: Manter=16836, Comprar=8453, Vender=11465
# Ganhos Totais: 31302.75, Perdas Totais: -28782.00
# Modelo e log do episódio 15 salvos em: 4.18.3.1\model_episode_15.pth e 4.18.3.1\log_episode_15.csv
#
# Episode 16/100, Total Reward: 2391.00, Win Rate: 0.56, Wins: 663, Losses: 521, Steps: 36754, Time: 351.98s
# Ações: Manter=13310, Comprar=8840, Vender=14604
# Ganhos Totais: 30524.25, Perdas Totais: -27836.75
# Modelo e log do episódio 16 salvos em: 4.18.3.1\model_episode_16.pth e 4.18.3.1\log_episode_16.csv
#
# Episode 17/100, Total Reward: 3190.75, Win Rate: 0.52, Wins: 759, Losses: 692, Steps: 36754, Time: 354.49s
# Ações: Manter=10767, Comprar=15395, Vender=10592
# Ganhos Totais: 31122.00, Perdas Totais: -27567.50
# Modelo e log do episódio 17 salvos em: 4.18.3.1\model_episode_17.pth e 4.18.3.1\log_episode_17.csv
#
# Episode 18/100, Total Reward: 2993.00, Win Rate: 0.55, Wins: 551, Losses: 460, Steps: 36754, Time: 351.79s
# Ações: Manter=11572, Comprar=15414, Vender=9768
# Ganhos Totais: 29191.50, Perdas Totais: -25945.50
# Modelo e log do episódio 18 salvos em: 4.18.3.1\model_episode_18.pth e 4.18.3.1\log_episode_18.csv
#
# Episode 19/100, Total Reward: 2062.00, Win Rate: 0.55, Wins: 719, Losses: 585, Steps: 36754, Time: 352.51s
# Ações: Manter=10230, Comprar=14462, Vender=12062
# Ganhos Totais: 31335.25, Perdas Totais: -28946.50
# Modelo e log do episódio 19 salvos em: 4.18.3.1\model_episode_19.pth e 4.18.3.1\log_episode_19.csv
#
# Episode 20/100, Total Reward: 4220.50, Win Rate: 0.54, Wins: 532, Losses: 456, Steps: 36754, Time: 351.88s
# Ações: Manter=12896, Comprar=19650, Vender=4208
# Ganhos Totais: 27865.00, Perdas Totais: -23396.25
# Modelo e log do episódio 20 salvos em: 4.18.3.1\model_episode_20.pth e 4.18.3.1\log_episode_20.csv
#
# Episode 21/100, Total Reward: 4886.00, Win Rate: 0.53, Wins: 621, Losses: 547, Steps: 36754, Time: 351.90s
# Ações: Manter=5180, Comprar=27544, Vender=4030
# Ganhos Totais: 30086.00, Perdas Totais: -24907.50
# Modelo e log do episódio 21 salvos em: 4.18.3.1\model_episode_21.pth e 4.18.3.1\log_episode_21.csv
#
# Episode 22/100, Total Reward: -662.50, Win Rate: 0.51, Wins: 930, Losses: 905, Steps: 36754, Time: 351.98s
# Ações: Manter=7775, Comprar=12305, Vender=16674
# Ganhos Totais: 31007.75, Perdas Totais: -31209.25
# Episode 23/100, Total Reward: -942.25, Win Rate: 0.48, Wins: 898, Losses: 982, Steps: 36754, Time: 352.09s
# Ações: Manter=8465, Comprar=7484, Vender=20805
# Ganhos Totais: 31033.75, Perdas Totais: -31502.75
# Episode 24/100, Total Reward: -3572.50, Win Rate: 0.48, Wins: 761, Losses: 820, Steps: 36754, Time: 352.56s
# Ações: Manter=6230, Comprar=7276, Vender=23248
# Ganhos Totais: 28346.75, Perdas Totais: -31522.75
# Episode 25/100, Total Reward: -1745.75, Win Rate: 0.51, Wins: 284, Losses: 277, Steps: 36754, Time: 353.27s
# Ações: Manter=15615, Comprar=841, Vender=20298
# Ganhos Totais: 19439.25, Perdas Totais: -21044.25
# Episode 26/100, Total Reward: -337.25, Win Rate: 0.51, Wins: 1473, Losses: 1421, Steps: 36754, Time: 352.00s
# Ações: Manter=5518, Comprar=10389, Vender=20847
# Ganhos Totais: 35828.25, Perdas Totais: -35437.75
# Episode 27/100, Total Reward: -3757.00, Win Rate: 0.52, Wins: 1265, Losses: 1182, Steps: 36754, Time: 352.92s
# Ações: Manter=9345, Comprar=18818, Vender=8591
# Ganhos Totais: 30465.50, Perdas Totais: -33606.25
# Episode 28/100, Total Reward: -2315.00, Win Rate: 0.51, Wins: 858, Losses: 811, Steps: 36754, Time: 352.81s
# Ações: Manter=6312, Comprar=6844, Vender=23598
# Ganhos Totais: 27146.75, Perdas Totais: -29042.75
# Episode 29/100, Total Reward: -3591.75, Win Rate: 0.49, Wins: 529, Losses: 560, Steps: 36754, Time: 352.79s
# Ações: Manter=3695, Comprar=3160, Vender=29899
# Ganhos Totais: 24951.50, Perdas Totais: -28269.75
# Episode 30/100, Total Reward: -4513.75, Win Rate: 0.50, Wins: 193, Losses: 191, Steps: 36754, Time: 352.24s
# Ações: Manter=21025, Comprar=244, Vender=15485
# Ganhos Totais: 10639.50, Perdas Totais: -15056.75
# Episode 31/100, Total Reward: -435.50, Win Rate: 0.47, Wins: 63, Losses: 70, Steps: 36754, Time: 352.14s
# Ações: Manter=36192, Comprar=14, Vender=548
# Ganhos Totais: 5184.00, Perdas Totais: -5585.75
# Episode 32/100, Total Reward: -1484.00, Win Rate: 0.48, Wins: 50, Losses: 55, Steps: 36754, Time: 352.39s
# Ações: Manter=36338, Comprar=334, Vender=82
# Ganhos Totais: 3604.00, Perdas Totais: -5061.75
# Episode 33/100, Total Reward: -79.50, Win Rate: 0.35, Wins: 6, Losses: 11, Steps: 36754, Time: 352.12s
# Ações: Manter=36735, Comprar=13, Vender=6
# Ganhos Totais: 514.75, Perdas Totais: -590.00
# Modelo e log do episódio 33 salvos em: 4.18.3.1\model_episode_33.pth e 4.18.3.1\log_episode_33.csv
#
# Episode 34/100, Total Reward: 229.25, Win Rate: 0.71, Wins: 5, Losses: 2, Steps: 36754, Time: 352.00s
# Ações: Manter=36724, Comprar=1, Vender=29
# Ganhos Totais: 415.50, Perdas Totais: -184.50
# Modelo e log do episódio 34 salvos em: 4.18.3.1\model_episode_34.pth e 4.18.3.1\log_episode_34.csv
#
# Episode 35/100, Total Reward: -145.75, Win Rate: 0.00, Wins: 0, Losses: 1, Steps: 36754, Time: 351.87s
# Ações: Manter=36724, Comprar=0, Vender=30
# Ganhos Totais: 0.00, Perdas Totais: -145.50
# Episode 36/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.71s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 37/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.92s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 38/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.10s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 39/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.32s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 40/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.64s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 41/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 350.83s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 42/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.58s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 43/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.63s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 44/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.34s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 45/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.68s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 46/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.24s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 47/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.68s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 48/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.81s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 49/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.98s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 50/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.83s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 51/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.29s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 52/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.53s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 53/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.34s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 54/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.44s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 55/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.99s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 56/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.74s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 57/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.17s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 58/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.60s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 59/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.01s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 60/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.07s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 61/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.75s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 62/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.00s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 63/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.59s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 64/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.47s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 65/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.99s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 66/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.17s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 67/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.50s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 68/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.06s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 69/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.60s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 70/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.59s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 71/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.24s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 72/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.85s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 73/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.53s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 74/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.73s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 75/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.86s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 76/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.98s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 77/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.87s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 78/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.54s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 79/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.01s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 80/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.26s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 81/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.59s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 82/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.48s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 83/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.71s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 84/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.62s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 85/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 353.06s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 86/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 354.03s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 87/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 354.48s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 88/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.70s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 89/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.90s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 90/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.91s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 91/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.44s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 92/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.85s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 93/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.84s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 94/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.29s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 95/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.76s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 96/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 352.20s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 97/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 351.35s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 98/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 329.34s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 99/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 329.37s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
# Episode 100/100, Total Reward: 0.00, Win Rate: 0.00, Wins: 0, Losses: 0, Steps: 36754, Time: 330.00s
# Ações: Manter=36754, Comprar=0, Vender=0
# Ganhos Totais: 0.00, Perdas Totais: 0.00
#
# Treinamento finalizado.
# Top 10 Melhores Episódios:
# Rank 1: Episode 21, Total Reward: 4886.00, Win Rate: 0.53, Wins: 621, Losses: 547, Ações: {0: 5180, 1: 27544, 2: 4030}, Steps: 36754, Time: 351.90s
# Rank 2: Episode 20, Total Reward: 4220.50, Win Rate: 0.54, Wins: 532, Losses: 456, Ações: {0: 12896, 1: 19650, 2: 4208}, Steps: 36754, Time: 351.88s
# Rank 3: Episode 17, Total Reward: 3190.75, Win Rate: 0.52, Wins: 759, Losses: 692, Ações: {0: 10767, 1: 15395, 2: 10592}, Steps: 36754, Time: 354.49s
# Rank 4: Episode 18, Total Reward: 2993.00, Win Rate: 0.55, Wins: 551, Losses: 460, Ações: {0: 11572, 1: 15414, 2: 9768}, Steps: 36754, Time: 351.79s
# Rank 5: Episode 16, Total Reward: 2391.00, Win Rate: 0.56, Wins: 663, Losses: 521, Ações: {0: 13310, 1: 8840, 2: 14604}, Steps: 36754, Time: 351.98s
# Rank 6: Episode 14, Total Reward: 2293.25, Win Rate: 0.55, Wins: 814, Losses: 669, Ações: {0: 19813, 1: 7257, 2: 9684}, Steps: 36754, Time: 352.42s
# Rank 7: Episode 15, Total Reward: 2148.00, Win Rate: 0.56, Wins: 835, Losses: 655, Ações: {0: 16836, 1: 8453, 2: 11465}, Steps: 36754, Time: 352.12s
# Rank 8: Episode 19, Total Reward: 2062.00, Win Rate: 0.55, Wins: 719, Losses: 585, Ações: {0: 10230, 1: 14462, 2: 12062}, Steps: 36754, Time: 352.51s
# Rank 9: Episode 5, Total Reward: 1450.50, Win Rate: 0.49, Wins: 354, Losses: 363, Ações: {0: 29779, 1: 2594, 2: 4381}, Steps: 36754, Time: 394.93s
# Rank 10: Episode 34, Total Reward: 229.25, Win Rate: 0.71, Wins: 5, Losses: 2, Ações: {0: 36724, 1: 1, 2: 29}, Steps: 36754, Time: 352.00s
